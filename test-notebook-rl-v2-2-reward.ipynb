# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#from src.data.data_collector import DataCollector
from src.models.model_trainer_rl_v2_2 import ModelTrainerRL, TradingEnvRL
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from src.models.backtester import PortfolioBacktester, PortfolioBacktesterRL
from src.utils.config_loader import load_config


config = load_config("config/config.yaml")
# Out:
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:32: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_format is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_format instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:33: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_width is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_width instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:34: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_height is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_height instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:35: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_scale is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_scale instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:133: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:141: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.plotlyjs is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.plotlyjs instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:147: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.

# %% [markdown]
# ## V2.2 PPO Agent

# %% [markdown]
# #### Template

# %%
# # Load Data
# try:
#     data = pd.read_csv('data/processed/CWCO_processed_2022.csv')
#     if 'Date' in data.columns:
#         data['Date'] = pd.to_datetime(data['Date'])
#         data.set_index('Date', inplace=True)
#     print("Data loaded successfully.")
# except FileNotFoundError:
#     print("Error: Data file not found. Check path.")
#     # Exit if no data
#     sys.exit()

# # Split Data
# split_idx = int(len(data) * 0.8)
# train_df = data.iloc[:split_idx]
# test_df = data.iloc[split_idx:]
# # (Ensure your CSV has columns like 'close', 'rsi', 'sma', etc.)
# try:
#     data = pd.read_csv('data/processed/CWCO_processed_2022.csv')
#     if 'Date' in data.columns:
#         data['Date'] = pd.to_datetime(data['Date'])
#         data.set_index('Date', inplace=True)
#     print("Data loaded successfully.")
# except FileNotFoundError:
#     print("Error: Data file not found. Check path.")


# # ... Load Data ...
# # Ensure you fit your scaler ONLY on train_df, then transform test_df
# split_idx = int(len(data) * 0.7)
# train_df = data.iloc[:split_idx]
# test_df = data.iloc[split_idx:]

# # --- TRAINING ---
# trainer = ModelTrainerRL(config={'ppo': {'learning_rate': 0.0003}, 'total_timesteps': 20000})
# env_train = TradingEnvRL(train_df, initial_balance=10000)

# # This trains AND stores the VecNormalize stats internally
# result = trainer.train_ppo(env_train) 

# # Save properly
# trainer.save_models("models/")

# # --- INFERENCE / BACKTEST ---
# print("Running Inference...")

# # 1. Load Model
# model = PPO.load("models/ppo_model")

# # 2. Create Test Environment
# env_test = TradingEnvRL(test_df, initial_balance=100000)
# vec_env_test = DummyVecEnv([lambda: env_test])

# # 3. CRITICAL FIX: Load Normalization Stats
# # We must apply the same scaling (mean/var) learned during training to the test data.
# # We set training=False so we don't update the stats based on test data.
# norm_path = "models/ppo_vecnormalize.pkl"
# vec_env_test = VecNormalize.load(norm_path, vec_env_test)
# vec_env_test.training = False 
# vec_env_test.norm_reward = False # Don't normalize rewards during test

# obs = vec_env_test.reset()
# done = False
# actions = []

# while not done:
#     # Now 'obs' is properly scaled (e.g., near 0.0 instead of 150.0)
#     action, _ = model.predict(obs, deterministic=True)
#     actions.append(action[0])
    
#     # Step the vectorized environment
#     obs, rewards, done, info = vec_env_test.step(action)

# print(f"Generated {len(actions)} actions.")

# %% [markdown]
# #### MDU - YES

# %%
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv('data/processed/MDU_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, "ppo_vecnormalize.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_16940\4030381681.py:6: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1638 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1288         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0049444935 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.479       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.094        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00507     |
# |    std                  | 1.01         |
# |    value_loss           | 0.379        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1192        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008037774 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.0238      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 1.01        |
# |    value_loss           | 0.191       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1148         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0067489063 |
# |    clip_fraction        | 0.0644       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.232        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00131     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0112      |
# |    std                  | 1            |
# |    value_loss           | 0.161        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1126        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007530244 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0166     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 1.01        |
# |    value_loss           | 0.139       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1105         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0060711848 |
# |    clip_fraction        | 0.0725       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.374        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0252      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 1.01         |
# |    value_loss           | 0.147        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1099        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008462237 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.04       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.994       |
# |    value_loss           | 0.109       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1088        |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006300729 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0405     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.981       |
# |    value_loss           | 0.106       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1084         |
# |    iterations           | 9            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0057239775 |
# |    clip_fraction        | 0.0602       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.455        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.062       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00983     |
# |    std                  | 0.974        |
# |    value_loss           | 0.0815       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1079        |
# |    iterations           | 10          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007301188 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0549     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.966       |
# |    value_loss           | 0.0697      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1080        |
# |    iterations           | 11          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005814252 |
# |    clip_fraction        | 0.0612      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0548     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00961    |
# |    std                  | 0.961       |
# |    value_loss           | 0.0544      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1071         |
# |    iterations           | 12           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0064986246 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0589      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 0.961        |
# |    value_loss           | 0.0536       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1068         |
# |    iterations           | 13           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0071734795 |
# |    clip_fraction        | 0.0752       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.65         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0728      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 0.961        |
# |    value_loss           | 0.0396       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1063         |
# |    iterations           | 14           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0060802987 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0719      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 0.961        |
# |    value_loss           | 0.0298       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1056         |
# |    iterations           | 15           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0067313453 |
# |    clip_fraction        | 0.0622       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0761      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.955        |
# |    value_loss           | 0.0255       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1061        |
# |    iterations           | 16          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005495932 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0683     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.95        |
# |    value_loss           | 0.0265      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1051        |
# |    iterations           | 17          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005282281 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0704     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00925    |
# |    std                  | 0.94        |
# |    value_loss           | 0.0216      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1052         |
# |    iterations           | 18           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0064378567 |
# |    clip_fraction        | 0.0695       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0712      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.931        |
# |    value_loss           | 0.0197       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1052        |
# |    iterations           | 19          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005307789 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0633     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00976    |
# |    std                  | 0.934       |
# |    value_loss           | 0.0182      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1054         |
# |    iterations           | 20           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0050137015 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0765      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.929        |
# |    value_loss           | 0.0148       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1053        |
# |    iterations           | 21          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005865293 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0782     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.92        |
# |    value_loss           | 0.0128      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1054        |
# |    iterations           | 22          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004501827 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0744     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.913       |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1056         |
# |    iterations           | 23           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0043160995 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0672      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00798     |
# |    std                  | 0.913        |
# |    value_loss           | 0.0102       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1053         |
# |    iterations           | 24           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0037810327 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0678      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00857     |
# |    std                  | 0.906        |
# |    value_loss           | 0.00949      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1052         |
# |    iterations           | 25           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0039622774 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0765      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00743     |
# |    std                  | 0.905        |
# |    value_loss           | 0.00791      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 26          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004040116 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0839     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0087     |
# |    std                  | 0.904       |
# |    value_loss           | 0.00871     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 27          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.005712581 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0723     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.911       |
# |    value_loss           | 0.00707     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1048         |
# |    iterations           | 28           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0037954033 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0839      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00839     |
# |    std                  | 0.91         |
# |    value_loss           | 0.00641      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 29          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.006535977 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0752     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00893    |
# |    std                  | 0.912       |
# |    value_loss           | 0.008       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1037         |
# |    iterations           | 30           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0053276494 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0781      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 0.92         |
# |    value_loss           | 0.00713      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1036        |
# |    iterations           | 31          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004570217 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0801     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00972    |
# |    std                  | 0.912       |
# |    value_loss           | 0.00689     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 32          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004309821 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0786     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00955    |
# |    std                  | 0.902       |
# |    value_loss           | 0.00521     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1015        |
# |    iterations           | 33          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004265606 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0762     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00918    |
# |    std                  | 0.908       |
# |    value_loss           | 0.00441     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1005         |
# |    iterations           | 34           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0050266893 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.069       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00918     |
# |    std                  | 0.909        |
# |    value_loss           | 0.00532      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 35          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004859218 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0684     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.912       |
# |    value_loss           | 0.00532     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 992          |
# |    iterations           | 36           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0039097755 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0801      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00758     |
# |    std                  | 0.917        |
# |    value_loss           | 0.00457      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 992          |
# |    iterations           | 37           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0045333304 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0822      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 0.91         |
# |    value_loss           | 0.00493      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 986          |
# |    iterations           | 38           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0059078326 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0754      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.912        |
# |    value_loss           | 0.00503      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 987        |
# |    iterations           | 39         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.00655607 |
# |    clip_fraction        | 0.0631     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0793    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00913   |
# |    std                  | 0.907      |
# |    value_loss           | 0.00468    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 987         |
# |    iterations           | 40          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005832359 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0837     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.899       |
# |    value_loss           | 0.00364     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 988         |
# |    iterations           | 41          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004409969 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0722     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00871    |
# |    std                  | 0.903       |
# |    value_loss           | 0.00431     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 992          |
# |    iterations           | 42           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0054822024 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0843      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.901        |
# |    value_loss           | 0.00464      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 995          |
# |    iterations           | 43           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0047515016 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0909      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.904        |
# |    value_loss           | 0.00349      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 997          |
# |    iterations           | 44           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0047264146 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0678      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00959     |
# |    std                  | 0.904        |
# |    value_loss           | 0.00379      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1000         |
# |    iterations           | 45           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0062090475 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0882      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.91         |
# |    value_loss           | 0.00372      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1004        |
# |    iterations           | 46          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006101327 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0771     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.913       |
# |    value_loss           | 0.00395     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 47          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006175068 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0851     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.91        |
# |    value_loss           | 0.00305     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 48          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005029331 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0859     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.908       |
# |    value_loss           | 0.00339     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1011         |
# |    iterations           | 49           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0046163797 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0783      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.895        |
# |    value_loss           | 0.00267      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1014        |
# |    iterations           | 50          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007424541 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0976     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.902       |
# |    value_loss           | 0.00274     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1016        |
# |    iterations           | 51          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.005972175 |
# |    clip_fraction        | 0.0408      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0866     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00896    |
# |    std                  | 0.902       |
# |    value_loss           | 0.0027      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1018        |
# |    iterations           | 52          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.005780566 |
# |    clip_fraction        | 0.0533      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.084      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.905       |
# |    value_loss           | 0.00262     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1021        |
# |    iterations           | 53          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.004962947 |
# |    clip_fraction        | 0.0369      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0877     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.909       |
# |    value_loss           | 0.00276     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 54          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.004754561 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.09       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.909       |
# |    value_loss           | 0.00259     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 55          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.004814373 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0749     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00926    |
# |    std                  | 0.904       |
# |    value_loss           | 0.00323     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1025         |
# |    iterations           | 56           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0059874784 |
# |    clip_fraction        | 0.0568       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0931      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.0112      |
# |    std                  | 0.906        |
# |    value_loss           | 0.00212      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1028         |
# |    iterations           | 57           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0052821264 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0901      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.906        |
# |    value_loss           | 0.00257      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1030         |
# |    iterations           | 58           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0049538403 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0885      |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.912        |
# |    value_loss           | 0.00203      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1030         |
# |    iterations           | 59           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0062044645 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0689      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.907        |
# |    value_loss           | 0.00231      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1030        |
# |    iterations           | 60          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.005817665 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# ...
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1058        |
# |    iterations           | 80          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.007114526 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0827     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.949       |
# |    value_loss           | 0.00174     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1059        |
# |    iterations           | 81          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.005973015 |
# |    clip_fraction        | 0.0498      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0914     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.957       |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1060         |
# |    iterations           | 82           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0061163213 |
# |    clip_fraction        | 0.0697       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0937      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0153      |
# |    std                  | 0.951        |
# |    value_loss           | 0.00121      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1061       |
# |    iterations           | 83         |
# |    time_elapsed         | 160        |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.00692037 |
# |    clip_fraction        | 0.0712     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0901    |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.0133    |
# |    std                  | 0.957      |
# |    value_loss           | 0.00156    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1062        |
# |    iterations           | 84          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.007803941 |
# |    clip_fraction        | 0.0661      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0789     |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.951       |
# |    value_loss           | 0.00147     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1063        |
# |    iterations           | 85          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.006010889 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0753     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.951       |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1064        |
# |    iterations           | 86          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.006230309 |
# |    clip_fraction        | 0.061       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0829     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.951       |
# |    value_loss           | 0.00219     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1065        |
# |    iterations           | 87          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.008178659 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0933     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.95        |
# |    value_loss           | 0.000918    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1066         |
# |    iterations           | 88           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0057423734 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0847      |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0129      |
# |    std                  | 0.954        |
# |    value_loss           | 0.00147      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 89          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.008079249 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0984     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.955       |
# |    value_loss           | 0.00198     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1068       |
# |    iterations           | 90         |
# |    time_elapsed         | 172        |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.00539184 |
# |    clip_fraction        | 0.0521     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0781    |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.0108    |
# |    std                  | 0.965      |
# |    value_loss           | 0.00124    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1069        |
# |    iterations           | 91          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.008235914 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.071      |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.965       |
# |    value_loss           | 0.000896    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1070        |
# |    iterations           | 92          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.009122517 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0907     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.964       |
# |    value_loss           | 0.00214     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1071        |
# |    iterations           | 93          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.006003162 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0938     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.965       |
# |    value_loss           | 0.0015      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1071       |
# |    iterations           | 94         |
# |    time_elapsed         | 179        |
# |    total_timesteps      | 192512     |
# | train/                  |            |
# |    approx_kl            | 0.00857291 |
# |    clip_fraction        | 0.0809     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0867    |
# |    n_updates            | 930        |
# |    policy_gradient_loss | -0.015     |
# |    std                  | 0.956      |
# |    value_loss           | 0.00149    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1072        |
# |    iterations           | 95          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.007350934 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0767     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.958       |
# |    value_loss           | 0.000976    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1073        |
# |    iterations           | 96          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.006748381 |
# |    clip_fraction        | 0.061       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0855     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.955       |
# |    value_loss           | 0.00172     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 97          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.007232843 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0833     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.95        |
# |    value_loss           | 0.00131     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1075       |
# |    iterations           | 98         |
# |    time_elapsed         | 186        |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.00864699 |
# |    clip_fraction        | 0.0671     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.082     |
# |    n_updates            | 970        |
# |    policy_gradient_loss | -0.0147    |
# |    std                  | 0.942      |
# |    value_loss           | 0.00194    |
# ----------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 88.28%
# INFO:BacktesterRL:Buy & Hold Return: 18.21%
# INFO:BacktesterRL:Outperformance: 70.06%
# Generated 218 actions.
# Running Backtest...
#
# --- Strategy Performance ---
# Total Return (%): 88.2800
# Annual Return (%): 188.4700
# Sharpe Ratio: 4.2726
# Sortino Ratio: 7.8894
# Max Drawdown (%): -9.1600
# Calmar Ratio: 20.5729
# Win Rate (%): 66.6700
# Total Trades: 45.0000
# Final Value ($): 188277.5000

# %% [markdown]
# #### CWCO - YES

# %%
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv('data/processed/CWCO_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, "ppo_vecnormalize.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_16940\2564739240.py:6: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1797 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1321         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0072425175 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.0323      |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.115        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0109      |
# |    std                  | 0.999        |
# |    value_loss           | 0.47         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1142        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006156856 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.048       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.0182      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0081     |
# |    std                  | 1.01        |
# |    value_loss           | 0.246       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1109         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0069885124 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0398      |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.00798      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0112      |
# |    std                  | 1.01         |
# |    value_loss           | 0.181        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1055         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0078118946 |
# |    clip_fraction        | 0.0903       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0867       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0495      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0138      |
# |    std                  | 1.01         |
# |    value_loss           | 0.123        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1065       |
# |    iterations           | 6          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00563299 |
# |    clip_fraction        | 0.0528     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0.291      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0421    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.009     |
# |    std                  | 1.02       |
# |    value_loss           | 0.108      |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1076      |
# |    iterations           | 7         |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0057592 |
# |    clip_fraction        | 0.0732    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.44     |
# |    explained_variance   | 0.324     |
# |    learning_rate        | 0.0002    |
# |    loss                 | -0.0563   |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -0.0104   |
# |    std                  | 1.02      |
# |    value_loss           | 0.0843    |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1085         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0052233115 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.298        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0499      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0086      |
# |    std                  | 1.02         |
# |    value_loss           | 0.0893       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1090         |
# |    iterations           | 9            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0068167504 |
# |    clip_fraction        | 0.0854       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.531        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0669      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0143      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0739       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 10           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0051148525 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0576      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00877     |
# |    std                  | 1.01         |
# |    value_loss           | 0.0661       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1088         |
# |    iterations           | 11           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0073496033 |
# |    clip_fraction        | 0.0855       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.737        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.057       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0119      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0542       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1099        |
# |    iterations           | 12          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004579674 |
# |    clip_fraction        | 0.0435      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0631     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00859    |
# |    std                  | 1.01        |
# |    value_loss           | 0.0432      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1105        |
# |    iterations           | 13          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004335221 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0575     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00757    |
# |    std                  | 1.01        |
# |    value_loss           | 0.0389      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 14          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.003813834 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0614     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00645    |
# |    std                  | 1           |
# |    value_loss           | 0.0478      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1121         |
# |    iterations           | 15           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0050052176 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.056       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00928     |
# |    std                  | 0.991        |
# |    value_loss           | 0.0322       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1126         |
# |    iterations           | 16           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0049853753 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.938        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0762      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0078      |
# |    std                  | 0.982        |
# |    value_loss           | 0.0251       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 17           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0066556567 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0727      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0118      |
# |    std                  | 0.983        |
# |    value_loss           | 0.0222       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1137        |
# |    iterations           | 18          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004338325 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0785     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00743    |
# |    std                  | 0.985       |
# |    value_loss           | 0.032       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1141         |
# |    iterations           | 19           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0050833155 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.068       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00821     |
# |    std                  | 0.99         |
# |    value_loss           | 0.0169       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1146        |
# |    iterations           | 20          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004970479 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.072      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.982       |
# |    value_loss           | 0.0147      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1151         |
# |    iterations           | 21           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0044332487 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0752      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00953     |
# |    std                  | 0.982        |
# |    value_loss           | 0.0146       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1153         |
# |    iterations           | 22           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0031514699 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0783      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00777     |
# |    std                  | 0.978        |
# |    value_loss           | 0.0129       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1153         |
# |    iterations           | 23           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0048621558 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0815      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00859     |
# |    std                  | 0.968        |
# |    value_loss           | 0.0135       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1158         |
# |    iterations           | 24           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0052137934 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0734      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00956     |
# |    std                  | 0.961        |
# |    value_loss           | 0.0138       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1160        |
# |    iterations           | 25          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004013703 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0802     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00766    |
# |    std                  | 0.953       |
# |    value_loss           | 0.00974     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1162         |
# |    iterations           | 26           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0048069023 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0701      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.956        |
# |    value_loss           | 0.0127       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1165        |
# |    iterations           | 27          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004333379 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0702     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00909    |
# |    std                  | 0.952       |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1167         |
# |    iterations           | 28           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0040218146 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0863      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.
|
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0821     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00983    |
# |    std                  | 0.95        |
# |    value_loss           | 0.00321     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1200         |
# |    iterations           | 56           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0046021026 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0882      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00888     |
# |    std                  | 0.947        |
# |    value_loss           | 0.00322      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1200        |
# |    iterations           | 57          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.004520135 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0799     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00781    |
# |    std                  | 0.945       |
# |    value_loss           | 0.00368     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1201         |
# |    iterations           | 58           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0050323615 |
# |    clip_fraction        | 0.042        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0795      |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.0089      |
# |    std                  | 0.944        |
# |    value_loss           | 0.00417      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1200         |
# |    iterations           | 59           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0057233376 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.08        |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00901     |
# |    std                  | 0.949        |
# |    value_loss           | 0.00348      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1202         |
# |    iterations           | 60           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0068479646 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# ...
# |    iterations           | 80           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0069666863 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0868      |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.0111      |
# |    std                  | 0.969        |
# |    value_loss           | 0.00202      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1201         |
# |    iterations           | 81           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0071126143 |
# |    clip_fraction        | 0.0553       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.1         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0118      |
# |    std                  | 0.964        |
# |    value_loss           | 0.00298      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1200        |
# |    iterations           | 82          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.006856624 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0909     |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.955       |
# |    value_loss           | 0.00276     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1200        |
# |    iterations           | 83          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.007645775 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0832     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.951       |
# |    value_loss           | 0.00211     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1200        |
# |    iterations           | 84          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.007924436 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.091      |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.952       |
# |    value_loss           | 0.00198     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1199         |
# |    iterations           | 85           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0070530977 |
# |    clip_fraction        | 0.0736       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0934      |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.0127      |
# |    std                  | 0.952        |
# |    value_loss           | 0.00172      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1199        |
# |    iterations           | 86          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.007561068 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0976     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.946       |
# |    value_loss           | 0.00272     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1197         |
# |    iterations           | 87           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0057093133 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.087       |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0114      |
# |    std                  | 0.942        |
# |    value_loss           | 0.00186      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1198        |
# |    iterations           | 88          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008282552 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0839     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.941       |
# |    value_loss           | 0.0032      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1198        |
# |    iterations           | 89          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.008009736 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.048      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.936       |
# |    value_loss           | 0.0017      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1197       |
# |    iterations           | 90         |
# |    time_elapsed         | 153        |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.00729219 |
# |    clip_fraction        | 0.0736     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0924    |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.0143    |
# |    std                  | 0.938      |
# |    value_loss           | 0.00183    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1197        |
# |    iterations           | 91          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.009036143 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.11       |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.933       |
# |    value_loss           | 0.00137     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1196         |
# |    iterations           | 92           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0076908255 |
# |    clip_fraction        | 0.0754       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0869      |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.0127      |
# |    std                  | 0.936        |
# |    value_loss           | 0.00256      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1195         |
# |    iterations           | 93           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0076037296 |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0758      |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0109      |
# |    std                  | 0.936        |
# |    value_loss           | 0.00162      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1194         |
# |    iterations           | 94           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0076767523 |
# |    clip_fraction        | 0.0685       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0768      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0137      |
# |    std                  | 0.932        |
# |    value_loss           | 0.00237      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1194        |
# |    iterations           | 95          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.007723501 |
# |    clip_fraction        | 0.0655      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.104      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.923       |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1193        |
# |    iterations           | 96          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.008202621 |
# |    clip_fraction        | 0.0817      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0875     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.927       |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1194        |
# |    iterations           | 97          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.007513397 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0736     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.921       |
# |    value_loss           | 0.00154     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1194        |
# |    iterations           | 98          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.010246526 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0943     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.923       |
# |    value_loss           | 0.00203     |
# -----------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 143.30%
# INFO:BacktesterRL:Buy & Hold Return: 32.68%
# INFO:BacktesterRL:Outperformance: 110.62%
# Generated 218 actions.
# Running Backtest...
#
# --- Strategy Performance ---
# Total Return (%): 143.3000
# Annual Return (%): 343.1200
# Sharpe Ratio: 4.5309
# Sortino Ratio: 9.6004
# Max Drawdown (%): -6.5500
# Calmar Ratio: 52.3516
# Win Rate (%): 62.2800
# Total Trades: 114.0000
# Final Value ($): 243298.4700

# %% [markdown]
# #### NEE - YES

# %%
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv('data/processed/NEE_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, "ppo_vecnormalize.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_16940\2806722139.py:6: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1584 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1202         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0041711084 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.14         |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0718       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00575     |
# |    std                  | 0.998        |
# |    value_loss           | 0.429        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1078       |
# |    iterations           | 3          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00581613 |
# |    clip_fraction        | 0.0517     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | 0.12       |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0271    |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0084    |
# |    std                  | 1.01       |
# |    value_loss           | 0.185      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1050         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0041181976 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0266      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00273     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00847     |
# |    std                  | 1.02         |
# |    value_loss           | 0.198        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1041        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008614667 |
# |    clip_fraction        | 0.099       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.009       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.00176    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 1.01        |
# |    value_loss           | 0.16        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1039         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0046576243 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0091       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0132      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00701     |
# |    std                  | 1.02         |
# |    value_loss           | 0.143        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1056        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007393282 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0452     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 1.01        |
# |    value_loss           | 0.108       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1064         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0062423963 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0469      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0947       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1069         |
# |    iterations           | 9            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0064632157 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.52         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0621      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0882       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1079        |
# |    iterations           | 10          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006908715 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0427     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 1           |
# |    value_loss           | 0.0672      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1081        |
# |    iterations           | 11          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007859848 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0622     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.995       |
# |    value_loss           | 0.0523      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 12           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0059099514 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0673      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 0.993        |
# |    value_loss           | 0.0461       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1073         |
# |    iterations           | 13           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0052576666 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0629      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0109      |
# |    std                  | 0.984        |
# |    value_loss           | 0.0414       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 14          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006589274 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0696     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.981       |
# |    value_loss           | 0.0319      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1077        |
# |    iterations           | 15          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005078219 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0706     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00896    |
# |    std                  | 0.977       |
# |    value_loss           | 0.0312      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 16          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.003911679 |
# |    clip_fraction        | 0.0501      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0703     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00831    |
# |    std                  | 0.975       |
# |    value_loss           | 0.0213      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1076        |
# |    iterations           | 17          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.004524909 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0641     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00935    |
# |    std                  | 0.972       |
# |    value_loss           | 0.0228      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1080        |
# |    iterations           | 18          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005093295 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0717     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.953       |
# |    value_loss           | 0.018       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1081         |
# |    iterations           | 19           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0069012856 |
# |    clip_fraction        | 0.0777       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0867      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0137      |
# |    std                  | 0.942        |
# |    value_loss           | 0.0169       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1079        |
# |    iterations           | 20          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005696566 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0862     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.943       |
# |    value_loss           | 0.0141      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 21           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0033336487 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0676      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00721     |
# |    std                  | 0.938        |
# |    value_loss           | 0.0136       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1083         |
# |    iterations           | 22           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0030044918 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0914      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00723     |
# |    std                  | 0.934        |
# |    value_loss           | 0.0116       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1086        |
# |    iterations           | 23          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.003968576 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.077      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00729    |
# |    std                  | 0.937       |
# |    value_loss           | 0.00956     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1089        |
# |    iterations           | 24          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006782884 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0772     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.938       |
# |    value_loss           | 0.00937     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1088        |
# |    iterations           | 25          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004410228 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0673     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00913    |
# |    std                  | 0.944       |
# |    value_loss           | 0.00807     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1088        |
# |    iterations           | 26          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005648777 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0733     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.943       |
# |    value_loss           | 0.00638     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1090        |
# |    iterations           | 27          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.005142331 |
# |    clip_fraction        | 0.0558      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0894     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.942       |
# |    value_loss           | 0.0056      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1091       |
# |    iterations           | 28         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.00386813 |
# |    clip_fraction        | 0.0351     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0903    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00765   |
# |    std                  | 0.95       |
# |    value_loss           | 0.00474    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 
|
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.919       |
# |    value_loss           | 0.0026      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1120         |
# |    iterations           | 54           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0056183427 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0804      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 0.918        |
# |    value_loss           | 0.00276      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1121       |
# |    iterations           | 55         |
# |    time_elapsed         | 100        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.00658982 |
# |    clip_fraction        | 0.0724     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0833    |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0133    |
# |    std                  | 0.919      |
# |    value_loss           | 0.0026     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1122         |
# |    iterations           | 56           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0045972397 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0761      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.0103      |
# |    std                  | 0.92         |
# |    value_loss           | 0.00212      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1122         |
# |    iterations           | 57           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0051017106 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0893      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.0112      |
# |    std                  | 0.917        |
# |    value_loss           | 0.00236      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1123        |
# |    iterations           | 58          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.007487707 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0908     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.919       |
# |    value_loss           | 0.00262     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1124         |
# |    iterations           | 59           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0060715186 |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0791      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0127      |
# |    std                  | 0.92         |
# |    value_loss           | 0.00203      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1124         |
# |    iterations           | 60           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0038987328 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0723      |
# ...
# |    iterations           | 80          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.005433593 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0798     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.922       |
# |    value_loss           | 0.00222     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1134         |
# |    iterations           | 81           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0066609825 |
# |    clip_fraction        | 0.0734       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0961      |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0137      |
# |    std                  | 0.928        |
# |    value_loss           | 0.00223      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1135        |
# |    iterations           | 82          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.006630061 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0815     |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.927       |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1135        |
# |    iterations           | 83          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.006621857 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0875     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.925       |
# |    value_loss           | 0.00241     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1136         |
# |    iterations           | 84           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0063154064 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0784      |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.928        |
# |    value_loss           | 0.00159      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1136         |
# |    iterations           | 85           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0075101857 |
# |    clip_fraction        | 0.0706       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0968      |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 0.926        |
# |    value_loss           | 0.00183      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1137       |
# |    iterations           | 86         |
# |    time_elapsed         | 154        |
# |    total_timesteps      | 176128     |
# | train/                  |            |
# |    approx_kl            | 0.00903545 |
# |    clip_fraction        | 0.0667     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0752    |
# |    n_updates            | 850        |
# |    policy_gradient_loss | -0.0149    |
# |    std                  | 0.915      |
# |    value_loss           | 0.00164    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 87          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.007711903 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0838     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.906       |
# |    value_loss           | 0.00116     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1138         |
# |    iterations           | 88           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0069787926 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0967      |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0129      |
# |    std                  | 0.896        |
# |    value_loss           | 0.002        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1138         |
# |    iterations           | 89           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0069965804 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0783      |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0135      |
# |    std                  | 0.897        |
# |    value_loss           | 0.00157      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 90          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.006304525 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0743     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.9         |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1139        |
# |    iterations           | 91          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.008029517 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0905     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.898       |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1140        |
# |    iterations           | 92          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.009225311 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0769     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.897       |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1140         |
# |    iterations           | 93           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0064601386 |
# |    clip_fraction        | 0.0726       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0789      |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0136      |
# |    std                  | 0.896        |
# |    value_loss           | 0.000865     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1140        |
# |    iterations           | 94          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.008418363 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0855     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.902       |
# |    value_loss           | 0.00114     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1141        |
# |    iterations           | 95          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.007862518 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0757     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.905       |
# |    value_loss           | 0.00101     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1142        |
# |    iterations           | 96          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.008359122 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0937     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.916       |
# |    value_loss           | 0.00118     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1142        |
# |    iterations           | 97          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.007377278 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0817     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.917       |
# |    value_loss           | 0.00113     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1143         |
# |    iterations           | 98           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0070897476 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0815      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.012       |
# |    std                  | 0.914        |
# |    value_loss           | 0.000795     |
# ------------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 188.10%
# INFO:BacktesterRL:Buy & Hold Return: 28.02%
# INFO:BacktesterRL:Outperformance: 160.08%
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# Generated 218 actions.
# Running Backtest...
#
# --- Strategy Performance ---
# Total Return (%): 188.1000
# Annual Return (%): 488.0400
# Sharpe Ratio: 5.7212
# Sortino Ratio: 11.6267
# Max Drawdown (%): -6.5800
# Calmar Ratio: 74.1300
# Win Rate (%): 67.1200
# Total Trades: 73.0000
# Final Value ($): 288095.6900

# %% [markdown]
# #### AGX 2022 - NO

# %%
# 1. Load Configuration
config = load_config("config/config.yaml")

# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv('data/processed/AGX_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, "ppo_vecnormalize.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_16940\1517525819.py:9: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1456 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1179         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0076814424 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00769     |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.125        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00843     |
# |    std                  | 1            |
# |    value_loss           | 0.589        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1098        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005405867 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.0546      |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.000954    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00936    |
# |    std                  | 1.01        |
# |    value_loss           | 0.237       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1079        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006942657 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -0.0311     |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.0526      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 1.01        |
# |    value_loss           | 0.246       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1059         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0075275367 |
# |    clip_fraction        | 0.0744       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0135       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 1.02         |
# |    value_loss           | 0.176        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1056         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0056108003 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.192        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0294      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00874     |
# |    std                  | 1.02         |
# |    value_loss           | 0.135        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1071        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005915831 |
# |    clip_fraction        | 0.0514      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.0784      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0135     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00864    |
# |    std                  | 1.02        |
# |    value_loss           | 0.152       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0082227755 |
# |    clip_fraction        | 0.0951       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.343        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0405      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0141      |
# |    std                  | 1.02         |
# |    value_loss           | 0.103        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1077        |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006917814 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0442     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 1.02        |
# |    value_loss           | 0.103       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1084         |
# |    iterations           | 10           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0061744554 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.447        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0588      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 1.02         |
# |    value_loss           | 0.0739       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1091        |
# |    iterations           | 11          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006049764 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.03       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00861    |
# |    std                  | 1.02        |
# |    value_loss           | 0.0648      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1096         |
# |    iterations           | 12           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0057522403 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.717        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0642      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0108      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0515       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1099         |
# |    iterations           | 13           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0049330215 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.77         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0461      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0083      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0445       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1099        |
# |    iterations           | 14          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006752567 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0733     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00918    |
# |    std                  | 1.01        |
# |    value_loss           | 0.0349      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1103         |
# |    iterations           | 15           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0048872046 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.84         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0652      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00923     |
# |    std                  | 1.01         |
# |    value_loss           | 0.0296       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1106         |
# |    iterations           | 16           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0036059325 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0731      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00707     |
# |    std                  | 1.02         |
# |    value_loss           | 0.0248       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1106         |
# |    iterations           | 17           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0068997326 |
# |    clip_fraction        | 0.0718       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0877      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0111      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0203       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1109         |
# |    iterations           | 18           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0058213947 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0763      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0108      |
# |    std                  | 1            |
# |    value_loss           | 0.0218       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 19           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0071341805 |
# |    clip_fraction        | 0.0781       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0599      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0118      |
# |    std                  | 0.994        |
# |    value_loss           | 0.0247       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 20          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004050159 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0718     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00653    |
# |    std                  | 0.988       |
# |    value_loss           | 0.0186      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1115         |
# |    iterations           | 21           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0049166726 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0718      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00977     |
# |    std                  | 0.992        |
# |    value_loss           | 0.0199       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1118        |
# |    iterations           | 22          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.006312589 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.098      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 1           |
# |    value_loss           | 0.0162      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1120         |
# |    iterations           | 23           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0054446985 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0782      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0093      |
# |    std                  | 0.985        |
# |    value_loss           | 0.0116       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1122        |
# |    iterations           | 24          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005746364 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0691     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00841    |
# |    std                  | 0.98        |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1123         |
# |    iterations           | 25           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0059865434 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0819      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0123      |
# |    std                  | 0.981        |
# |    value_loss           | 0.0171       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1125         |
# |    iterations           | 26           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0063102823 |
# |    clip_fraction        | 0.0506       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0818      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00939     |
# |    std                  | 0.979        |
# |    value_loss           | 0.0162       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1127        |
# |    iterations           | 27          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004149736 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0762     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.
|
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0812      |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.993        |
# |    value_loss           | 0.00322      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1163       |
# |    iterations           | 56         |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.00477191 |
# |    clip_fraction        | 0.0407     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0767    |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.00753   |
# |    std                  | 1.01       |
# |    value_loss           | 0.00348    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 57          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.005060834 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0651     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00879    |
# |    std                  | 1.01        |
# |    value_loss           | 0.00353     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1164         |
# |    iterations           | 58           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0052931597 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0784      |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00904     |
# |    std                  | 1.02         |
# |    value_loss           | 0.00369      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1165         |
# |    iterations           | 59           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0051296866 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.08        |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 1.02         |
# |    value_loss           | 0.00322      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1166         |
# |    iterations           | 60           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0043477667 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# ...
# |    iterations           | 80           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0058965553 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0955      |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.00989     |
# |    std                  | 1.03         |
# |    value_loss           | 0.002        |
# ------------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1177     |
# |    iterations           | 81       |
# |    time_elapsed         | 140      |
# |    total_timesteps      | 165888   |
# | train/                  |          |
# |    approx_kl            | 0.007995 |
# |    clip_fraction        | 0.0635   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.44    |
# |    explained_variance   | 0.992    |
# |    learning_rate        | 0.0002   |
# |    loss                 | -0.11    |
# |    n_updates            | 800      |
# |    policy_gradient_loss | -0.0129  |
# |    std                  | 1.02     |
# |    value_loss           | 0.00224  |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1178         |
# |    iterations           | 82           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0055770813 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0864      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00975     |
# |    std                  | 1.02         |
# |    value_loss           | 0.00336      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1178        |
# |    iterations           | 83          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.005598978 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.082      |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00865    |
# |    std                  | 1.02        |
# |    value_loss           | 0.005       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1179         |
# |    iterations           | 84           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0060797506 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0882      |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.0114      |
# |    std                  | 1.02         |
# |    value_loss           | 0.00242      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 85          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.005783352 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0829     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 1.02        |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 86          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.006313715 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0907     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 1.02        |
# |    value_loss           | 0.0021      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1181         |
# |    iterations           | 87           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0068588704 |
# |    clip_fraction        | 0.0644       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0954      |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0103      |
# |    std                  | 1.02         |
# |    value_loss           | 0.00277      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1181        |
# |    iterations           | 88          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.005790581 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.077      |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00998    |
# |    std                  | 1.02        |
# |    value_loss           | 0.00203     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1181         |
# |    iterations           | 89           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0064702975 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0975      |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 1.02         |
# |    value_loss           | 0.0021       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1182        |
# |    iterations           | 90          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.007642935 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0891     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 1.02        |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1182         |
# |    iterations           | 91           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0065430105 |
# |    clip_fraction        | 0.0756       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.08        |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0126      |
# |    std                  | 1.02         |
# |    value_loss           | 0.00172      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1182        |
# |    iterations           | 92          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.005726393 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0801     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.00987    |
# |    std                  | 1.02        |
# |    value_loss           | 0.00149     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1183        |
# |    iterations           | 93          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.006577306 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0826     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 1.02        |
# |    value_loss           | 0.00203     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1183        |
# |    iterations           | 94          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.007999368 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0913     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 1.03        |
# |    value_loss           | 0.00232     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1184         |
# |    iterations           | 95           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0073368475 |
# |    clip_fraction        | 0.0642       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0904      |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 1.03         |
# |    value_loss           | 0.00222      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1184         |
# |    iterations           | 96           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0051616216 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0826      |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 1.03         |
# |    value_loss           | 0.00196      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1185         |
# |    iterations           | 97           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0076547293 |
# |    clip_fraction        | 0.055        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0844      |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 1.03         |
# |    value_loss           | 0.00165      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1185         |
# |    iterations           | 98           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0064757415 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0853      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 1.03         |
# |    value_loss           | 0.00144      |
# ------------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 43.36%
# INFO:BacktesterRL:Buy & Hold Return: 123.31%
# INFO:BacktesterRL:Outperformance: -79.96%
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# Generated 218 actions.
# Running Backtest...
#
# --- Strategy Performance ---
# Total Return (%): 43.3600
# Annual Return (%): 82.7700
# Sharpe Ratio: 1.1629
# Sortino Ratio: 1.7377
# Max Drawdown (%): -35.8200
# Calmar Ratio: 2.3107
# Win Rate (%): 52.2400
# Total Trades: 67.0000
# Final Value ($): 143357.3400

# %% [markdown]
# #### AGX FULL - YES

# %%
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv('data/processed/AGX_processed.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, "ppo_vecnormalize.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_12196\1096160923.py:9: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2388 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2043         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0073090754 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0821       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0398       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00844     |
# |    std                  | 1.01         |
# |    value_loss           | 0.382        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1941        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006331234 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.0893      |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.00275    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00751    |
# |    std                  | 1.02        |
# |    value_loss           | 0.196       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1918        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006146361 |
# |    clip_fraction        | 0.0499      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.00994     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00864    |
# |    std                  | 1.03        |
# |    value_loss           | 0.189       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1878        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005909522 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.0826      |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.00776     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.03        |
# |    value_loss           | 0.23        |
# -----------------------------------------
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 726, Predictions: 665
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 749.78%
# INFO:BacktesterRL:Buy & Hold Return: 635.13%
# INFO:BacktesterRL:Outperformance: 114.65%
# Generated 665 actions.
# Running Backtest...
#
# --- Strategy Performance ---
# Total Return (%): 749.7800
# Annual Return (%): 223.6500
# Sharpe Ratio: 4.1127
# Sortino Ratio: 13.0749
# Max Drawdown (%): -9.1900
# Calmar Ratio: 24.3298
# Win Rate (%): 73.1600
# Total Trades: 380.0000
# Final Value ($): 849781.1200

# %% [markdown]
# #### BKH - NO

# %%
stock_symbol = "BKH"
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv(f'data/processed/{stock_symbol}_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, f"ppo_vecnormalize_{stock_symbol}.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_16940\1696278471.py:7: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# -----------------------------
# | time/              |      |
# |    fps             | 1657 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1331         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0030640177 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.366       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0151       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0046      |
# |    std                  | 1.02         |
# |    value_loss           | 0.278        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1162         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0067892373 |
# |    clip_fraction        | 0.0607       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.00765     |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0477      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00956     |
# |    std                  | 1.02         |
# |    value_loss           | 0.0982       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1136        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008325659 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -0.0951     |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.04       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 1.02        |
# |    value_loss           | 0.115       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1120        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005808875 |
# |    clip_fraction        | 0.0514      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -0.0274     |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0352     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0092     |
# |    std                  | 1.01        |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1131        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006191862 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0392     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 1.01        |
# |    value_loss           | 0.098       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1130         |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0072810324 |
# |    clip_fraction        | 0.0909       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.197        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0396      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0134      |
# |    std                  | 1.01         |
# |    value_loss           | 0.122        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1125         |
# |    iterations           | 8            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0055046417 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.337        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0469      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00837     |
# |    std                  | 1.01         |
# |    value_loss           | 0.0931       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1132        |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007066105 |
# |    clip_fraction        | 0.0733      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0576     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0698      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1143        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005309228 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0749     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0497      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1151        |
# |    iterations           | 11          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006247946 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0706     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.998       |
# |    value_loss           | 0.0358      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1158       |
# |    iterations           | 12         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00611631 |
# |    clip_fraction        | 0.0638     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.062     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.011     |
# |    std                  | 0.995      |
# |    value_loss           | 0.0393     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 13          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007478299 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.071      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.992       |
# |    value_loss           | 0.0283      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 14          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005111129 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0601     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00902    |
# |    std                  | 0.981       |
# |    value_loss           | 0.0266      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 
|
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0831     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.927       |
# |    value_loss           | 0.000565    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1145        |
# |    iterations           | 89          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.007385305 |
# |    clip_fraction        | 0.0615      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0805     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.932       |
# |    value_loss           | 0.000979    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1145        |
# |    iterations           | 90          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.005828741 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0942     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.939       |
# |    value_loss           | 0.000713    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1146         |
# |    iterations           | 91           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0068193506 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0924      |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0109      |
# |    std                  | 0.94         |
# |    value_loss           | 0.000783     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1146        |
# |    iterations           | 92          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.007176478 |
# |    clip_fraction        | 0.0669      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0811     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.934       |
# |    value_loss           | 0.000926    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1146        |
# |    iterations           | 93          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.005738964 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0616     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.934       |
# |    value_loss           | 0.001       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 94          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.006544707 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.064      |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00896    |
# |    std                  | 0.937       |
# |    value_loss           | 0.00198     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1147         |
# |    iterations           | 95           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0075092707 |
# |    clip_fraction        | 0.0768       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0908      |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0154      |
# |    std                  | 0.94         |
# |    value_loss           | 0.000949     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1147         |
# |    iterations           | 96           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0064620133 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.095       |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0146      |
# |    std                  | 0.946        |
# |    value_loss           | 0.000932     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1148        |
# |    iterations           | 97          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.006337519 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0902     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.954       |
# |    value_loss           | 0.00107     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1148         |
# |    iterations           | 98           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0105300695 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0879      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0133      |
# |    std                  | 0.959        |
# |    value_loss           | 0.00226      |
# ------------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# WARNING: Normalization stats not found. Model predictions may be garbage.
# Generated 218 actions.
# Running Backtest...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: -26.69%
# INFO:BacktesterRL:Buy & Hold Return: 31.05%
# INFO:BacktesterRL:Outperformance: -57.74%
# --- Strategy Performance ---
# Total Return (%): -26.6900
# Annual Return (%): -40.5400
# Sharpe Ratio: -2.0651
# Sortino Ratio: -2.7834
# Max Drawdown (%): -28.0700
# Calmar Ratio: -1.4445
# Win Rate (%): 2.3100
# Total Trades: 130.0000
# Final Value ($): 73308.9300

# %% [markdown]
# #### DUK - YES

# %%
stock_symbol = "DUK"
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv(f'data/processed/{stock_symbol}_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, f"ppo_vecnormalize_{stock_symbol}.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_36804\2521901854.py:7: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2308 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1916         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0038990625 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.00413      |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0696       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0051      |
# |    std                  | 1.01         |
# |    value_loss           | 0.494        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1817        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008302532 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0187     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.997       |
# |    value_loss           | 0.179       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1784         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0040545384 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.368        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00434     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00625     |
# |    std                  | 0.99         |
# |    value_loss           | 0.141        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1782        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006601205 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0369     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.989       |
# |    value_loss           | 0.0975      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1783         |
# |    iterations           | 6            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0072438354 |
# |    clip_fraction        | 0.0775       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.439        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0487      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0128      |
# |    std                  | 0.986        |
# |    value_loss           | 0.0892       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1778        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005291271 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0558     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00945    |
# |    std                  | 0.986       |
# |    value_loss           | 0.0764      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1776        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006947182 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0471     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.977       |
# |    value_loss           | 0.0708      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1775        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006139652 |
# |    clip_fraction        | 0.0644      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0708     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.973       |
# |    value_loss           | 0.0497      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1754         |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0069112936 |
# |    clip_fraction        | 0.0759       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0652      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0125      |
# |    std                  | 0.956        |
# |    value_loss           | 0.053        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1746         |
# |    iterations           | 11           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0054418244 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.64         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0658      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00911     |
# |    std                  | 0.953        |
# |    value_loss           | 0.0395       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1743        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004764674 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0663     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00845    |
# |    std                  | 0.945       |
# |    value_loss           | 0.0317      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1748        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.
|
# |    time_elapsed         | 45           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0046840995 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0815      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.868        |
# |    value_loss           | 0.00362      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1786        |
# |    iterations           | 41          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.003836588 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0744     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.873       |
# |    value_loss           | 0.00289     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1787         |
# |    iterations           | 42           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0051788497 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0815      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0111      |
# |    std                  | 0.87         |
# |    value_loss           | 0.00282      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1788         |
# |    iterations           | 43           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0070518386 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.075       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0138      |
# |    std                  | 0.87         |
# |    value_loss           | 0.00395      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1788         |
# |    iterations           | 44           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0050260955 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0696      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00911     |
# |    std                  | 0.871        |
# |    value_loss           | 0.00259      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1787         |
# |    iterations           | 45           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0045067677 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0871      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.867        |
# |    value_loss           | 0.00316      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1787         |
# |    iterations           | 46           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0057494338 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0684      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00907     |
# |    std                  | 0.873        |
# |    value_loss           | 0.00248      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1785         |
# |    iterations           | 47           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0054950905 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0793      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00925     |
# |    std                  | 0.873        |
# |    value_loss           | 0.0023       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1785        |
# |    iterations           | 48          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005131147 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0647     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.878       |
# |    value_loss           | 0.00215     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1787        |
# |    iterations           | 49          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004576175 |
# |    clip_fraction        | 0.0403      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0683     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00884    |
# |    std                  | 0.884       |
# |    value_loss           | 0.00376     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1789        |
# |    iterations           | 50          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004848321 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0846     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.886       |
# |    value_loss           | 0.00184     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1790        |
# |    iterations           | 51          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.005607406 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0743     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00963    |
# |    std                  | 0.885       |
# |    value_loss           | 0.00212     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1792         |
# |    iterations           | 52           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0055386107 |
# |    clip_fraction        | 0.0676       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.08        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.895        |
# |    value_loss           | 0.00215      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1792        |
# |    iterations           | 53          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.005921797 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.077      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.889       |
# |    value_loss           | 0.00232     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1792        |
# |    iterations           | 54          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.003806459 |
# |    clip_fraction        | 0.0371      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0854     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00969    |
# |    std                  | 0.886       |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1791       |
# |    iterations           | 55         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.00561932 |
# |    clip_fraction        | 0.0462     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0747    |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.00927   |
# |    std                  | 0.885      |
# |    value_loss           | 0.00252    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1791         |
# |    iterations           | 56           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0064511895 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0771      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.884        |
# |    value_loss           | 0.0019       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1792         |
# |    iterations           | 57           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0050881123 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0764      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.0108      |
# |    std                  | 0.881        |
# |    value_loss           | 0.00284      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1793        |
# |    iterations           | 58          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.005523921 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0709     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00951    |
# |    std                  | 0.886       |
# |    value_loss           | 0.00158     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1794         |
# |    iterations           | 59           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0065388437 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0653      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0127      |
# |    std                  | 0.886        |
# |    value_loss           | 0.00305      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1796         |
# |    iterations           | 60           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# ...
# |    time_elapsed         | 90       |
# |    total_timesteps      | 163840   |
# | train/                  |          |
# |    approx_kl            | 0.008662 |
# |    clip_fraction        | 0.0718   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.29    |
# |    explained_variance   | 0.998    |
# |    learning_rate        | 0.0002   |
# |    loss                 | -0.097   |
# |    n_updates            | 790      |
# |    policy_gradient_loss | -0.0147  |
# |    std                  | 0.875    |
# |    value_loss           | 0.00149  |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1800        |
# |    iterations           | 81          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.009039052 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0637     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.885       |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1799         |
# |    iterations           | 82           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0051942323 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0598      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0118      |
# |    std                  | 0.885        |
# |    value_loss           | 0.00189      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1799         |
# |    iterations           | 83           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0052397973 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.087       |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.891        |
# |    value_loss           | 0.00206      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1800         |
# |    iterations           | 84           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0071424246 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0708      |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.893        |
# |    value_loss           | 0.00229      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1800         |
# |    iterations           | 85           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0059823385 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0825      |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.89         |
# |    value_loss           | 0.00179      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1801         |
# |    iterations           | 86           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0057268655 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0869      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0109      |
# |    std                  | 0.896        |
# |    value_loss           | 0.00198      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1803        |
# |    iterations           | 87          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.005823233 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0817     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.886       |
# |    value_loss           | 0.00194     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1803        |
# |    iterations           | 88          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.009661689 |
# |    clip_fraction        | 0.0709      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0845     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.888       |
# |    value_loss           | 0.00461     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1803        |
# |    iterations           | 89          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.006203395 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0967     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.891       |
# |    value_loss           | 0.00175     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1802         |
# |    iterations           | 90           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0071146246 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.067       |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0141      |
# |    std                  | 0.9          |
# |    value_loss           | 0.00176      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1802        |
# |    iterations           | 91          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.007583953 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0785     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.895       |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1799       |
# |    iterations           | 92         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.00781149 |
# |    clip_fraction        | 0.071      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0869    |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.0135    |
# |    std                  | 0.894      |
# |    value_loss           | 0.00159    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1799         |
# |    iterations           | 93           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0075933877 |
# |    clip_fraction        | 0.0813       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.101       |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0132      |
# |    std                  | 0.895        |
# |    value_loss           | 0.00156      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1799        |
# |    iterations           | 94          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.004989058 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.09       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.889       |
# |    value_loss           | 0.00173     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1799         |
# |    iterations           | 95           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0057491157 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0884      |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0114      |
# |    std                  | 0.889        |
# |    value_loss           | 0.00202      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1800       |
# |    iterations           | 96         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.00767688 |
# |    clip_fraction        | 0.0763     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0975    |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.0154    |
# |    std                  | 0.882      |
# |    value_loss           | 0.0016     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1800         |
# |    iterations           | 97           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0059916712 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.101       |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0138      |
# |    std                  | 0.879        |
# |    value_loss           | 0.00186      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1799        |
# |    iterations           | 98          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.007029689 |
# |    clip_fraction        | 0.0726      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0837     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.875       |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 16.99%
# INFO:BacktesterRL:Buy & Hold Return: 19.81%
# INFO:BacktesterRL:Outperformance: -2.82%
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# WARNING: Normalization stats not found. Model predictions may be garbage.
# Generated 218 actions.
# Running Backtest...
#
# --- Strategy Performance ---
# Total Return (%): 16.9900
# Annual Return (%): 30.0500
# Sharpe Ratio: 1.4535
# Sortino Ratio: 2.1369
# Max Drawdown (%): -8.5400
# Calmar Ratio: 3.5209
# Win Rate (%): 100.0000
# Total Trades: 58.0000
# Final Value ($): 116992.6500

# %% [markdown]
# #### YORW - YES

# %%
stock_symbol = "YORW"
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv(f'data/processed/{stock_symbol}_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, f"ppo_vecnormalize_{stock_symbol}.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_36804\3214714451.py:7: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1894 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1417         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0050285477 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.039        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0053      |
# |    std                  | 1.01         |
# |    value_loss           | 0.379        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1294         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0058539137 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0917       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0463       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0082      |
# |    std                  | 1.01         |
# |    value_loss           | 0.257        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1246         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0053287772 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.197       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0234      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00745     |
# |    std                  | 1.02         |
# |    value_loss           | 0.157        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1202        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007610606 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0222     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 1.02        |
# |    value_loss           | 0.121       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1186         |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0072473856 |
# |    clip_fraction        | 0.084        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.298        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0522      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0134      |
# |    std                  | 1.02         |
# |    value_loss           | 0.111        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1185         |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0050295903 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.486        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0339      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0952       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1186         |
# |    iterations           | 8            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0045689866 |
# |    clip_fraction        | 0.0402       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.476        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0535      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00759     |
# |    std                  | 1.01         |
# |    value_loss           | 0.0843       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005559901 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0547     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0117     |
# |    std                  |

# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1220      |
# |    iterations           | 39        |
# |    time_elapsed         | 65        |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.0071539 |
# |    clip_fraction        | 0.076     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32     |
# |    explained_variance   | 0.992     |
# |    learning_rate        | 0.0002    |
# |    loss                 | -0.0757   |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -0.0143   |
# |    std                  | 0.908     |
# |    value_loss           | 0.00405   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1223        |
# |    iterations           | 40          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.003272518 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0739     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00836    |
# |    std                  | 0.912       |
# |    value_loss           | 0.00329     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1225         |
# |    iterations           | 41           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0055793263 |
# |    clip_fraction        | 0.0543       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0772      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0135      |
# |    std                  | 0.906        |
# |    value_loss           | 0.00327      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1229         |
# |    iterations           | 42           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0044600205 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0668      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.914        |
# |    value_loss           | 0.0042       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1232        |
# |    iterations           | 43          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.003757826 |
# |    clip_fraction        | 0.0267      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0728     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00842    |
# |    std                  | 0.914       |
# |    value_loss           | 0.00396     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1236         |
# |    iterations           | 44           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0044794874 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0781      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0103      |
# |    std                  | 0.911        |
# |    value_loss           | 0.0033       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1240        |
# |    iterations           | 45          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006042901 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.076      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.899       |
# |    value_loss           | 0.00344     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1243        |
# |    iterations           | 46          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006156412 |
# |    clip_fraction        | 0.0651      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.085      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.893       |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1246        |
# |    iterations           | 47          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005367323 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0845     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.897       |
# |    value_loss           | 0.00375     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1249        |
# |    iterations           | 48          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006678541 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0899     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.89        |
# |    value_loss           | 0.0035      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1252         |
# |    iterations           | 49           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0065322286 |
# |    clip_fraction        | 0.0582       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0953      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0143      |
# |    std                  | 0.889        |
# |    value_loss           | 0.00279      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1255         |
# |    iterations           | 50           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0050134906 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0818      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0103      |
# |    std                  | 0.89         |
# |    value_loss           | 0.00302      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1257         |
# |    iterations           | 51           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0048251236 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0863      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0111      |
# |    std                  | 0.896        |
# |    value_loss           | 0.0024       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1260         |
# |    iterations           | 52           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0044622384 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0753      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0117      |
# |    std                  | 0.894        |
# |    value_loss           | 0.00323      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1262        |
# |    iterations           | 53          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.005108734 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.072      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.889       |
# |    value_loss           | 0.00244     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1264         |
# |    iterations           | 54           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0069984104 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.079       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0146      |
# |    std                  | 0.876        |
# |    value_loss           | 0.00253      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1267        |
# |    iterations           | 55          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.004908084 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.073      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.877       |
# |    value_loss           | 0.00184     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1269        |
# |    iterations           | 56          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.006077024 |
# |    clip_fraction        | 0.0549      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0859     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.877       |
# |    value_loss           | 0.00228     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1271         |
# |    iterations           | 57           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0056497776 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0774      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.0119      |
# |    std                  | 0.877        |
# |    value_loss           | 0.00206      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1273        |
# |    iterations           | 58          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.007221367 |
# |    clip_fraction        | 0.056       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0969     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.867       |
# |    value_loss           | 0.00257     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1275        |
# |    iterations           | 59          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.008597948 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0838     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.868       |
# |    value_loss           | 0.00167     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1277         |
# |    iterations           | 60           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0075015724 |
# |    clip_fraction        | 0.0789       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# ...
# |    time_elapsed         | 125         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.008255963 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0739     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.869       |
# |    value_loss           | 0.0018      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1307         |
# |    iterations           | 81           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0068280306 |
# |    clip_fraction        | 0.0702       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0861      |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0153      |
# |    std                  | 0.865        |
# |    value_loss           | 0.0013       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1309         |
# |    iterations           | 82           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0075046704 |
# |    clip_fraction        | 0.0782       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0671      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0147      |
# |    std                  | 0.868        |
# |    value_loss           | 0.00173      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1310        |
# |    iterations           | 83          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.006705921 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0873     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.87        |
# |    value_loss           | 0.00148     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1311        |
# |    iterations           | 84          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.007739352 |
# |    clip_fraction        | 0.061       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0821     |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.868       |
# |    value_loss           | 0.000826    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1313         |
# |    iterations           | 85           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0070995623 |
# |    clip_fraction        | 0.0635       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0944      |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.0133      |
# |    std                  | 0.859        |
# |    value_loss           | 0.00133      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1314        |
# |    iterations           | 86          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.009256629 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0944     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.855       |
# |    value_loss           | 0.00141     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1315       |
# |    iterations           | 87         |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 178176     |
# | train/                  |            |
# |    approx_kl            | 0.00865498 |
# |    clip_fraction        | 0.0682     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0882    |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0137    |
# |    std                  | 0.855      |
# |    value_loss           | 0.0013     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1316         |
# |    iterations           | 88           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0077849547 |
# |    clip_fraction        | 0.0772       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0947      |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0178      |
# |    std                  | 0.851        |
# |    value_loss           | 0.00104      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1317        |
# |    iterations           | 89          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.007292399 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0926     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.847       |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 90          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.008768063 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0741     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.855       |
# |    value_loss           | 0.00127     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 91           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0073569734 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.077       |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0137      |
# |    std                  | 0.848        |
# |    value_loss           | 0.00139      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1321        |
# |    iterations           | 92          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.009971851 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0756     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.846       |
# |    value_loss           | 0.00117     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1322        |
# |    iterations           | 93          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.007823713 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0744     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.847       |
# |    value_loss           | 0.00163     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1323         |
# |    iterations           | 94           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0070251655 |
# |    clip_fraction        | 0.0745       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0946      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0161      |
# |    std                  | 0.846        |
# |    value_loss           | 0.0011       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1323        |
# |    iterations           | 95          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.009359501 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0947     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.845       |
# |    value_loss           | 0.00152     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1324        |
# |    iterations           | 96          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.007852418 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0796     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.845       |
# |    value_loss           | 0.000635    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1325        |
# |    iterations           | 97          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.008469894 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0673     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.845       |
# |    value_loss           | 0.00106     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 98          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.008463513 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0739     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.845       |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 1.31%
# INFO:BacktesterRL:Buy & Hold Return: 4.25%
# INFO:BacktesterRL:Outperformance: -2.94%
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# WARNING: Normalization stats not found. Model predictions may be garbage.
# Generated 218 actions.
# Running Backtest...
#
# --- Strategy Performance ---
# Total Return (%): 1.3100
# Annual Return (%): 2.2100
# Sharpe Ratio: 0.2088
# Sortino Ratio: 0.2985
# Max Drawdown (%): -15.6400
# Calmar Ratio: 0.1411
# Win Rate (%): 69.2300
# Total Trades: 117.0000
# Final Value ($): 101311.7700

# %% [markdown]
# #### PCG

# %%
stock_symbol = "PCG"
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv(f'data/processed/{stock_symbol}_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, f"ppo_vecnormalize_{stock_symbol}.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_36804\3656799877.py:7: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1833 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1452         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0046446966 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.233       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0807       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00547     |
# |    std                  | 1.01         |
# |    value_loss           | 0.411        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1394         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0060189543 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0279      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00943     |
# |    std                  | 1            |
# |    value_loss           | 0.117        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1353         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0046463134 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0255      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00639     |
# |    std                  | 1            |
# |    value_loss           | 0.109        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1325         |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0074782763 |
# |    clip_fraction        | 0.0779       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.00717      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0376      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0131      |
# |    std                  | 1            |
# |    value_loss           | 0.0913       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1317        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005257713 |
# |    clip_fraction        | 0.0591      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.023      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00946    |
# |    std                  | 0.998       |
# |    value_loss           | 0.102       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1306         |
# |    iterations           | 7            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0060289865 |
# |    clip_fraction        | 0.0614       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.
|
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1248        |
# |    iterations           | 34          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005352694 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0753     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.92        |
# |    value_loss           | 0.00489     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1248        |
# |    iterations           | 35          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004264632 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0897     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00907    |
# |    std                  | 0.926       |
# |    value_loss           | 0.00527     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1248        |
# |    iterations           | 36          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004833693 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0799     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.923       |
# |    value_loss           | 0.00496     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1248         |
# |    iterations           | 37           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0037406092 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0758      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00883     |
# |    std                  | 0.919        |
# |    value_loss           | 0.0044       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1249         |
# |    iterations           | 38           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0049053347 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0815      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00909     |
# |    std                  | 0.915        |
# |    value_loss           | 0.00434      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1255         |
# |    iterations           | 39           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0054566185 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0779      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0124      |
# |    std                  | 0.919        |
# |    value_loss           | 0.00496      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1264        |
# |    iterations           | 40          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006415231 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0642     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00864    |
# |    std                  | 0.917       |
# |    value_loss           | 0.00445     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1272        |
# |    iterations           | 41          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004854118 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0885     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.914       |
# |    value_loss           | 0.00449     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1281        |
# |    iterations           | 42          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004484074 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0765     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.907       |
# |    value_loss           | 0.00444     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1290         |
# |    iterations           | 43           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0051921783 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0823      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.906        |
# |    value_loss           | 0.00393      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1299        |
# |    iterations           | 44          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006684234 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0878     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.904       |
# |    value_loss           | 0.00384     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1308        |
# |    iterations           | 45          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004406889 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0788     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00892    |
# |    std                  | 0.902       |
# |    value_loss           | 0.00363     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1316         |
# |    iterations           | 46           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0059414036 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0775      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.91         |
# |    value_loss           | 0.00445      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1323        |
# |    iterations           | 47          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004931233 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0825     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00752    |
# |    std                  | 0.913       |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1328        |
# |    iterations           | 48          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005955953 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0796     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00956    |
# |    std                  | 0.912       |
# |    value_loss           | 0.003       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1335         |
# |    iterations           | 49           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0060315216 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.077       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.012       |
# |    std                  | 0.911        |
# |    value_loss           | 0.00359      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1342        |
# |    iterations           | 50          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006871894 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0734     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.919       |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1350         |
# |    iterations           | 51           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0072676577 |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0916      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0139      |
# |    std                  | 0.914        |
# |    value_loss           | 0.00342      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1357         |
# |    iterations           | 52           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0049570273 |
# |    clip_fraction        | 0.0376       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0812      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.913        |
# |    value_loss           | 0.00333      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1364        |
# |    iterations           | 53          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.005921173 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0889     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.911       |
# |    value_loss           | 0.00349     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1371        |
# |    iterations           | 54          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.005381967 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0728     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.909       |
# |    value_loss           | 0.00259     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1378       |
# |    iterations           | 55         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.00655704 |
# |    clip_fraction        | 0.055      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0852    |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0138    |
# |    std                  | 0.902      |
# |    value_loss           | 0.00271    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1384       |
# |    iterations           | 56         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.00720763 |
# |    clip_fraction        | 0.058      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0835    |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.0132    |
# |    std                  | 0.91       |
# |    value_loss           | 0.00306    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1391         |
# |    iterations           | 57           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0056773117 |
# |    clip_fraction        | 0.0577       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0663      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.906        |
# |    value_loss           | 0.00363      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1398         |
# |    iterations           | 58           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0057434365 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.085       |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.909        |
# |    value_loss           | 0.0033       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1404         |
# |    iterations           | 59           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0062309746 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0952      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0117      |
# |    std                  | 0.909        |
# |    value_loss           | 0.00307      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1410        |
# |    iterations           | 60          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.005508965 |
# |    clip_fraction        | 0.0499      |
# |    clip_range           | 0.2         |
# ...
# |    time_elapsed         | 108          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0068340637 |
# |    clip_fraction        | 0.0644       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0675      |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 0.914        |
# |    value_loss           | 0.00171      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1508         |
# |    iterations           | 81           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0066832793 |
# |    clip_fraction        | 0.0636       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0844      |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0129      |
# |    std                  | 0.918        |
# |    value_loss           | 0.00209      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1511         |
# |    iterations           | 82           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0077249636 |
# |    clip_fraction        | 0.0705       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0905      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.917        |
# |    value_loss           | 0.00187      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1515        |
# |    iterations           | 83          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.008295345 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0847     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.916       |
# |    value_loss           | 0.0023      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1518        |
# |    iterations           | 84          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.007119334 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0736     |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.913       |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1522         |
# |    iterations           | 85           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0063971975 |
# |    clip_fraction        | 0.0498       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0943      |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.0133      |
# |    std                  | 0.911        |
# |    value_loss           | 0.00189      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1525         |
# |    iterations           | 86           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0069006192 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0883      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0114      |
# |    std                  | 0.907        |
# |    value_loss           | 0.0024       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1529        |
# |    iterations           | 87          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.009757946 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0945     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.902       |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1532        |
# |    iterations           | 88          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.007911035 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0894     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.907       |
# |    value_loss           | 0.00272     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1535        |
# |    iterations           | 89          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.007368842 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0906     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.896       |
# |    value_loss           | 0.00154     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1539        |
# |    iterations           | 90          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.009450623 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.073      |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.899       |
# |    value_loss           | 0.00181     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1542        |
# |    iterations           | 91          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.007595281 |
# |    clip_fraction        | 0.0868      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0893     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.891       |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1545         |
# |    iterations           | 92           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0073594362 |
# |    clip_fraction        | 0.0718       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0816      |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.0114      |
# |    std                  | 0.895        |
# |    value_loss           | 0.00181      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1548        |
# |    iterations           | 93          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.006812839 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0916     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.901       |
# |    value_loss           | 0.00159     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1551        |
# |    iterations           | 94          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.008279884 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.091      |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.9         |
# |    value_loss           | 0.00153     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1554        |
# |    iterations           | 95          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.008546334 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0911     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.913       |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1557         |
# |    iterations           | 96           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0072553284 |
# |    clip_fraction        | 0.0744       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.102       |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0145      |
# |    std                  | 0.916        |
# |    value_loss           | 0.00151      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1561       |
# |    iterations           | 97         |
# |    time_elapsed         | 127        |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.00839606 |
# |    clip_fraction        | 0.0702     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0875    |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.0137    |
# |    std                  | 0.91       |
# |    value_loss           | 0.00174    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1564        |
# |    iterations           | 98          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.008570608 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.098      |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.91        |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 1.67%
# INFO:BacktesterRL:Buy & Hold Return: -7.38%
# INFO:BacktesterRL:Outperformance: 9.06%
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# WARNING: Normalization stats not found. Model predictions may be garbage.
# Generated 218 actions.
# Running Backtest...
#
# --- Strategy Performance ---
# Total Return (%): 1.6700
# Annual Return (%): 2.8200
# Sharpe Ratio: 0.2358
# Sortino Ratio: 0.3283
# Max Drawdown (%): -20.8800
# Calmar Ratio: 0.1350
# Win Rate (%): 75.6100
# Total Trades: 123.0000
# Final Value ($): 101674.5600

# %% [markdown]
# #### CNP

# %%
stock_symbol = "CNP"
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv(f'data/processed/{stock_symbol}_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, f"ppo_vecnormalize_{stock_symbol}.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_36804\2430291878.py:7: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2517 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2135         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0064608157 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0489       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0398       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00838     |
# |    std                  | 1.01         |
# |    value_loss           | 0.294        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2023         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0050909286 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0309      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00938     |
# |    std                  | 1            |
# |    value_loss           | 0.172        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1972         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0059257243 |
# |    clip_fraction        | 0.052        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0321      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00971     |
# |    std                  | 1.01         |
# |    value_loss           | 0.109        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1936        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008337669 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0361     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 1.02        |
# |    value_loss           | 0.128       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1921         |
# |    iterations           | 6            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0069746533 |
# |    clip_fraction        | 0.0736       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0608      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0141      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0911       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1903         |
# |    iterations           | 7            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0066575785 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0559      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0346      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00996     |
# |    std                  | 1.01         |
# |    value_loss           | 0.105        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1893        |
# |    iterations           | 8           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008142533 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.049       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0629     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 1.02        |
# |    value_loss           | 0.0684      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1891        |
# |    iterations           | 9           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004954353 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0686     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0625      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1889        |
# |    iterations           | 10          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004891397 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0658     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.993       |
# |    value_loss           | 0.0568      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1886         |
# |    iterations           | 11           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0066486774 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.555        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0658      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0125      |
# |    std                  | 0.992        |
# |    value_loss           | 0.0412       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1889         |
# |    iterations           | 12           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0065572103 |
# |    clip_fraction        | 0.0776       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.704        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0717      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0136      |
# |    std                  | 0.987        |
# |    value_loss           | 0.0387       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1878        |
# |    iterations           | 13          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006348187 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0849     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.983       |
# |    value_loss           | 0.0334      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1878        |
# |    iterations           | 14          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007141565 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0817     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.98        |
# |    value_loss           | 0.0293      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1878        |
# |    iterations           | 15          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005199496 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0721     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00838    |
# |    std                  | 0.977       |
# |    value_loss           | 0.0265      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1877        |
# |    iterations           | 16          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004946397 |
# |    clip_fraction        | 0.049       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.075      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.964       |
# |    value_loss           | 0.0216      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1876         |
# |    iterations           | 17           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0045929686 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0741      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00907     |
# |    std                  | 0.959        |
# |    value_loss           | 0.0157       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1880        |
# |    iterations           | 18          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006340242 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0698     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.959       |
# |    value_loss           | 0.0157      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1881         |
# |    iterations           | 19           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0061612437 |
# |    clip_fraction        | 0.0673       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0906      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 0.963        |
# |    value_loss           | 0.0138       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1883        |
# |    iterations           | 20          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006062528 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.069      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.955       |
# |    value_loss           | 0.0127      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1885        |
# |    iterations           | 21          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004994884 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0636     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.943       |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1885       |
# |    iterations           | 22         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00669802 |
# |    clip_fraction        | 0.0796     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0871    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.013     |
# |    std                  | 0.939      |
# |    value_loss           | 0.00935    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1885        |
# |    iterations           | 23          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005152977 |
# |    clip_fraction        | 0.0418      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0733     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00978    |
# |    std                  | 0.943       |
# |    value_loss           | 0.00869     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1885         |
# |    iterations           | 24           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0068055727 |
# |    clip_fraction        | 0.0738       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0903      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0139      |
# |    std                  | 0.949        |
# |    value_loss           | 0.0096       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1886         |
# |    iterations           | 25           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0046575735 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0698      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00887     |
# |    std                  | 0.949        |
# |    value_loss           | 0.0075       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1887         |
# |    iterations           | 26           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0050791805 |
# |    clip_fraction        | 0.0549       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0764      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 0.939        |
# |    value_loss           | 0.00654      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1888        |
# |    iterations           | 27          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004216135 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0791     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0085     |
# |    std                  | 0.939       |
# |    value_loss           | 0.00663     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1889        |
# |    iterations           | 28          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004407458 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0933     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.938       |
# |    value_loss           | 0.00686     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1889        |
# |    iterations           | 29          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004222084 |
# |    clip_fraction        | 0.0369      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0893     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00994    |
# |    std                  | 0.936       |
# |    value_loss           | 0.00509     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1890         |
# |    iterations           | 30           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0042059473 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0832      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00848     |
# |    std                  | 0.935        |
# |    value_loss           | 0.0053       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1890         |
# |    iterations           | 31           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0052946554 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0844      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00947     |
# |    std                  | 0.938        |
# |    value_loss           | 0.00454      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1891        |
# |    iterations           | 32          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005171084 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0694     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.937       |
# |    value_loss           | 0.00502     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1892        |
# |    iterations           | 33          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004266315 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0885     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00978    |
# |    std                  | 0.945       |
# |    value_loss           | 0.00459     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1891         |
# |    iterations           | 34           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0041900976 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0924      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 0.951        |
# |    value_loss           | 0.00377      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1892        |
# |    iterations           | 35          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004009966 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0826     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00774    |
# |    std                  | 0.949       |
# |    value_loss           | 0.00566     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1890         |
# |    iterations           | 36           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0049618063 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0805      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00931     |
# |    std                  | 0.948        |
# |    value_loss           | 0.00371      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1889         |
# |    iterations           | 37           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0051022572 |
# |    clip_fraction        | 0.0413       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0864      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.94         |
# |    value_loss           | 0.00505      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1889         |
# |    iterations           | 38           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0073170653 |
# |    clip_fraction        | 0.0726       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0868      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0137      |
# |    std                  | 0.933        |
# |    value_loss           | 0.00359      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1889        |
# |    iterations           | 39          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005202556 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0863     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.93        |
# |    value_loss           | 0.00385     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1889         |
# |    iterations           | 40           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0067084157 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0718      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0135      |
# |    std                  | 0.928        |
# |    value_loss           | 0.0036       |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1889      |
# |    iterations           | 41        |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.0047554 |
# |    clip_fraction        | 0.0479    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.34     |
# |    explained_variance   | 0.991     |
# |    learning_rate        | 0.0002    |
# |    loss                 | -0.0871   |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.0103   |
# |    std                  | 0.927     |
# |    value_loss           | 0.00349   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1890        |
# |    iterations           | 42          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006515415 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0941     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.927       |
# |    value_loss           | 0.00405     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1889        |
# |    iterations           | 43          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006659981 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0851     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.929       |
# |    value_loss           | 0.0038      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1888         |
# |    iterations           | 44           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0050811525 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0859      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.931        |
# |    value_loss           | 0.00299      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1889        |
# |    iterations           | 45          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004992773 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0578     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00947    |
# |    std                  | 0.926       |
# |    value_loss           | 0.00241     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1889         |
# |    iterations           | 46           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0057348534 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0776      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.928        |
# |    value_loss           | 0.00246      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1890        |
# |    iterations           | 47          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004221438 |
# |    clip_fraction        | 0.0285      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0805     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00905    |
# |    std                  | 0.928       |
# |    value_loss           | 0.00248     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1889         |
# |    iterations           | 48           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0063544223 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0919      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.939        |
# |    value_loss           | 0.00366      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1890        |
# |    iterations           | 49          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005098257 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0811     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.942       |
# |    value_loss           | 0.00364     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1891        |
# |    iterations           | 50          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006930677 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0826     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.943       |
# |    value_loss           | 0.00263     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1891       |
# |    iterations           | 51         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.00568399 |
# |    clip_fraction        | 0.0482     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0973    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0126    |
# |    std                  | 0.948      |
# |    value_loss           | 0.00414    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1891         |
# |    iterations           | 52           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0049557267 |
# |    clip_fraction        | 0.0534       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.066       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0129      |
# |    std                  | 0.949        |
# |    value_loss           | 0.0028       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1891         |
# |    iterations           | 53           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0072391145 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0868      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0128      |
# |    std                  | 0.954        |
# |    value_loss           | 0.00292      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1890         |
# |    iterations           | 54           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0064439937 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0738      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0128      |
# |    std                  | 0.958        |
# |    value_loss           | 0.00208      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1891         |
# |    iterations           | 55           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0073401583 |
# |    clip_fraction        | 0.0608       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0815      |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.0156      |
# |    std                  | 0.964        |
# |    value_loss           | 0.00434      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1892        |
# |    iterations           | 56          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.004787065 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0767     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.956       |
# |    value_loss           | 0.00272     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1893         |
# |    iterations           | 57           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0045409063 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0801      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00879     |
# |    std                  | 0.959        |
# |    value_loss           | 0.00299      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1892        |
# |    iterations           | 58          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.006690441 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0863     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.957       |
# |    value_loss           | 0.00225     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1893         |
# |    iterations           | 59           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0065172045 |
# |    clip_fraction        | 0.0611       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.088       |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0135      |
# |    std                  | 0.953        |
# |    value_loss           | 0.00334      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1893         |
# |    iterations           | 60           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0067949938 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.993        |
# ...
# |    iterations           | 80          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.006938868 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0988     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.953       |
# |    value_loss           | 0.00288     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1898        |
# |    iterations           | 81          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.005860137 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0737     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.952       |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1898        |
# |    iterations           | 82          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.007940644 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0905     |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.948       |
# |    value_loss           | 0.00239     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1898        |
# |    iterations           | 83          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.006787735 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0848     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.946       |
# |    value_loss           | 0.00288     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1898         |
# |    iterations           | 84           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0069204066 |
# |    clip_fraction        | 0.0577       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0858      |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.0142      |
# |    std                  | 0.934        |
# |    value_loss           | 0.00175      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 85          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.009288097 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0718     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.929       |
# |    value_loss           | 0.00153     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1899         |
# |    iterations           | 86           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0067083263 |
# |    clip_fraction        | 0.0636       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0852      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0125      |
# |    std                  | 0.931        |
# |    value_loss           | 0.0018       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 87          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.007601167 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0735     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.935       |
# |    value_loss           | 0.00265     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1899         |
# |    iterations           | 88           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0068060337 |
# |    clip_fraction        | 0.0747       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0873      |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0131      |
# |    std                  | 0.934        |
# |    value_loss           | 0.00216      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 89          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.006655261 |
# |    clip_fraction        | 0.0624      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0707     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.935       |
# |    value_loss           | 0.00225     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 90          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.009568032 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0989     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.93        |
# |    value_loss           | 0.00132     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1899         |
# |    iterations           | 91           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0059901536 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0879      |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.932        |
# |    value_loss           | 0.00105      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1899         |
# |    iterations           | 92           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0067668296 |
# |    clip_fraction        | 0.0644       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0909      |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.0149      |
# |    std                  | 0.943        |
# |    value_loss           | 0.00177      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 93          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.007550217 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0966     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.947       |
# |    value_loss           | 0.001       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1898        |
# |    iterations           | 94          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.007286076 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0604     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.951       |
# |    value_loss           | 0.00185     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1897       |
# |    iterations           | 95         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.00828219 |
# |    clip_fraction        | 0.0763     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0854    |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0137    |
# |    std                  | 0.944      |
# |    value_loss           | 0.00231    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1897        |
# |    iterations           | 96          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.010300674 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0906     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.937       |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1897        |
# |    iterations           | 97          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.008670138 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0926     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.932       |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1896        |
# |    iterations           | 98          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.008880845 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.108      |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 0.926       |
# |    value_loss           | 0.00178     |
# -----------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 7.65%
# INFO:BacktesterRL:Buy & Hold Return: 29.90%
# INFO:BacktesterRL:Outperformance: -22.25%
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# WARNING: Normalization stats not found. Model predictions may be garbage.
# Generated 218 actions.
# Running Backtest...
#
# --- Strategy Performance ---
# Total Return (%): 7.6500
# Annual Return (%): 13.1400
# Sharpe Ratio: 1.4816
# Sortino Ratio: 2.2146
# Max Drawdown (%): -3.7900
# Calmar Ratio: 3.4628
# Win Rate (%): 82.7900
# Total Trades: 122.0000
# Final Value ($): 107652.8900

# %% [markdown]
# #### ABC

# %%
 

stock_symbol = "XEL"
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv(f'data/processed/{stock_symbol}_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training PPO Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_ppo(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = PPO.load(os.path.join(save_path, "ppo_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, f"ppo_vecnormalize_{stock_symbol}.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_48232\1389244196.py:7: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
# Data loaded successfully.
# Training PPO Agent...
# Using cpu device
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# -----------------------------
# | time/              |      |
# |    fps             | 2211 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1923         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0030308678 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.228       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.1          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00353     |
# |    std                  | 1.01         |
# |    value_loss           | 0.615        |
# ------------------------------------------
