# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#from src.data.data_collector import DataCollector
from src.models.model_trainer_rl_v2_2_buyhold import ModelTrainerRL, TradingEnvRL
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from src.models.backtester import PortfolioBacktester, PortfolioBacktesterRL
from src.utils.config_loader import load_config


config = load_config("config/config.yaml")
# Out:
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:32: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_format is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_format instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:33: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_width is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_width instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:34: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_height is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_height instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:35: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_scale is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_scale instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:133: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:141: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.plotlyjs is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.plotlyjs instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:147: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.

# %% [markdown]
# ## V2.2 PPO Agent

# %% [markdown]
# ### Function

# %%
def run_ppo_trading_pipeline(stock_symbol, config, year='2022', save_path="models/", show_plot=True):
    """
    Complete PPO trading pipeline: load data, train model, generate predictions, and backtest.
    
    Parameters:
    -----------
    stock_symbol : str
        Stock ticker symbol (e.g., 'CNP', 'MDU')
    config : dict
        Configuration dictionary loaded from config.yaml
    year : str, optional
        Year for data file selection (default: '2022')
    save_path : str, optional
        Directory to save/load models (default: 'models/')
    show_plot : bool, optional
        Whether to display the portfolio plot (default: True)
    
    Returns:
    --------
    tuple : (portfolio, metrics, actions)
        - portfolio: VectorBT portfolio object
        - metrics: Dictionary of performance metrics
        - actions: Array of predicted actions
    """
    # 1. Load Data
    try:
        data = pd.read_csv(f'data/processed/{stock_symbol}_processed_{year}.csv')
        if 'Date' in data.columns:
            data['Date'] = pd.to_datetime(data['Date'])
            data.set_index('Date', inplace=True)
        print(f"Data loaded successfully for {stock_symbol}.")
    except FileNotFoundError:
        print(f"Error: Data file not found for {stock_symbol}. Check path.")
        sys.exit()
    
    # 2. Split Train/Test
    split_idx = int(len(data) * 0.7)
    train_df = data.iloc[:split_idx]
    test_df = data.iloc[split_idx:]
    
    # 3. Training Phase
    print(f"Training PPO Agent for {stock_symbol}...")
    trainer = ModelTrainerRL(config['reinforcement_learning'])
    env_params = config['reinforcement_learning']['environment']
    
    env_train = TradingEnvRL(
        train_df, 
        initial_balance=env_params.get('initial_balance', 10000),
        commission=env_params.get('commission', 0.001),
        lookback_window=env_params.get('lookback_window', 30),
        reward_func='profit'
    )
    
    result = trainer.train_ppo(env_train)
    trainer.save_models(save_path)
    print("Training Complete. Models saved.")
    
    # 4. Inference Phase
    print("Generating Agent Predictions on Test Data...")
    model = PPO.load(os.path.join(save_path, "ppo_model"))
    
    env_test = TradingEnvRL(
        test_df, 
        initial_balance=env_params.get('initial_balance', 100000),
        commission=env_params.get('commission', 0.001),
        lookback_window=env_params.get('lookback_window', 30),
        reward_func='profit' 
    )
    
    vec_env_test = DummyVecEnv([lambda: env_test])
    
    norm_path = os.path.join(save_path, "ppo_vecnormalize.pkl")
    if os.path.exists(norm_path):
        vec_env_test = VecNormalize.load(norm_path, vec_env_test)
        vec_env_test.training = False
        vec_env_test.norm_reward = False
    else:
        print("WARNING: Normalization stats not found. Model predictions may be garbage.")
    
    obs = vec_env_test.reset()
    done = [False]
    actions = []
    
    while not done[0]:
        action, _ = model.predict(obs, deterministic=True)
        actions.append(action[0])
        obs, _, done, _ = vec_env_test.step(action)
    
    print(f"Generated {len(actions)} actions.")
    
    # 5. Backtesting Phase
    print("Running Backtest...")
    backtester = PortfolioBacktesterRL(env_params)
    
    portfolio = backtester.run_backtest(
        price_data=test_df['close'], 
        predicted_weights=np.array(actions).flatten(),
        lookback_window=env_params.get('lookback_window', 30)
    )
    
    comparison = backtester.compare_with_buy_and_hold_rl()
    metrics = backtester.get_performance_metrics()
    
    print(f"\n--- Strategy Performance for {stock_symbol} ---")
    for k, v in metrics.items():
        print(f"{k}: {v:.4f}")
    
    if show_plot:
        portfolio.plot().show()
        # Print trade statistics
        trades = portfolio.trades.records_readable
        print(f"\n--- Trade Statistics for {stock_symbol} ---")
        print(f"Total number of trades: {len(trades)}")
        print("\nTrade Direction Counts:")
        print(trades['Direction'].value_counts())

        # Analyze trade outcomes
        if 'PnL' in trades.columns:
                profitable_trades = trades[trades['PnL'] > 0]
                loss_trades = trades[trades['PnL'] < 0]
                
                print(f"\n--- Trade Outcomes ---")
                print(f"Number of profitable exits: {len(profitable_trades)}")
                print(f"Number of loss exits (cut loss): {len(loss_trades)}")
                print(f"Win rate: {len(profitable_trades) / len(trades) * 100:.2f}%")
                print(f"Average profit per winning trade: ${profitable_trades['PnL'].mean():.2f}" if len(profitable_trades) > 0 else "No profitable trades")
                print(f"Average loss per losing trade: ${loss_trades['PnL'].mean():.2f}" if len(loss_trades) > 0 else "No losing trades")
            


    
    return portfolio, metrics, np.array(actions).flatten()

# %%
# ## Single stock
# stock_symbol = "CNP"
# portfolio, metrics, actions = run_ppo_trading_pipeline(stock_symbol, config)

# %%
# # portfolio.trades.records_readable
# # Print trade statistics
# trades = portfolio.trades.records_readable
# print(f"\n--- Trade Statistics for abc ---")
# print(f"Total number of trades: {len(trades)}")
# print("\nTrade Direction Counts:")
# print(trades['Direction'].value_counts())

# # Analyze trade outcomes
# if 'PnL' in trades.columns:
#         profitable_trades = trades[trades['PnL'] > 0]
#         loss_trades = trades[trades['PnL'] < 0]
        
#         print(f"\n--- Trade Outcomes ---")
#         print(f"Number of profitable exits: {len(profitable_trades)}")
#         print(f"Number of loss exits (cut loss): {len(loss_trades)}")
#         print(f"Win rate: {len(profitable_trades) / len(trades) * 100:.2f}%")
#         print(f"Average profit per winning trade: ${profitable_trades['PnL'].mean():.2f}" if len(profitable_trades) > 0 else "No profitable trades")
#         print(f"Average loss per losing trade: ${loss_trades['PnL'].mean():.2f}" if len(loss_trades) > 0 else "No losing trades")

# %%
# Multiple stocks in a loop
stocks = ["AAPL", "AMZN", "TSLA", "BAC","MDU", "CWCO", "NEE", "DUK"]
results = {}

for stock in stocks:
    print(f"\n{'='*60}")
    print(f"Processing {stock}")
    print(f"{'='*60}")
    portfolio, metrics, actions = run_ppo_trading_pipeline(
        stock_symbol=stock, 
        config=config,
        show_plot=True  # Don't show plots in loop
    )
    results[stock] = {'portfolio': portfolio, 'metrics': metrics, 'actions': actions}
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_36288\1970358808.py:29: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2_buyhold:Training PPO...
# ============================================================
# Processing AAPL
# ============================================================
# Data loaded successfully for AAPL.
# Training PPO Agent for AAPL...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2381 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2037         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0040051187 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.00198      |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0664       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00313     |
# |    std                  | 1.01         |
# |    value_loss           | 0.368        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1684         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0069092903 |
# |    clip_fraction        | 0.0633       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.448        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0187      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00881     |
# |    std                  | 1.01         |
# |    value_loss           | 0.137        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1513       |
# |    iterations           | 4          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00619354 |
# |    clip_fraction        | 0.0568     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | 0.362      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0176    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00891   |
# |    std                  | 1.01       |
# |    value_loss           | 0.164      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1429        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006525492 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.264       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.00157    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 1.02        |
# |    value_loss           | 0.171       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 6            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0068507865 |
# |    clip_fraction        | 0.0727       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.293        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00544     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 1.02         |
# |    value_loss           | 0.15         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1305        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006185454 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0615     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 1.01        |
# |    value_loss           | 0.114       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1268        |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007380753 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0467     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 1.02        |
# |    value_loss           | 0.0705      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1259         |
# |    iterations           | 9            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0065886327 |
# |    clip_fraction        | 0.0877       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0601      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.013       |
# |    std                  | 1.01         |
# |    value_loss           | 0.0716       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1260         |
# |    iterations           | 10           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0051201526 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.842        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0645      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0094      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0589       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1256        |
# |    iterations           | 11          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006737512 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0679     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0431      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1240         |
# |    iterations           | 12           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0053824466 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0573      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0486       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1235        |
# |    iterations           | 13          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006017602 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0598     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 1           |
# |    value_loss           | 0.0331      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 14          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005595896 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0897     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.999       |
# |    value_loss           | 0.0323      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1233        |
# |    iterations           | 15          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005916148 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0694     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.986       |
# |    value_loss           | 0.0242      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1228         |
# |    iterations           | 16           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0068492647 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.078       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0109      |
# |    std                  | 0.992        |
# |    value_loss           | 0.0239       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1210        |
# |    iterations           | 17          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005664419 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0914     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.988       |
# |    value_loss           | 0.0182      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1201        |
# |    iterations           | 18          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004451486 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0797     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00852    |
# |    std                  | 0.989       |
# |    value_loss           | 0.016       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1203         |
# |    iterations           | 19           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0065145385 |
# |    clip_fraction        | 0.0582       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0719      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.977        |
# |    value_loss           | 0.018        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 20           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0057364563 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0839      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00965     |
# |    std                  | 0.971        |
# |    value_loss           | 0.0147       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1198        |
# |    iterations           | 21          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004577785 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0846     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.97        |
# |    value_loss           | 0.0157      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1199         |
# |    iterations           | 22           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0033578782 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0774      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00811     |
# |    std                  | 0.973        |
# |    value_loss           | 0.00907      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1198         |
# |    iterations           | 23           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0062836437 |
# |    clip_fraction        | 0.0607       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0855      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.966        |
# |    value_loss           | 0.0118       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1197        |
# |    iterations           | 24          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004779776 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0544     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00978    |
# |    std                  | 0.963       |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1198        |
# |    iterations           | 25          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004312088 |
# |    clip_fraction        | 0.0363      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0909     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0076     |
# |    std                  | 0.963       |
# |    value_loss           | 0.00831     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1201         |
# |    iterations           | 26           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0038690711 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0699      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.007       |
# |    std                  | 0.963        |
# |    value_loss           | 0.00969      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1200        |
# |    iterations           | 27          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.005109388 |
# |    clip_fraction        | 0.0582      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0846     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0099     |
# |    std                  | 0.971       |
# |    value_loss           | 0.00674     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 28           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0062287143 |
# |    clip_fraction        | 0.0447       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0662      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00905     |
# |    std                  | 0.967        |
# |    value_loss           | 0.00605      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1208        |
# |    iterations           | 29          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008387521 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0579     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.96        |
# |    value_loss           | 0.0071      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1211        |
# |    iterations           | 30          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005160467 |
# |    clip_fraction        | 0.0484      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.081      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00957    |
# |    std                  | 0.953       |
# |    value_loss           | 0.0053      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 31          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005804414 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0917     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.942       |
# |    value_loss           | 0.00523     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 32           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0062009534 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0827      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0103      |
# |    std                  | 0.946        |
# |    value_loss           | 0.00513      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1219         |
# |    iterations           | 33           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0048583895 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0659      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00918     |
# |    std                  | 0.932        |
# |    value_loss           | 0.00476      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1221        |
# |    iterations           | 34          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006651994 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0628     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.928       |
# |    value_loss           | 0.00453     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1222        |
# |    iterations           | 35          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004791468 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0705     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00922    |
# |    std                  | 0.931       |
# |    value_loss           | 0.00547     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1224         |
# |    iterations           | 36           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0041786954 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0743      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00854     |
# |    std                  | 0.929        |
# |    value_loss           | 0.00474      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1225        |
# |    iterations           | 37          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005312635 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0765     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.929       |
# |    value_loss           | 0.00467     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1228         |
# |    iterations           | 38           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0057639997 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0681      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.93         |
# |    value_loss           | 0.00374      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1229         |
# |    iterations           | 39           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0042899298 |
# |    clip_fraction        | 0.047        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0777      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.934        |
# |    value_loss           | 0.00454      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 40          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005575055 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0639     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.941       |
# |    value_loss           | 0.00572     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1232        |
# |    iterations           | 41          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004862736 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0709     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.937       |
# |    value_loss           | 0.00394     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1221         |
# |    iterations           | 42           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0043750126 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0843      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00928     |
# |    std                  | 0.937        |
# |    value_loss           | 0.00545      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1215         |
# |    iterations           | 43           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0061332877 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0986      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0112      |
# |    std                  | 0.932        |
# |    value_loss           | 0.00392      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 44           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0070507703 |
# |    clip_fraction        | 0.0681       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0825      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0139      |
# |    std                  | 0.928        |
# |    value_loss           | 0.00321      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1219         |
# |    iterations           | 45           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0042851456 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0764      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00905     |
# |    std                  | 0.927        |
# |    value_loss           | 0.00374      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1221        |
# |    iterations           | 46          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005668825 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0731     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.927       |
# |    value_loss           | 0.00298     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1222        |
# |    iterations           | 47          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005003832 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0719     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00907    |
# |    std                  | 0.919       |
# |    value_loss           | 0.00386     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1224       |
# |    iterations           | 48         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00429568 |
# |    clip_fraction        | 0.0384     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0837    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0101    |
# |    std                  | 0.914      |
# |    value_loss           | 0.00417    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1226       |
# |    iterations           | 49         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.00481469 |
# |    clip_fraction        | 0.0297     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0746    |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00952   |
# |    std                  | 0.917      |
# |    value_loss           | 0.00366    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1227        |
# |    iterations           | 50          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004969377 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0885     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.911       |
# |    value_loss           | 0.00247     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1229       |
# |    iterations           | 51         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.00435861 |
# |    clip_fraction        | 0.0325     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0937    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0106    |
# |    std                  | 0.904      |
# |    value_loss           | 0.00314    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1230         |
# |    iterations           | 52           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0052189743 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0633      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00937     |
# |    std                  | 0.908        |
# |    value_loss           | 0.00231      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1231         |
# |    iterations           | 53           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0049065296 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0697      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00993     |
# |    std                  | 0.9          |
# |    value_loss           | 0.0029       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1231         |
# |    iterations           | 54           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0061434717 |
# |    clip_fraction        | 0.0599       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0765      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00975     |
# |    std                  | 0.902        |
# |    value_loss           | 0.00317      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1232         |
# |    iterations           | 55           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0068564983 |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0871      |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.0124      |
# |    std                  | 0.906        |
# |    value_loss           | 0.00336      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1233        |
# |    iterations           | 56          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.006041268 |
# |    clip_fraction        | 0.0659      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0712     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.901       |
# |    value_loss           | 0.00297     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 57          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.005820145 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0837     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.906       |
# |    value_loss           | 0.00171     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1235         |
# |    iterations           | 58           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0045532663 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0639      |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 0.906        |
# |    value_loss           | 0.00198      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 59          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.005022077 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.078      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00993    |
# |    std                  | 0.908       |
# |    value_loss           | 0.00271     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1237        |
# |    iterations           | 60          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.006327349 |
# |    clip_fraction        | 0.0561      |
# ...
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0985     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.903       |
# |    value_loss           | 0.00239     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1284         |
# |    iterations           | 81           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0063958997 |
# |    clip_fraction        | 0.0585       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0686      |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0125      |
# |    std                  | 0.906        |
# |    value_loss           | 0.00322      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1283         |
# |    iterations           | 82           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0061594294 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0799      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.904        |
# |    value_loss           | 0.00231      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1283        |
# |    iterations           | 83          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.008259516 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0745     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.908       |
# |    value_loss           | 0.00287     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 84          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.008000795 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0812     |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.913       |
# |    value_loss           | 0.00243     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1281        |
# |    iterations           | 85          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.008144819 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0843     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.908       |
# |    value_loss           | 0.00172     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1281         |
# |    iterations           | 86           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0055410066 |
# |    clip_fraction        | 0.07         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0861      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0114      |
# |    std                  | 0.909        |
# |    value_loss           | 0.00275      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1281        |
# |    iterations           | 87          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.008183246 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.082      |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.91        |
# |    value_loss           | 0.00218     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1280        |
# |    iterations           | 88          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008804968 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0817     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.906       |
# |    value_loss           | 0.00242     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1280         |
# |    iterations           | 89           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0056704124 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0847      |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0126      |
# |    std                  | 0.901        |
# |    value_loss           | 0.00263      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1279         |
# |    iterations           | 90           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0075953077 |
# |    clip_fraction        | 0.0802       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0856      |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0134      |
# |    std                  | 0.899        |
# |    value_loss           | 0.00158      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1279         |
# |    iterations           | 91           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0077064047 |
# |    clip_fraction        | 0.0644       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0748      |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0123      |
# |    std                  | 0.899        |
# |    value_loss           | 0.00186      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1279         |
# |    iterations           | 92           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0067913104 |
# |    clip_fraction        | 0.0653       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0857      |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.0128      |
# |    std                  | 0.886        |
# |    value_loss           | 0.00254      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1278        |
# |    iterations           | 93          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.008087619 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.091      |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.893       |
# |    value_loss           | 0.00139     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1277         |
# |    iterations           | 94           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0073081926 |
# |    clip_fraction        | 0.0776       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0828      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0147      |
# |    std                  | 0.891        |
# |    value_loss           | 0.00144      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1276        |
# |    iterations           | 95          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.007718966 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0683     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.892       |
# |    value_loss           | 0.00286     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1276        |
# |    iterations           | 96          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.010671378 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0789     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.898       |
# |    value_loss           | 0.00231     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1274        |
# |    iterations           | 97          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.007566246 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0752     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.899       |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1274         |
# |    iterations           | 98           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0075972406 |
# |    clip_fraction        | 0.0668       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0903      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0119      |
# |    std                  | 0.895        |
# |    value_loss           | 0.00205      |
# ------------------------------------------
# INFO:src.models.model_trainer_rl_v2_2_buyhold:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# Generated 218 actions.
# Running Backtest...
# INFO:BacktesterRL:Strategy Return: 37.71%
# INFO:BacktesterRL:Buy & Hold Return: 19.81%
# INFO:BacktesterRL:Outperformance: 17.90%
# --- Strategy Performance for DUK ---
# Total Return (%): 37.7100
# Annual Return (%): 70.8700
# Sharpe Ratio: 3.1346
# Sortino Ratio: 5.1131
# Max Drawdown (%): -6.6900
# Calmar Ratio: 10.5851
# Win Rate (%): 68.7500
# Total Trades: 32.0000
# Final Value ($): 137707.5300
# --- Trade Statistics for DUK ---
# Total number of trades: 32
#
# --- Trade Outcomes ---
# Number of profitable exits: 22
# Number of loss exits (cut loss): 10
# Win rate: 68.75%
# Average profit per winning trade: $2164.10
# Average loss per losing trade: $-990.27
