# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#from src.data.data_collector import DataCollector
from src.models.model_trainer_rl_v2_2_buyhold import ModelTrainerRL, TradingEnvRL
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from src.models.backtester import PortfolioBacktester, PortfolioBacktesterRL
from src.utils.config_loader import load_config


config = load_config("config/config.yaml")
# Out:
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:32: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_format is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_format instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:33: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_width is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_width instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:34: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_height is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_height instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:35: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_scale is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_scale instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:133: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:141: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.plotlyjs is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.plotlyjs instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:147: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.

# %% [markdown]
# ## V2.2 PPO Agent

# %% [markdown]
# ### Function

# %%
def run_ppo_trading_pipeline(stock_symbol, config, year='2022', save_path="models/", show_plot=True):
    """
    Complete PPO trading pipeline: load data, train model, generate predictions, and backtest.
    
    Parameters:
    -----------
    stock_symbol : str
        Stock ticker symbol (e.g., 'CNP', 'MDU')
    config : dict
        Configuration dictionary loaded from config.yaml
    year : str, optional
        Year for data file selection (default: '2022')
    save_path : str, optional
        Directory to save/load models (default: 'models/')
    show_plot : bool, optional
        Whether to display the portfolio plot (default: True)
    
    Returns:
    --------
    tuple : (portfolio, metrics, actions)
        - portfolio: VectorBT portfolio object
        - metrics: Dictionary of performance metrics
        - actions: Array of predicted actions
    """
    # 1. Load Data
    try:
        data = pd.read_csv(f'data/processed/{stock_symbol}_processed_{year}.csv')
        if 'Date' in data.columns:
            data['Date'] = pd.to_datetime(data['Date'])
            data.set_index('Date', inplace=True)
        print(f"Data loaded successfully for {stock_symbol}.")
    except FileNotFoundError:
        print(f"Error: Data file not found for {stock_symbol}. Check path.")
        sys.exit()
    
    # 2. Split Train/Test
    split_idx = int(len(data) * 0.7)
    train_df = data.iloc[:split_idx]
    test_df = data.iloc[split_idx:]
    
    # 3. Training Phase
    print(f"Training PPO Agent for {stock_symbol}...")
    trainer = ModelTrainerRL(config['reinforcement_learning'])
    env_params = config['reinforcement_learning']['environment']
    
    env_train = TradingEnvRL(
        train_df, 
        initial_balance=env_params.get('initial_balance', 10000),
        commission=env_params.get('commission', 0.001),
        lookback_window=env_params.get('lookback_window', 30),
        reward_func='profit'
    )
    
    result = trainer.train_ppo(env_train)
    trainer.save_models(save_path)
    print("Training Complete. Models saved.")
    
    # 4. Inference Phase
    print("Generating Agent Predictions on Test Data...")
    model = PPO.load(os.path.join(save_path, "ppo_model"))
    
    env_test = TradingEnvRL(
        test_df, 
        initial_balance=env_params.get('initial_balance', 100000),
        commission=env_params.get('commission', 0.001),
        lookback_window=env_params.get('lookback_window', 30),
        reward_func='profit' 
    )
    
    vec_env_test = DummyVecEnv([lambda: env_test])
    
    norm_path = os.path.join(save_path, "ppo_vecnormalize.pkl")
    if os.path.exists(norm_path):
        vec_env_test = VecNormalize.load(norm_path, vec_env_test)
        vec_env_test.training = False
        vec_env_test.norm_reward = False
    else:
        print("WARNING: Normalization stats not found. Model predictions may be garbage.")
    
    obs = vec_env_test.reset()
    done = [False]
    actions = []
    
    while not done[0]:
        action, _ = model.predict(obs, deterministic=True)
        actions.append(action[0])
        obs, _, done, _ = vec_env_test.step(action)
    
    print(f"Generated {len(actions)} actions.")
    
    # 5. Backtesting Phase
    print("Running Backtest...")
    backtester = PortfolioBacktesterRL(env_params)
    
    portfolio = backtester.run_backtest(
        price_data=test_df['close'], 
        predicted_weights=np.array(actions).flatten(),
        lookback_window=env_params.get('lookback_window', 30)
    )
    
    comparison = backtester.compare_with_buy_and_hold_rl()
    metrics = backtester.get_performance_metrics()
    
    print(f"\n--- Strategy Performance for {stock_symbol} ---")
    for k, v in metrics.items():
        print(f"{k}: {v:.4f}")
    
    if show_plot:
        portfolio.plot().show()
        # Print trade statistics
        trades = portfolio.trades.records_readable
        print(f"\n--- Trade Statistics for {stock_symbol} ---")
        print(f"Total number of trades: {len(trades)}")
        #print("\nTrade Direction Counts:")
        #print(trades['Direction'].value_counts())

        # Analyze trade outcomes
        if 'PnL' in trades.columns:
                profitable_trades = trades[trades['PnL'] > 0]
                loss_trades = trades[trades['PnL'] < 0]
                
                print(f"\n--- Trade Outcomes ---")
                print(f"Number of profitable exits: {len(profitable_trades)}")
                print(f"Number of loss exits (cut loss): {len(loss_trades)}")
                print(f"Win rate: {len(profitable_trades) / len(trades) * 100:.2f}%")
                print(f"Average profit per winning trade: ${profitable_trades['PnL'].mean():.2f}" if len(profitable_trades) > 0 else "No profitable trades")
                print(f"Average loss per losing trade: ${loss_trades['PnL'].mean():.2f}" if len(loss_trades) > 0 else "No losing trades")
            


    
    return portfolio, metrics, np.array(actions).flatten()

# %%
## Single stock
stock_symbol = "CNP"
portfolio, metrics, actions = run_ppo_trading_pipeline(stock_symbol, config)
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_49968\1970358808.py:29: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2_buyhold:Training PPO...
# Data loaded successfully for CNP.
# Training PPO Agent for CNP...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2198 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0032407343 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.441       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.143        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00354     |
# |    std                  | 1.01         |
# |    value_loss           | 0.387        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1817         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0050761513 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.339        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0232      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00762     |
# |    std                  | 1            |
# |    value_loss           | 0.142        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1792         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0049979887 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00722     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00914     |
# |    std                  | 1.01         |
# |    value_loss           | 0.138        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1772        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008464437 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.00127    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 1.02        |
# |    value_loss           | 0.129       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1767         |
# |    iterations           | 6            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0071936585 |
# |    clip_fraction        | 0.0839       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.477        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.024       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 1.02         |
# |    value_loss           | 0.135        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1761        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005215614 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0573     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.02        |
# |    value_loss           | 0.0911      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1757        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006447099 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0654     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 1.03        |
# |    value_loss           | 0.0787      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1759         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0055220732 |
# |    clip_fraction        | 0.0681       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0331      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 1.02         |
# |    value_loss           | 0.0794       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1753         |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0059820707 |
# |    clip_fraction        | 0.0611       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.483        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.053       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0099      |
# |    std                  | 1.03         |
# |    value_loss           | 0.0807       |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1727       |
# |    iterations           | 11         |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00588593 |
# |    clip_fraction        | 0.0696     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0.597      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0612    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.012     |
# |    std                  | 1.02       |
# |    value_loss           | 0.0574     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1723         |
# |    iterations           | 12           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0066054817 |
# |    clip_fraction        | 0.0607       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0536      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 1.02         |
# |    value_loss           | 0.0631       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1731         |
# |    iterations           | 13           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0060655563 |
# |    clip_fraction        | 0.0735       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.743        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0631      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0118      |
# |    std                  | 1.02         |
# |    value_loss           | 0.0473       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1735         |
# |    iterations           | 14           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0067636836 |
# |    clip_fraction        | 0.0774       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0592      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.013       |
# |    std                  | 1.01         |
# |    value_loss           | 0.0331       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1744        |
# |    iterations           | 15          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.003844676 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0711     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00733    |
# |    std                  | 1.01        |
# |    value_loss           | 0.036       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1737        |
# |    iterations           | 16          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005082678 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0556     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0282      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1737         |
# |    iterations           | 17           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0038051582 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0745      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00896     |
# |    std                  | 1            |
# |    value_loss           | 0.0286       |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1738       |
# |    iterations           | 18         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00321145 |
# |    clip_fraction        | 0.0247     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0641    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00692   |
# |    std                  | 0.988      |
# |    value_loss           | 0.0217     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1741         |
# |    iterations           | 19           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0050064316 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0771      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0086      |
# |    std                  | 0.985        |
# |    value_loss           | 0.0211       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1748         |
# |    iterations           | 20           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0056856354 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0782      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0093      |
# |    std                  | 0.979        |
# |    value_loss           | 0.0192       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1755         |
# |    iterations           | 21           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0046598464 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0807      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0099      |
# |    std                  | 0.98         |
# |    value_loss           | 0.0178       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1759        |
# |    iterations           | 22          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004147539 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0801     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00777    |
# |    std                  | 0.974       |
# |    value_loss           | 0.0191      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1753         |
# |    iterations           | 23           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0051622447 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0687      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00886     |
# |    std                  | 0.972        |
# |    value_loss           | 0.0136       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1751         |
# |    iterations           | 24           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0066046547 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0844      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0123      |
# |    std                  | 0.963        |
# |    value_loss           | 0.0131       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1751        |
# |    iterations           | 25          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.003783882 |
# |    clip_fraction        | 0.0231      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0893     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00828    |
# |    std                  | 0.954       |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1753         |
# |    iterations           | 26           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0037005348 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0659      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00851     |
# |    std                  | 0.955        |
# |    value_loss           | 0.0114       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1754         |
# |    iterations           | 27           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0056169587 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0842      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00941     |
# |    std                  | 0.951        |
# |    value_loss           | 0.0105       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1751        |
# |    iterations           | 28          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005020748 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.084      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.949       |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1753        |
# |    iterations           | 29          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005833922 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0807     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00895    |
# |    std                  | 0.945       |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1755        |
# |    iterations           | 30          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.003389154 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0713     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00887    |
# |    std                  | 0.939       |
# |    value_loss           | 0.00953     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1757         |
# |    iterations           | 31           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0043707583 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0861      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.934        |
# |    value_loss           | 0.00757      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1760         |
# |    iterations           | 32           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0047730934 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0768      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00922     |
# |    std                  | 0.925        |
# |    value_loss           | 0.0055       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1763        |
# |    iterations           | 33          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.005237137 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.082      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.923       |
# |    value_loss           | 0.0067      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1765         |
# |    iterations           | 34           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0038410511 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0786      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00894     |
# |    std                  | 0.921        |
# |    value_loss           | 0.00593      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1767         |
# |    iterations           | 35           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0048720185 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0741      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00948     |
# |    std                  | 0.923        |
# |    value_loss           | 0.00512      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1762        |
# |    iterations           | 36          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005419185 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0963     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.924       |
# |    value_loss           | 0.00499     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1763        |
# |    iterations           | 37          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007239921 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0885     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.92        |
# |    value_loss           | 0.0057      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1764         |
# |    iterations           | 38           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0055017034 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0771      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 0.927        |
# |    value_loss           | 0.00433      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 39          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004673367 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0664     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.921       |
# |    value_loss           | 0.00557     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1766        |
# |    iterations           | 40          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005214709 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0864     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.919       |
# |    value_loss           | 0.00595     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1769        |
# |    iterations           | 41          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.006342304 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0811     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.92        |
# |    value_loss           | 0.00416     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1772         |
# |    iterations           | 42           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0056153783 |
# |    clip_fraction        | 0.0594       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0647      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.927        |
# |    value_loss           | 0.00687      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1774         |
# |    iterations           | 43           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0063831005 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0659      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.934        |
# |    value_loss           | 0.00419      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1776        |
# |    iterations           | 44          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004380902 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0693     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.929       |
# |    value_loss           | 0.00376     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1777        |
# |    iterations           | 45          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005477142 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0772     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00934    |
# |    std                  | 0.926       |
# |    value_loss           | 0.00421     |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1779     |
# |    iterations           | 46       |
# |    time_elapsed         | 52       |
# |    total_timesteps      | 94208    |
# | train/                  |          |
# |    approx_kl            | 0.004621 |
# |    clip_fraction        | 0.0421   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.34    |
# |    explained_variance   | 0.991    |
# |    learning_rate        | 0.0002   |
# |    loss                 | -0.094   |
# |    n_updates            | 450      |
# |    policy_gradient_loss | -0.0107  |
# |    std                  | 0.923    |
# |    value_loss           | 0.00379  |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1780        |
# |    iterations           | 47          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005098585 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0802     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.926       |
# |    value_loss           | 0.00379     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1782         |
# |    iterations           | 48           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0044462574 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0959      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.922        |
# |    value_loss           | 0.00404      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1782         |
# |    iterations           | 49           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0070673195 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0604      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0146      |
# |    std                  | 0.92         |
# |    value_loss           | 0.00494      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1777        |
# |    iterations           | 50          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004522541 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0793     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.921       |
# |    value_loss           | 0.0045      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1778        |
# |    iterations           | 51          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.004579818 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0761     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.914       |
# |    value_loss           | 0.00411     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1774         |
# |    iterations           | 52           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0046216464 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0865      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 0.913        |
# |    value_loss           | 0.0032       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1774        |
# |    iterations           | 53          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.004505804 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.087      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.906       |
# |    value_loss           | 0.00445     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1776         |
# |    iterations           | 54           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0044530956 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0675      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00743     |
# |    std                  | 0.902        |
# |    value_loss           | 0.00384      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1776        |
# |    iterations           | 55          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.005398703 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0816     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.904       |
# |    value_loss           | 0.00365     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1778        |
# |    iterations           | 56          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.005779124 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0541     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00988    |
# |    std                  | 0.902       |
# |    value_loss           | 0.00444     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1779        |
# |    iterations           | 57          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.006906513 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0823     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.907       |
# |    value_loss           | 0.00428     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1780        |
# |    iterations           | 58          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.005667027 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0871     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.906       |
# |    value_loss           | 0.00334     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1780         |
# |    iterations           | 59           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0052305423 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0782      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0103      |
# |    std                  | 0.901        |
# |    value_loss           | 0.00419      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1781         |
# |    iterations           | 60           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0074496316 |
# |    clip_fraction        | 0.0727       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# ...
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0901     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.907       |
# |    value_loss           | 0.00398     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1769         |
# |    iterations           | 81           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0053373454 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0883      |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0111      |
# |    std                  | 0.913        |
# |    value_loss           | 0.00379      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1769         |
# |    iterations           | 82           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0064442093 |
# |    clip_fraction        | 0.0633       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0832      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0132      |
# |    std                  | 0.91         |
# |    value_loss           | 0.00262      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1769       |
# |    iterations           | 83         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.00674679 |
# |    clip_fraction        | 0.0619     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0949    |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.0157    |
# |    std                  | 0.902      |
# |    value_loss           | 0.00234    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1768        |
# |    iterations           | 84          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.006467648 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0775     |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.903       |
# |    value_loss           | 0.00251     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1768        |
# |    iterations           | 85          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.006369568 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.091      |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.905       |
# |    value_loss           | 0.00246     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1767         |
# |    iterations           | 86           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0077492683 |
# |    clip_fraction        | 0.0842       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0894      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0147      |
# |    std                  | 0.907        |
# |    value_loss           | 0.00343      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1766         |
# |    iterations           | 87           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0064209104 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0848      |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.906        |
# |    value_loss           | 0.00222      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 88          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.005771066 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0961     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.9         |
# |    value_loss           | 0.00277     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1762         |
# |    iterations           | 89           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0073518697 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0856      |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0147      |
# |    std                  | 0.896        |
# |    value_loss           | 0.00216      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1759         |
# |    iterations           | 90           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0071875844 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.091       |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0131      |
# |    std                  | 0.892        |
# |    value_loss           | 0.00226      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1758         |
# |    iterations           | 91           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0065741464 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0916      |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0109      |
# |    std                  | 0.887        |
# |    value_loss           | 0.00195      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1757         |
# |    iterations           | 92           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0077907853 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0798      |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.0139      |
# |    std                  | 0.88         |
# |    value_loss           | 0.00231      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1755         |
# |    iterations           | 93           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0066960896 |
# |    clip_fraction        | 0.0668       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0861      |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0132      |
# |    std                  | 0.873        |
# |    value_loss           | 0.00256      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1753        |
# |    iterations           | 94          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.008864237 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0875     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.877       |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1751        |
# |    iterations           | 95          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.006508425 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0797     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.878       |
# |    value_loss           | 0.00247     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1751        |
# |    iterations           | 96          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.006826355 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0762     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.881       |
# |    value_loss           | 0.00149     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1752       |
# |    iterations           | 97         |
# |    time_elapsed         | 113        |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.00868064 |
# |    clip_fraction        | 0.0723     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0745    |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.0155    |
# |    std                  | 0.886      |
# |    value_loss           | 0.00381    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1751        |
# |    iterations           | 98          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.008912462 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0776     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.888       |
# |    value_loss           | 0.00189     |
# -----------------------------------------
# INFO:src.models.model_trainer_rl_v2_2_buyhold:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# Generated 218 actions.
# Running Backtest...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 14.41%
# INFO:BacktesterRL:Buy & Hold Return: 29.90%
# INFO:BacktesterRL:Outperformance: -15.49%
# --- Strategy Performance for CNP ---
# Total Return (%): 14.4100
# Annual Return (%): 25.2800
# Sharpe Ratio: 3.4472
# Sortino Ratio: 14.3008
# Max Drawdown (%): -0.9900
# Calmar Ratio: 25.5754
# Win Rate (%): 80.0000
# Total Trades: 20.0000
# Final Value ($): 114408.6000
# --- Trade Statistics for CNP ---
# Total number of trades: 20
#
# --- Trade Outcomes ---
# Number of profitable exits: 16
# Number of loss exits (cut loss): 4
# Win rate: 80.00%
# Average profit per winning trade: $915.28
# Average loss per losing trade: $-58.98

# %%
# # portfolio.trades.records_readable
# # Print trade statistics
# trades = portfolio.trades.records_readable
# print(f"\n--- Trade Statistics for abc ---")
# print(f"Total number of trades: {len(trades)}")
# print("\nTrade Direction Counts:")
# print(trades['Direction'].value_counts())

# # Analyze trade outcomes
# if 'PnL' in trades.columns:
#         profitable_trades = trades[trades['PnL'] > 0]
#         loss_trades = trades[trades['PnL'] < 0]
        
#         print(f"\n--- Trade Outcomes ---")
#         print(f"Number of profitable exits: {len(profitable_trades)}")
#         print(f"Number of loss exits (cut loss): {len(loss_trades)}")
#         print(f"Win rate: {len(profitable_trades) / len(trades) * 100:.2f}%")
#         print(f"Average profit per winning trade: ${profitable_trades['PnL'].mean():.2f}" if len(profitable_trades) > 0 else "No profitable trades")
#         print(f"Average loss per losing trade: ${loss_trades['PnL'].mean():.2f}" if len(loss_trades) > 0 else "No losing trades")
# Out:
# --- Trade Statistics for abc ---
# Total number of trades: 30
#
# Trade Direction Counts:
# Direction
# Long    30
# Name: count, dtype: int64
#
# --- Trade Outcomes ---
# Number of profitable exits: 24
# Number of loss exits (cut loss): 6
# Win rate: 80.00%
# Average profit per winning trade: $1691.00
# Average loss per losing trade: $-171.27

# %%
# Multiple stocks in a loop
stocks = ["CNP", "MDU", "CWCO", "NEE", "DUK"]
results = {}

for stock in stocks:
    print(f"\n{'='*60}")
    print(f"Processing {stock}")
    print(f"{'='*60}")
    portfolio, metrics, actions = run_ppo_trading_pipeline(
        stock_symbol=stock, 
        config=config,
        show_plot=True  # Don't show plots in loop
    )
    results[stock] = {'portfolio': portfolio, 'metrics': metrics, 'actions': actions}
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_49968\1970358808.py:29: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2_buyhold:Training PPO...
# ============================================================
# Processing CNP
# ============================================================
# Data loaded successfully for CNP.
# Training PPO Agent for CNP...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2291 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1915        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.002854994 |
# |    clip_fraction        | 0.00796     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.349      |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.0399      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00291    |
# |    std                  | 1.01        |
# |    value_loss           | 0.396       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1806        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006763989 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.00538    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.01        |
# |    value_loss           | 0.253       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1790         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0057243477 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.428        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00333     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00931     |
# |    std                  | 1.02         |
# |    value_loss           | 0.204        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1780         |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0054294337 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.428        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0254      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00933     |
# |    std                  | 1.02         |
# |    value_loss           | 0.136        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1770        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005613614 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0241     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 1.03        |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1763        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005303285 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.467       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0329     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00977    |
# |    std                  | 1.02        |
# |    value_loss           | 0.126       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1759         |
# |    iterations           | 8            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0060838684 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0467      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 1.01         |
# |    value_loss           | 0.0986       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1761        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005801334 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0375     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 1           |
# |    value_loss           | 0.102       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1762         |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0060311016 |
# |    clip_fraction        | 0.0687       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0576      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 0.999        |
# |    value_loss           | 0.0841       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1760        |
# |    iterations           | 11          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005112741 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0591     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.992       |
# |    value_loss           | 0.0899      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1761        |
# |    iterations           | 12          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006100852 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0631     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.987       |
# |    value_loss           | 0.0811      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1767         |
# |    iterations           | 13           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0048961975 |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.742        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0503      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00853     |
# |    std                  | 0.986        |
# |    value_loss           | 0.062        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1772        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006358884 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0766     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.978       |
# |    value_loss           | 0.0527      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1775         |
# |    iterations           | 15           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0060373577 |
# |    clip_fraction        | 0.0692       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.855        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0711      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.971        |
# |    value_loss           | 0.0439       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1768        |
# |    iterations           | 16          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006826265 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0883     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.976       |
# |    value_loss           | 0.0321      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1766         |
# |    iterations           | 17           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0064658877 |
# |    clip_fraction        | 0.0727       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0686      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0124      |
# |    std                  | 0.97         |
# |    value_loss           | 0.033        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1766       |
# |    iterations           | 18         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00470831 |
# |    clip_fraction        | 0.0395     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0679    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00728   |
# |    std                  | 0.966      |
# |    value_loss           | 0.0227     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1767       |
# |    iterations           | 19         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00428731 |
# |    clip_fraction        | 0.0385     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0795    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00868   |
# |    std                  | 0.966      |
# |    value_loss           | 0.0197     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1769         |
# |    iterations           | 20           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0051055877 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0817      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 0.96         |
# |    value_loss           | 0.0231       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1773        |
# |    iterations           | 21          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004834449 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0785     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.952       |
# |    value_loss           | 0.0161      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1774         |
# |    iterations           | 22           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0052090865 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0616      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00791     |
# |    std                  | 0.95         |
# |    value_loss           | 0.0138       |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1776       |
# |    iterations           | 23         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00468717 |
# |    clip_fraction        | 0.0432     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0661    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0087    |
# |    std                  | 0.945      |
# |    value_loss           | 0.012      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1774         |
# |    iterations           | 24           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0064036753 |
# |    clip_fraction        | 0.0763       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0654      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0123      |
# |    std                  | 0.94         |
# |    value_loss           | 0.0142       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1773         |
# |    iterations           | 25           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0046549942 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0718      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00935     |
# |    std                  | 0.935        |
# |    value_loss           | 0.00995      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1773         |
# |    iterations           | 26           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0056179203 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0849      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0117      |
# |    std                  | 0.924        |
# |    value_loss           | 0.0099       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1774        |
# |    iterations           | 27          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.006929583 |
# |    clip_fraction        | 0.0735      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.076      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.922       |
# |    value_loss           | 0.00687     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1775         |
# |    iterations           | 28           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0056047216 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0757      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.924        |
# |    value_loss           | 0.00688      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1775        |
# |    iterations           | 29          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004697019 |
# |    clip_fraction        | 0.0435      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0855     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00906    |
# |    std                  | 0.918       |
# |    value_loss           | 0.00626     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1776         |
# |    iterations           | 30           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0070265783 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0873      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.919        |
# |    value_loss           | 0.00739      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1777         |
# |    iterations           | 31           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0035150908 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0844      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00903     |
# |    std                  | 0.919        |
# |    value_loss           | 0.00584      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1776         |
# |    iterations           | 32           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0052345963 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0803      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 0.929        |
# |    value_loss           | 0.00596      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1776         |
# |    iterations           | 33           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0056538824 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0827      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 0.934        |
# |    value_loss           | 0.00573      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1775         |
# |    iterations           | 34           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0065265903 |
# |    clip_fraction        | 0.0635       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0819      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.938        |
# |    value_loss           | 0.00427      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1776         |
# |    iterations           | 35           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0071553467 |
# |    clip_fraction        | 0.0606       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0886      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0126      |
# |    std                  | 0.937        |
# |    value_loss           | 0.00426      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1776        |
# |    iterations           | 36          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004782171 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0769     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.944       |
# |    value_loss           | 0.0038      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1778        |
# |    iterations           | 37          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005018631 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0808     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00881    |
# |    std                  | 0.945       |
# |    value_loss           | 0.00505     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1778         |
# |    iterations           | 38           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0045911474 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0797      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00937     |
# |    std                  | 0.948        |
# |    value_loss           | 0.00509      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1778         |
# |    iterations           | 39           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0047555286 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0745      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00784     |
# |    std                  | 0.952        |
# |    value_loss           | 0.00618      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1777         |
# |    iterations           | 40           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0061940276 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0854      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0125      |
# |    std                  | 0.95         |
# |    value_loss           | 0.00477      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1776         |
# |    iterations           | 41           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0049555455 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0675      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.95         |
# |    value_loss           | 0.00443      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1772         |
# |    iterations           | 42           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0045478195 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0742      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00913     |
# |    std                  | 0.96         |
# |    value_loss           | 0.00384      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1769        |
# |    iterations           | 43          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007501032 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0972     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.965       |
# |    value_loss           | 0.00311     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1769        |
# |    iterations           | 44          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005191884 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0994     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.958       |
# |    value_loss           | 0.00413     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1769         |
# |    iterations           | 45           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0045065847 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0879      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 0.953        |
# |    value_loss           | 0.00409      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1768         |
# |    iterations           | 46           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0058509307 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0829      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0138      |
# |    std                  | 0.948        |
# |    value_loss           | 0.00396      |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1766      |
# |    iterations           | 47        |
# |    time_elapsed         | 54        |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.0069316 |
# |    clip_fraction        | 0.0829    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.37     |
# |    explained_variance   | 0.99      |
# |    learning_rate        | 0.0002    |
# |    loss                 | -0.0765   |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.0132   |
# |    std                  | 0.95      |
# |    value_loss           | 0.00441   |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1769         |
# |    iterations           | 48           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0046848613 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0782      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0118      |
# |    std                  | 0.95         |
# |    value_loss           | 0.00345      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1770        |
# |    iterations           | 49          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006809354 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0902     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.949       |
# |    value_loss           | 0.0044      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1771         |
# |    iterations           | 50           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0061857104 |
# |    clip_fraction        | 0.0793       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0827      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.95         |
# |    value_loss           | 0.00332      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1773         |
# |    iterations           | 51           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0070961835 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0829      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0135      |
# |    std                  | 0.956        |
# |    value_loss           | 0.00301      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1775       |
# |    iterations           | 52         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.00456951 |
# |    clip_fraction        | 0.0307     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0742    |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00913   |
# |    std                  | 0.953      |
# |    value_loss           | 0.003      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1777        |
# |    iterations           | 53          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.004753759 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0861     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.961       |
# |    value_loss           | 0.00305     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1778        |
# |    iterations           | 54          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.007362176 |
# |    clip_fraction        | 0.0732      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0856     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.958       |
# |    value_loss           | 0.00279     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1780        |
# |    iterations           | 55          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.006254051 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.076      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.955       |
# |    value_loss           | 0.00401     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1782         |
# |    iterations           | 56           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0060025733 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0942      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.0138      |
# |    std                  | 0.955        |
# |    value_loss           | 0.00352      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1784        |
# |    iterations           | 57          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.004786455 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0731     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.956       |
# |    value_loss           | 0.00329     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1784         |
# |    iterations           | 58           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0063130166 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0781      |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.95         |
# |    value_loss           | 0.00333      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1786         |
# |    iterations           | 59           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0062149856 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.081       |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0139      |
# |    std                  | 0.946        |
# |    value_loss           | 0.00447      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1787        |
# |    iterations           | 60          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.005807691 |
# ...
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.104       |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 1.05         |
# |    value_loss           | 0.00228      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1822        |
# |    iterations           | 81          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.005361689 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0815     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 1.05        |
# |    value_loss           | 0.00184     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1821         |
# |    iterations           | 82           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0064179255 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0991      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 1.05         |
# |    value_loss           | 0.00155      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1820         |
# |    iterations           | 83           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0075132614 |
# |    clip_fraction        | 0.071        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0802      |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.0129      |
# |    std                  | 1.05         |
# |    value_loss           | 0.00215      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1819        |
# |    iterations           | 84          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.005858399 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.094      |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 1.05        |
# |    value_loss           | 0.00313     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1819         |
# |    iterations           | 85           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0055694794 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0853      |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.0132      |
# |    std                  | 1.05         |
# |    value_loss           | 0.00226      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1819         |
# |    iterations           | 86           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0056538633 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0868      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 1.05         |
# |    value_loss           | 0.00208      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1818        |
# |    iterations           | 87          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.006760769 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.091      |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 1.05        |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1817        |
# |    iterations           | 88          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.004303749 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0938     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00947    |
# |    std                  | 1.05        |
# |    value_loss           | 0.00224     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1816        |
# |    iterations           | 89          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.009043615 |
# |    clip_fraction        | 0.0643      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0901     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 1.04        |
# |    value_loss           | 0.00146     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1816        |
# |    iterations           | 90          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.007278338 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0902     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 1.05        |
# |    value_loss           | 0.0031      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1817         |
# |    iterations           | 91           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0077477293 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0953      |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0132      |
# |    std                  | 1.05         |
# |    value_loss           | 0.00231      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1815        |
# |    iterations           | 92          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.006966979 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0967     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 1.05        |
# |    value_loss           | 0.00254     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1815         |
# |    iterations           | 93           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0065053357 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.103       |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 1.04         |
# |    value_loss           | 0.0022       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1815         |
# |    iterations           | 94           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0068292776 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0838      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 1.04         |
# |    value_loss           | 0.00196      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1813         |
# |    iterations           | 95           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0068319514 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0826      |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 1.05         |
# |    value_loss           | 0.00206      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1811         |
# |    iterations           | 96           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0055355867 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0885      |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.012       |
# |    std                  | 1.04         |
# |    value_loss           | 0.00189      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1809        |
# |    iterations           | 97          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.006623978 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.107      |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 1.04        |
# |    value_loss           | 0.00209     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1807         |
# |    iterations           | 98           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0066623357 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0852      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 1.04         |
# |    value_loss           | 0.00287      |
# ------------------------------------------
# INFO:src.models.model_trainer_rl_v2_2_buyhold:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 42.47%
# INFO:BacktesterRL:Buy & Hold Return: 19.81%
# INFO:BacktesterRL:Outperformance: 22.66%
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# Generated 218 actions.
# Running Backtest...
#
# --- Strategy Performance for DUK ---
# Total Return (%): 42.4700
# Annual Return (%): 80.8800
# Sharpe Ratio: 3.5647
# Sortino Ratio: 6.2171
# Max Drawdown (%): -4.9800
# Calmar Ratio: 16.2332
# Win Rate (%): 94.1200
# Total Trades: 17.0000
# Final Value ($): 142471.6700
# --- Trade Statistics for DUK ---
# Total number of trades: 17
#
# --- Trade Outcomes ---
# Number of profitable exits: 16
# Number of loss exits (cut loss): 1
# Win rate: 94.12%
# Average profit per winning trade: $2815.88
# Average loss per losing trade: $-2582.40
