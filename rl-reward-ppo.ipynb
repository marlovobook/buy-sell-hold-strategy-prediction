# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#from src.data.data_collector import DataCollector
from src.models.model_trainer_rl_v2_2 import ModelTrainerRL, TradingEnvRL
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from src.models.backtester import PortfolioBacktester, PortfolioBacktesterRL
from src.utils.config_loader import load_config


config = load_config("config/config.yaml")
# Out:
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:32: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_format is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_format instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:33: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_width is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_width instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:34: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_height is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_height instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:35: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_scale is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_scale instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:133: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:141: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.plotlyjs is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.plotlyjs instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:147: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.

# %% [markdown]
# ## V2.2 PPO Agent

# %% [markdown]
# ### Function

# %%
def run_ppo_trading_pipeline(stock_symbol, config, year='2022', save_path="models/", show_plot=True):
    """
    Complete PPO trading pipeline: load data, train model, generate predictions, and backtest.
    
    Parameters:
    -----------
    stock_symbol : str
        Stock ticker symbol (e.g., 'CNP', 'MDU')
    config : dict
        Configuration dictionary loaded from config.yaml
    year : str, optional
        Year for data file selection (default: '2022')
    save_path : str, optional
        Directory to save/load models (default: 'models/')
    show_plot : bool, optional
        Whether to display the portfolio plot (default: True)
    
    Returns:
    --------
    tuple : (portfolio, metrics, actions)
        - portfolio: VectorBT portfolio object
        - metrics: Dictionary of performance metrics
        - actions: Array of predicted actions
    """
    # 1. Load Data
    try:
        data = pd.read_csv(f'data/processed/{stock_symbol}_processed_{year}.csv')
        if 'Date' in data.columns:
            data['Date'] = pd.to_datetime(data['Date'])
            data.set_index('Date', inplace=True)
        print(f"Data loaded successfully for {stock_symbol}.")
    except FileNotFoundError:
        print(f"Error: Data file not found for {stock_symbol}. Check path.")
        sys.exit()
    
    # 2. Split Train/Test
    split_idx = int(len(data) * 0.7)
    train_df = data.iloc[:split_idx]
    test_df = data.iloc[split_idx:]
    
    # 3. Training Phase
    print(f"Training PPO Agent for {stock_symbol}...")
    trainer = ModelTrainerRL(config['reinforcement_learning'])
    env_params = config['reinforcement_learning']['environment']
    
    env_train = TradingEnvRL(
        train_df, 
        initial_balance=env_params.get('initial_balance', 10000),
        commission=env_params.get('commission', 0.001),
        lookback_window=env_params.get('lookback_window', 30),
        reward_func='profit'
    )
    
    result = trainer.train_ppo(env_train)
    trainer.save_models(save_path)
    print("Training Complete. Models saved.")
    
    # 4. Inference Phase
    print("Generating Agent Predictions on Test Data...")
    model = PPO.load(os.path.join(save_path, "ppo_model"))
    
    env_test = TradingEnvRL(
        test_df, 
        initial_balance=env_params.get('initial_balance', 100000),
        commission=env_params.get('commission', 0.001),
        lookback_window=env_params.get('lookback_window', 30),
        reward_func='profit' 
    )
    
    vec_env_test = DummyVecEnv([lambda: env_test])
    
    norm_path = os.path.join(save_path, "ppo_vecnormalize.pkl")
    if os.path.exists(norm_path):
        vec_env_test = VecNormalize.load(norm_path, vec_env_test)
        vec_env_test.training = False
        vec_env_test.norm_reward = False
    else:
        print("WARNING: Normalization stats not found. Model predictions may be garbage.")
    
    obs = vec_env_test.reset()
    done = [False]
    actions = []
    
    while not done[0]:
        action, _ = model.predict(obs, deterministic=True)
        actions.append(action[0])
        obs, _, done, _ = vec_env_test.step(action)
    
    print(f"Generated {len(actions)} actions.")
    
    # 5. Backtesting Phase
    print("Running Backtest...")
    backtester = PortfolioBacktesterRL(env_params)
    
    portfolio = backtester.run_backtest(
        price_data=test_df['close'], 
        predicted_weights=np.array(actions).flatten(),
        lookback_window=env_params.get('lookback_window', 30)
    )
    
    comparison = backtester.compare_with_buy_and_hold_rl()
    metrics = backtester.get_performance_metrics()
    
    print(f"\n--- Strategy Performance for {stock_symbol} ---")
    for k, v in metrics.items():
        print(f"{k}: {v:.4f}")
    
    if show_plot:
        portfolio.plot().show()
        # Print trade statistics
        trades = portfolio.trades.records_readable
        print(f"\n--- Trade Statistics for {stock_symbol} ---")
        print(f"Total number of trades: {len(trades)}")
        print("\nTrade Direction Counts:")
        print(trades['Direction'].value_counts())

        # Analyze trade outcomes
        if 'PnL' in trades.columns:
                profitable_trades = trades[trades['PnL'] > 0]
                loss_trades = trades[trades['PnL'] < 0]
                
                print(f"\n--- Trade Outcomes ---")
                print(f"Number of profitable exits: {len(profitable_trades)}")
                print(f"Number of loss exits (cut loss): {len(loss_trades)}")
                print(f"Win rate: {len(profitable_trades) / len(trades) * 100:.2f}%")
                print(f"Average profit per winning trade: ${profitable_trades['PnL'].mean():.2f}" if len(profitable_trades) > 0 else "No profitable trades")
                print(f"Average loss per losing trade: ${loss_trades['PnL'].mean():.2f}" if len(loss_trades) > 0 else "No losing trades")
            


    
    return portfolio, metrics, np.array(actions).flatten()

# %%
## Single stock
stock_symbol = "CNP"
portfolio, metrics, actions = run_ppo_trading_pipeline(stock_symbol, config)
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_32544\1835811511.py:29: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
# Data loaded successfully for CNP.
# Training PPO Agent for CNP...
# Using cpu device
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# -----------------------------
# | time/              |      |
# |    fps             | 2482 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2016         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0054611554 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0309       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0775       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00792     |
# |    std                  | 0.999        |
# |    value_loss           | 0.416        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1951        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009943621 |
# |    clip_fraction        | 0.0801      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0271     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 1           |
# |    value_loss           | 0.188       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1929        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006792262 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0235     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 1           |
# |    value_loss           | 0.141       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1903        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007451804 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0422     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 1.01        |
# |    value_loss           | 0.132       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1894        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006669527 |
# |    clip_fraction        | 0.0822      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0119     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 1.01        |
# |    value_loss           | 0.117       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1820        |
# |    iterations           | 7           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005973222 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0323     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 1.01        |
# |    value_loss           | 0.108       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1763         |
# |    iterations           | 8            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0069060368 |
# |    clip_fraction        | 0.0765       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.626        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0424      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 1            |
# |    value_loss           | 0.0776       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1729         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0059835357 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.576        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.051       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.994        |
# |    value_loss           | 0.0706       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1702         |
# |    iterations           | 10           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0056028483 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.662        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0413      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0117      |
# |    std                  | 0.977        |
# |    value_loss           | 0.0749       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1694         |
# |    iterations           | 11           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0063374517 |
# |    clip_fraction        | 0.077        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0724      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0157      |
# |    std                  | 0.968        |
# |    value_loss           | 0.0614       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1687         |
# |    iterations           | 12           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0044114105 |
# |    clip_fraction        | 0.0583       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.812        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0743      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.963        |
# |    value_loss           | 0.0473       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1676         |
# |    iterations           | 13           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0048102657 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.83         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0647      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.963        |
# |    value_loss           | 0.037        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1671         |
# |    iterations           | 14           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0064073717 |
# |    clip_fraction        | 0.0755       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0601      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.96         |
# |    value_loss           | 0.0376       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1666         |
# |    iterations           | 15           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0049802195 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0709      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00926     |
# |    std                  | 0.96         |
# |    value_loss           | 0.0247       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1666         |
# |    iterations           | 16           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0053359075 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.088       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.961        |
# |    value_loss           | 0.022        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1667        |
# |    iterations           | 17          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005731329 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0667     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.956       |
# |    value_loss           | 0.021       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1650         |
# |    iterations           | 18           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0042236447 |
# |    clip_fraction        | 0.0402       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.081       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00921     |
# |    std                  | 0.957        |
# |    value_loss           | 0.0206       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1644         |
# |    iterations           | 19           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0043367352 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0729      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0111      |
# |    std                  | 0.952        |
# |    value_loss           | 0.014        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1640        |
# |    iterations           | 20          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005351575 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0597     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0094     |
# |    std                  | 0.954       |
# |    value_loss           | 0.0175      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1632         |
# |    iterations           | 21           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0040257354 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0602      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00854     |
# |    std                  | 0.95         |
# |    value_loss           | 0.0174       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 22          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005259346 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0837     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.941       |
# |    value_loss           | 0.015       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1623         |
# |    iterations           | 23           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0042917673 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0763      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00871     |
# |    std                  | 0.939        |
# |    value_loss           | 0.0134       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1607         |
# |    iterations           | 24           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0050123623 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0871      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.943        |
# |    value_loss           | 0.011        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1601         |
# |    iterations           | 25           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0058384426 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0623      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 0.935        |
# |    value_loss           | 0.0119       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1601         |
# |    iterations           | 26           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0047690673 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0873      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.933        |
# |    value_loss           | 0.0114       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1602         |
# |    iterations           | 27           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0048926193 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0734      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00929     |
# |    std                  | 0.935        |
# |    value_loss           | 0.00805      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1602        |
# |    iterations           | 28          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004344835 |
# |    clip_fraction        | 0.0347      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0708     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00918    |
# |    std                  | 0.937       |
# |    value_loss           | 0.00709     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1596        |
# |    iterations           | 29          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005095968 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0749     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.941       |
# |    value_loss           | 0.00685     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1600         |
# |    iterations           | 30           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0049679754 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.079       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.926        |
# |    value_loss           | 0.00682      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1605         |
# |    iterations           | 31           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0041092266 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0728      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.919        |
# |    value_loss           | 0.00699      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1610         |
# |    iterations           | 32           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0040923366 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0871      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00859     |
# |    std                  | 0.904        |
# |    value_loss           | 0.00583      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1615         |
# |    iterations           | 33           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0049956474 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0794      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.012       |
# |    std                  | 0.905        |
# |    value_loss           | 0.00737      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1620        |
# |    iterations           | 34          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005983008 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0774     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.905       |
# |    value_loss           | 0.0063      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1627         |
# |    iterations           | 35           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0043820227 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0792      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 0.901        |
# |    value_loss           | 0.00482      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1632         |
# |    iterations           | 36           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0039980146 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0643      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.901        |
# |    value_loss           | 0.00481      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1638         |
# |    iterations           | 37           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0057115545 |
# |    clip_fraction        | 0.0632       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0928      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.013       |
# |    std                  | 0.894        |
# |    value_loss           | 0.00633      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1641         |
# |    iterations           | 38           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0035230808 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0795      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.89         |
# |    value_loss           | 0.00676      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1646        |
# |    iterations           | 39          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005879923 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0868     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.892       |
# |    value_loss           | 0.00548     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1651        |
# |    iterations           | 40          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008170934 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.106      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.887       |
# |    value_loss           | 0.00599     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1655         |
# |    iterations           | 41           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0042597107 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0725      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00957     |
# |    std                  | 0.891        |
# |    value_loss           | 0.00367      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1659        |
# |    iterations           | 42          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.005462445 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0846     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.885       |
# |    value_loss           | 0.00623     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1660         |
# |    iterations           | 43           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0055292547 |
# |    clip_fraction        | 0.0534       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0863      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.888        |
# |    value_loss           | 0.00451      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1665         |
# |    iterations           | 44           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0067487676 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0794      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0127      |
# |    std                  | 0.887        |
# |    value_loss           | 0.00377      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1669        |
# |    iterations           | 45          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005707053 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0913     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.89        |
# |    value_loss           | 0.00287     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1672        |
# |    iterations           | 46          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004672804 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0708     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.889       |
# |    value_loss           | 0.00391     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1674         |
# |    iterations           | 47           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0058618244 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0838      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0123      |
# |    std                  | 0.883        |
# |    value_loss           | 0.00438      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1676         |
# |    iterations           | 48           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0059995707 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0753      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.874        |
# |    value_loss           | 0.0037       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1680         |
# |    iterations           | 49           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0046173665 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0761      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0093      |
# |    std                  | 0.874        |
# |    value_loss           | 0.00338      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1683       |
# |    iterations           | 50         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.00816238 |
# |    clip_fraction        | 0.081      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0922    |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0173    |
# |    std                  | 0.871      |
# |    value_loss           | 0.00491    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 51          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.005591938 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0888     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.87        |
# |    value_loss           | 0.00442     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1688         |
# |    iterations           | 52           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0061200107 |
# |    clip_fraction        | 0.052        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0835      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0126      |
# |    std                  | 0.874        |
# |    value_loss           | 0.0038       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1690        |
# |    iterations           | 53          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.005886974 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0684     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.87        |
# |    value_loss           | 0.00325     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1692       |
# |    iterations           | 54         |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.00521716 |
# |    clip_fraction        | 0.0454     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0859    |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0119    |
# |    std                  | 0.871      |
# |    value_loss           | 0.00232    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1694         |
# |    iterations           | 55           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0037559853 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0827      |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00835     |
# |    std                  | 0.867        |
# |    value_loss           | 0.00353      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1696        |
# |    iterations           | 56          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.006280113 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0918     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.866       |
# |    value_loss           | 0.00242     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1697        |
# |    iterations           | 57          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.005142259 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0775     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.869       |
# |    value_loss           | 0.00306     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1699        |
# |    iterations           | 58          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.005223395 |
# |    clip_fraction        | 0.0483      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0775     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.864       |
# |    value_loss           | 0.0027      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1701         |
# |    iterations           | 59           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0072796764 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0902      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0158      |
# |    std                  | 0.865        |
# |    value_loss           | 0.00345      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1703        |
# |    iterations           | 60          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.005268005 |
# ...
# |    iterations           | 80          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.007005875 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0962     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.878       |
# |    value_loss           | 0.00208     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1682        |
# |    iterations           | 81          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.006784929 |
# |    clip_fraction        | 0.0714      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0864     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.879       |
# |    value_loss           | 0.00245     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1682         |
# |    iterations           | 82           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0075839693 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0871      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0144      |
# |    std                  | 0.884        |
# |    value_loss           | 0.00151      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1683         |
# |    iterations           | 83           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0076134065 |
# |    clip_fraction        | 0.0718       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0965      |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.0159      |
# |    std                  | 0.884        |
# |    value_loss           | 0.00211      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1683        |
# |    iterations           | 84          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.007176391 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0879     |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.889       |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1684        |
# |    iterations           | 85          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.007431556 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0797     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.886       |
# |    value_loss           | 0.00198     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1684        |
# |    iterations           | 86          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.006796113 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0712     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.877       |
# |    value_loss           | 0.00241     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1685         |
# |    iterations           | 87           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0053797085 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0897      |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.013       |
# |    std                  | 0.875        |
# |    value_loss           | 0.00217      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 88          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008471571 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0805     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.88        |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 89          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.007179731 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.111      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.878       |
# |    value_loss           | 0.00216     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1685         |
# |    iterations           | 90           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0068523036 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0782      |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0136      |
# |    std                  | 0.878        |
# |    value_loss           | 0.00244      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 91          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.008622566 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0903     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.881       |
# |    value_loss           | 0.0014      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 92          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.010481704 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0823     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.877       |
# |    value_loss           | 0.00155     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 93          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.008152539 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0792     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.875       |
# |    value_loss           | 0.00166     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1685         |
# |    iterations           | 94           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0078640375 |
# |    clip_fraction        | 0.0683       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0875      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0154      |
# |    std                  | 0.88         |
# |    value_loss           | 0.00125      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 95          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.008932376 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0863     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.882       |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 96          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.010385838 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.1        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.886       |
# |    value_loss           | 0.00161     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1683        |
# |    iterations           | 97          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.008861727 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0886     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0206     |
# |    std                  | 0.888       |
# |    value_loss           | 0.00314     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1683         |
# |    iterations           | 98           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0067569586 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0906      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.884        |
# |    value_loss           | 0.0019       |
# ------------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# Generated 218 actions.
# Running Backtest...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: -0.20%
# INFO:BacktesterRL:Buy & Hold Return: 29.90%
# INFO:BacktesterRL:Outperformance: -30.10%
# --- Strategy Performance for CNP ---
# Total Return (%): -0.2000
# Annual Return (%): -0.3400
# Sharpe Ratio: 0.0669
# Sortino Ratio: 0.0995
# Max Drawdown (%): -10.3800
# Calmar Ratio: -0.0325
# Win Rate (%): 43.1000
# Total Trades: 116.0000
# Final Value ($): 99798.0700

# %%
# Multiple stocks in a loop
stocks = ["AAPL", "AMZN", "TSLA", "BAC","MDU", "CWCO", "NEE", "DUK"]
results = {}

for stock in stocks:
    print(f"\n{'='*60}")
    print(f"Processing {stock}")
    print(f"{'='*60}")
    portfolio, metrics, actions = run_ppo_trading_pipeline(
        stock_symbol=stock, 
        config=config,
        show_plot=True  # Don't show plots in loop
    )
    results[stock] = {'portfolio': portfolio, 'metrics': metrics, 'actions': actions}
# Out:
# ============================================================
# Processing AAPL
# ============================================================
# Data loaded successfully for AAPL.
# Training PPO Agent for AAPL...
# Using cpu device
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_21784\4005697599.py:29: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training PPO...
# -----------------------------
# | time/              |      |
# |    fps             | 2021 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1434        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006042389 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.348      |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.152       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00734    |
# |    std                  | 1           |
# |    value_loss           | 0.436       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1273        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005156005 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -0.265      |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.00532     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00749    |
# |    std                  | 1.02        |
# |    value_loss           | 0.162       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1202         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0075799595 |
# |    clip_fraction        | 0.0721       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.0793      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00795     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 1.03         |
# |    value_loss           | 0.151        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1195        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009073868 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | -0.0702     |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0368     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 1.03        |
# |    value_loss           | 0.137       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1170         |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0075898403 |
# |    clip_fraction        | 0.0803       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.0141       |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0446      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0136      |
# |    std                  | 1.02         |
# |    value_loss           | 0.126        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0063374457 |
# |    clip_fraction        | 0.0752       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0425      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.013       |
# |    std                  | 1.02         |
# |    value_loss           | 0.112        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1131         |
# |    iterations           | 8            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0062609217 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.43         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0483      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 1.01         |
# |    value_loss           | 0.0841       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1128        |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007852404 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.05       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 1           |
# |    value_loss           | 0.0679      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1139        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007108854 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0439     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.998       |
# |    value_loss           | 0.0721      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1146         |
# |    iterations           | 11           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0075473227 |
# |    clip_fraction        | 0.0856       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.802        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0672      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0134      |
# |    std                  | 0.989        |
# |    value_loss           | 0.0405       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 12          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006895268 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0712     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.984       |
# |    value_loss           | 0.0415      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1163         |
# |    iterations           | 13           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0060692653 |
# |    clip_fraction        | 0.0648       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0836      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.977        |
# |    value_loss           | 0.0362       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1162         |
# |    iterations           | 14           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0026578614 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0635      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00488     |
# |    std                  | 0.968        |
# |    value_loss           | 0.026        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1171        |
# |    iterations           | 15          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007810629 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0561     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.962       |
# |    value_loss           | 0.0262      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1177         |
# |    iterations           | 16           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0048365127 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0797      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00879     |
# |    std                  | 0.957        |
# |    value_loss           | 0.0229       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1180         |
# |    iterations           | 17           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0060182186 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0656      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00947     |
# |    std                  | 0.955        |
# |    value_loss           | 0.0162       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1180         |
# |    iterations           | 18           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0063803103 |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0604      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.952        |
# |    value_loss           | 0.0168       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1185        |
# |    iterations           | 19          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004569806 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0692     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0097     |
# |    std                  | 0.936       |
# |    value_loss           | 0.0153      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1188        |
# |    iterations           | 20          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005060983 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0615     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00894    |
# |    std                  | 0.935       |
# |    value_loss           | 0.015       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1189         |
# |    iterations           | 21           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0061729234 |
# |    clip_fraction        | 0.0645       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0681      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.934        |
# |    value_loss           | 0.0107       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1190        |
# |    iterations           | 22          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005777446 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0686     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00999    |
# |    std                  | 0.932       |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1193         |
# |    iterations           | 23           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0051125325 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0664      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00772     |
# |    std                  | 0.94         |
# |    value_loss           | 0.0108       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1196        |
# |    iterations           | 24          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.003819385 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0813     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00711    |
# |    std                  | 0.938       |
# |    value_loss           | 0.0103      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1195        |
# |    iterations           | 25          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004309457 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0685     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0083     |
# |    std                  | 0.934       |
# |    value_loss           | 0.00809     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1196         |
# |    iterations           | 26           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0053409757 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0701      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00957     |
# |    std                  | 0.927        |
# |    value_loss           | 0.0094       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1197         |
# |    iterations           | 27           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0051431446 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0893      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.928        |
# |    value_loss           | 0.00708      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1201        |
# |    iterations           | 28          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005707465 |
# |    clip_fraction        | 0.0644      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0825     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.927       |
# |    value_loss           | 0.00698     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1203         |
# |    iterations           | 29           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0040414785 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0834      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00902     |
# |    std                  | 0.925        |
# |    value_loss           | 0.00625      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1204        |
# |    iterations           | 30          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006196389 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0725     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00981    |
# |    std                  | 0.928       |
# |    value_loss           | 0.0053      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1207        |
# |    iterations           | 31          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004126663 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0808     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00739    |
# |    std                  | 0.926       |
# |    value_loss           | 0.00426     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1208        |
# |    iterations           | 32          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004541754 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0547     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00753    |
# |    std                  | 0.921       |
# |    value_loss           | 0.00483     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1209         |
# |    iterations           | 33           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0048279595 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0773      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00969     |
# |    std                  | 0.913        |
# |    value_loss           | 0.00596      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1211         |
# |    iterations           | 34           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0041316813 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0835      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00848     |
# |    std                  | 0.916        |
# |    value_loss           | 0.00345      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1212         |
# |    iterations           | 35           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0044008945 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0798      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00871     |
# |    std                  | 0.909        |
# |    value_loss           | 0.00771      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1214         |
# |    iterations           | 36           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0063622706 |
# |    clip_fraction        | 0.0602       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0768      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.903        |
# |    value_loss           | 0.00431      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1215        |
# |    iterations           | 37          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007034164 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0719     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.901       |
# |    value_loss           | 0.00413     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 38           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0048228325 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0701      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00937     |
# |    std                  | 0.9          |
# |    value_loss           | 0.00291      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 39           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0067838957 |
# |    clip_fraction        | 0.0735       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0843      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0145      |
# |    std                  | 0.896        |
# |    value_loss           | 0.00413      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1218        |
# |    iterations           | 40          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005106299 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.092      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.891       |
# |    value_loss           | 0.00431     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1213         |
# |    iterations           | 41           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0055626305 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0883      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.891        |
# |    value_loss           | 0.00486      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1205        |
# |    iterations           | 42          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004412033 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0803     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00991    |
# |    std                  | 0.888       |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 43           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0037978208 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0795      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00875     |
# |    std                  | 0.886        |
# |    value_loss           | 0.00225      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1206        |
# |    iterations           | 44          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004954935 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.09       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.883       |
# |    value_loss           | 0.00288     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1207         |
# |    iterations           | 45           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0052496465 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0848      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00948     |
# |    std                  | 0.882        |
# |    value_loss           | 0.00257      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1209        |
# |    iterations           | 46          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005451402 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.064      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.876       |
# |    value_loss           | 0.00265     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1211         |
# |    iterations           | 47           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0039882096 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0821      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00965     |
# |    std                  | 0.881        |
# |    value_loss           | 0.00253      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1211        |
# |    iterations           | 48          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005949924 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0827     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.877       |
# |    value_loss           | 0.00221     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 49          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006073271 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0851     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.869       |
# |    value_loss           | 0.00266     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1213         |
# |    iterations           | 50           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0073554385 |
# |    clip_fraction        | 0.0743       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0797      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0126      |
# |    std                  | 0.866        |
# |    value_loss           | 0.00214      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1215         |
# |    iterations           | 51           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0045591616 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0668      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.855        |
# |    value_loss           | 0.0021       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1215        |
# |    iterations           | 52          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.006352678 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0801     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.86        |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 53           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0057664067 |
# |    clip_fraction        | 0.0461       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0697      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00811     |
# |    std                  | 0.859        |
# |    value_loss           | 0.00179      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1217        |
# |    iterations           | 54          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.004881614 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0837     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00969    |
# |    std                  | 0.856       |
# |    value_loss           | 0.00156     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1218        |
# |    iterations           | 55          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.003915663 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0734     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00896    |
# |    std                  | 0.857       |
# |    value_loss           | 0.00175     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1218        |
# |    iterations           | 56          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.006241385 |
# |    clip_fraction        | 0.0558      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0602     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.862       |
# |    value_loss           | 0.00173     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1219         |
# |    iterations           | 57           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0042783045 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.073       |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00805     |
# |    std                  | 0.861        |
# |    value_loss           | 0.00204      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1220         |
# |    iterations           | 58           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0050864676 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0858      |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.858        |
# |    value_loss           | 0.00184      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1221        |
# |    iterations           | 59          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.006011161 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0777     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.86        |
# |    value_loss           | 0.00168     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1221         |
# |    iterations           | 60           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 122880       |
# ...
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1051        |
# |    iterations           | 81          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.004948549 |
# |    clip_fraction        | 0.0621      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.103      |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.953       |
# |    value_loss           | 0.00218     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1051         |
# |    iterations           | 82           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0049888007 |
# |    clip_fraction        | 0.0502       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.082       |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0097      |
# |    std                  | 0.95         |
# |    value_loss           | 0.00154      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1051        |
# |    iterations           | 83          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.006213174 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0865     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.949       |
# |    value_loss           | 0.00272     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 84          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.005293406 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0854     |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.953       |
# |    value_loss           | 0.0026      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 85          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.006339725 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.092      |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.957       |
# |    value_loss           | 0.00195     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1051         |
# |    iterations           | 86           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0066076224 |
# |    clip_fraction        | 0.0601       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0852      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0132      |
# |    std                  | 0.954        |
# |    value_loss           | 0.0021       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1052        |
# |    iterations           | 87          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.008890806 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0759     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.952       |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1053        |
# |    iterations           | 88          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.006945947 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.081      |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.949       |
# |    value_loss           | 0.00188     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1054         |
# |    iterations           | 89           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0074866954 |
# |    clip_fraction        | 0.077        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.102       |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0169      |
# |    std                  | 0.953        |
# |    value_loss           | 0.00241      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1054        |
# |    iterations           | 90          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.006943254 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0799     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.948       |
# |    value_loss           | 0.003       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1054        |
# |    iterations           | 91          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.006045266 |
# |    clip_fraction        | 0.0567      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0935     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.943       |
# |    value_loss           | 0.00201     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1055       |
# |    iterations           | 92         |
# |    time_elapsed         | 178        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.00595859 |
# |    clip_fraction        | 0.0469     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.076     |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.012     |
# |    std                  | 0.941      |
# |    value_loss           | 0.00172    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1053         |
# |    iterations           | 93           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0054523894 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0853      |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0114      |
# |    std                  | 0.94         |
# |    value_loss           | 0.00212      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1051         |
# |    iterations           | 94           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0062963683 |
# |    clip_fraction        | 0.0759       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0834      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0152      |
# |    std                  | 0.941        |
# |    value_loss           | 0.00252      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1052         |
# |    iterations           | 95           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0065723937 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0975      |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0134      |
# |    std                  | 0.946        |
# |    value_loss           | 0.00165      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1053         |
# |    iterations           | 96           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0062530325 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0661      |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0108      |
# |    std                  | 0.948        |
# |    value_loss           | 0.00233      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1054         |
# |    iterations           | 97           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0057014325 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.106       |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0124      |
# |    std                  | 0.948        |
# |    value_loss           | 0.00125      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1055        |
# |    iterations           | 98          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.008287777 |
# |    clip_fraction        | 0.0857      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0951     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.95        |
# |    value_loss           | 0.00364     |
# -----------------------------------------
# INFO:src.models.model_trainer_rl_v2_2:Training PPO for 200000 timesteps
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# Saved model and normalization stats for models/ppo_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# Generated 218 actions.
# Running Backtest...
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 66.78%
# INFO:BacktesterRL:Buy & Hold Return: 19.81%
# INFO:BacktesterRL:Outperformance: 46.97%
# --- Strategy Performance for DUK ---
# Total Return (%): 66.7800
# Annual Return (%): 135.4700
# Sharpe Ratio: 4.7090
# Sortino Ratio: 8.6635
# Max Drawdown (%): -4.2000
# Calmar Ratio: 32.2746
# Win Rate (%): 74.1900
# Total Trades: 62.0000
# Final Value ($): 166780.7300
# --- Trade Statistics for DUK ---
# Total number of trades: 62
#
# Trade Direction Counts:
# Direction
# Long     43
# Short    19
# Name: count, dtype: int64
#
# --- Trade Outcomes ---
# Number of profitable exits: 46
# Number of loss exits (cut loss): 16
# Win rate: 74.19%
# Average profit per winning trade: $1586.83
# Average loss per losing trade: $-388.35
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
