# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#from src.data.data_collector import DataCollector
from src.models.model_trainer_rl_v2_2_buyhold import ModelTrainerRL, TradingEnvRL
from stable_baselines3 import PPO, SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from src.models.backtester import PortfolioBacktester, PortfolioBacktesterRL
from src.utils.config_loader import load_config


config = load_config("config/config.yaml")
# Out:
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:32: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_format is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_format instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:33: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_width is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_width instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:34: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_height is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_height instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:35: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_scale is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_scale instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:133: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:141: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.plotlyjs is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.plotlyjs instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:147: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.

# %% [markdown]
# ## V2.2 PPO Agent

# %% [markdown]
# ### Function

# %%
def run_sac_trading_pipeline(stock_symbol, config, year='2022', save_path="models/", show_plot=True):
    """
    Complete SAC trading pipeline: load data, train model, generate predictions, and backtest.
    
    Parameters:
    -----------
    stock_symbol : str
        Stock ticker symbol (e.g., 'CNP', 'MDU')
    config : dict
        Configuration dictionary loaded from config.yaml
    year : str, optional
        Year for data file selection (default: '2022')
    save_path : str, optional
        Directory to save/load models (default: 'models/')
    show_plot : bool, optional
        Whether to display the portfolio plot (default: True)
    
    Returns:
    --------
    tuple : (portfolio, metrics, actions)
        - portfolio: VectorBT portfolio object
        - metrics: Dictionary of performance metrics
        - actions: Array of predicted actions
    """
    # 1. Load Data
    try:
        data = pd.read_csv(f'data/processed/{stock_symbol}_processed_{year}.csv')
        if 'Date' in data.columns:
            data['Date'] = pd.to_datetime(data['Date'])
            data.set_index('Date', inplace=True)
        print(f"Data loaded successfully for {stock_symbol}.")
    except FileNotFoundError:
        print(f"Error: Data file not found for {stock_symbol}. Check path.")
        sys.exit()
    
    # 2. Split Train/Test
    split_idx = int(len(data) * 0.7)
    train_df = data.iloc[:split_idx]
    test_df = data.iloc[split_idx:]
    
    # 3. Training Phase
    print(f"Training sac Agent for {stock_symbol}...")
    trainer = ModelTrainerRL(config['reinforcement_learning'])
    env_params = config['reinforcement_learning']['environment']
    
    env_train = TradingEnvRL(
        train_df, 
        initial_balance=env_params.get('initial_balance', 10000),
        commission=env_params.get('commission', 0.001),
        lookback_window=env_params.get('lookback_window', 30),
        reward_func='profit'
    )
    
    result = trainer.train_sac(env_train)
    trainer.save_models(save_path)
    print("Training Complete. Models saved.")
    
    # 4. Inference Phase
    print("Generating Agent Predictions on Test Data...")
    model = SAC.load(os.path.join(save_path, "sac  _model"))
    
    env_test = TradingEnvRL(
        test_df, 
        initial_balance=env_params.get('initial_balance', 100000),
        commission=env_params.get('commission', 0.001),
        lookback_window=env_params.get('lookback_window', 30),
        reward_func='profit' 
    )
    
    vec_env_test = DummyVecEnv([lambda: env_test])
    
    norm_path = os.path.join(save_path, "sac_vecnormalize.pkl")
    if os.path.exists(norm_path):
        vec_env_test = VecNormalize.load(norm_path, vec_env_test)
        vec_env_test.training = False
        vec_env_test.norm_reward = False
    else:
        print("WARNING: Normalization stats not found. Model predictions may be garbage.")
    
    obs = vec_env_test.reset()
    done = [False]
    actions = []
    
    while not done[0]:
        action, _ = model.predict(obs, deterministic=True)
        actions.append(action[0])
        obs, _, done, _ = vec_env_test.step(action)
    
    print(f"Generated {len(actions)} actions.")
    
    # 5. Backtesting Phase
    print("Running Backtest...")
    backtester = PortfolioBacktesterRL(env_params)
    
    portfolio = backtester.run_backtest(
        price_data=test_df['close'], 
        predicted_weights=np.array(actions).flatten(),
        lookback_window=env_params.get('lookback_window', 30)
    )
    
    comparison = backtester.compare_with_buy_and_hold_rl()
    metrics = backtester.get_performance_metrics()
    
    print(f"\n--- Strategy Performance for {stock_symbol} ---")
    for k, v in metrics.items():
        print(f"{k}: {v:.4f}")
    
    if show_plot:
        portfolio.plot().show()
        # Print trade statistics
        trades = portfolio.trades.records_readable
        print(f"\n--- Trade Statistics for {stock_symbol} ---")
        print(f"Total number of trades: {len(trades)}")
        #print("\nTrade Direction Counts:")
        #print(trades['Direction'].value_counts())

        # Analyze trade outcomes
        if 'PnL' in trades.columns:
                profitable_trades = trades[trades['PnL'] > 0]
                loss_trades = trades[trades['PnL'] < 0]
                
                print(f"\n--- Trade Outcomes ---")
                print(f"Number of profitable exits: {len(profitable_trades)}")
                print(f"Number of loss exits (cut loss): {len(loss_trades)}")
                print(f"Win rate: {len(profitable_trades) / len(trades) * 100:.2f}%")
                print(f"Average profit per winning trade: ${profitable_trades['PnL'].mean():.2f}" if len(profitable_trades) > 0 else "No profitable trades")
                print(f"Average loss per losing trade: ${loss_trades['PnL'].mean():.2f}" if len(loss_trades) > 0 else "No losing trades")
            


    
    return portfolio, metrics, np.array(actions).flatten()

# %%
## Single stock
stock_symbol = "CNP"
portfolio, metrics, actions = run_ppo_trading_pipeline(stock_symbol, config)
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_49968\1970358808.py:29: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2_buyhold:Training PPO...
# Data loaded successfully for CNP.
# Training PPO Agent for CNP...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2198 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0032407343 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.441       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.143        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00354     |
# |    std                  | 1.01         |
# |    value_loss           | 0.387        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1817         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0050761513 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.339        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0232      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00762     |
# |    std                  | 1            |
# |    value_loss           | 0.142        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1792         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0049979887 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00722     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00914     |
# |    std                  | 1.01         |
# |    value_loss           | 0.138        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1772        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008464437 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.00127    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 1.02        |
# |    value_loss           | 0.129       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1767         |
# |    iterations           | 6            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0071936585 |
# |    clip_fraction        | 0.0839       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.477        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.024       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 1.02         |
# |    value_loss           | 0.135        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1761        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005215614 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0573     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.02        |
# |    value_loss           | 0.0911      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1757        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006447099 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0654     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 1.03        |
# |    value_loss           | 0.0787      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1759         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0055220732 |
# |    clip_fraction        | 0.0681       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0331      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 1.02         |
# |    value_loss           | 0.0794       |
# ------------------------------------------

# %%
# portfolio.trades.records_readable
# Print trade statistics
trades = portfolio.trades.records_readable
print(f"\n--- Trade Statistics for abc ---")
print(f"Total number of trades: {len(trades)}")
print("\nTrade Direction Counts:")
print(trades['Direction'].value_counts())

# Analyze trade outcomes
if 'PnL' in trades.columns:
        profitable_trades = trades[trades['PnL'] > 0]
        loss_trades = trades[trades['PnL'] < 0]
        
        print(f"\n--- Trade Outcomes ---")
        print(f"Number of profitable exits: {len(profitable_trades)}")
        print(f"Number of loss exits (cut loss): {len(loss_trades)}")
        print(f"Win rate: {len(profitable_trades) / len(trades) * 100:.2f}%")
        print(f"Average profit per winning trade: ${profitable_trades['PnL'].mean():.2f}" if len(profitable_trades) > 0 else "No profitable trades")
        print(f"Average loss per losing trade: ${loss_trades['PnL'].mean():.2f}" if len(loss_trades) > 0 else "No losing trades")
# Out:
# --- Trade Statistics for abc ---
# Total number of trades: 30
#
# Trade Direction Counts:
# Direction
# Long    30
# Name: count, dtype: int64
#
# --- Trade Outcomes ---
# Number of profitable exits: 24
# Number of loss exits (cut loss): 6
# Win rate: 80.00%
# Average profit per winning trade: $1691.00
# Average loss per losing trade: $-171.27

# %%
# Multiple stocks in a loop
stocks = ["CNP", "MDU", "CWCO", "NEE", "DUK"]
results = {}

for stock in stocks:
    print(f"\n{'='*60}")
    print(f"Processing {stock}")
    print(f"{'='*60}")
    portfolio, metrics, actions = run_ppo_trading_pipeline(
        stock_symbol=stock, 
        config=config,
        show_plot=True  # Don't show plots in loop
    )
    results[stock] = {'portfolio': portfolio, 'metrics': metrics, 'actions': actions}
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_49968\1835811511.py:29: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2_buyhold:Training PPO...
# ============================================================
# Processing CNP
# ============================================================
# Data loaded successfully for CNP.
# Training PPO Agent for CNP...
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2322 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2013         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0050826063 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0123       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00813     |
# |    std                  | 1.02         |
# |    value_loss           | 0.305        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1925         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0057104975 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.285        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0156      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00598     |
# |    std                  | 1.02         |
# |    value_loss           | 0.146        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1880        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007610944 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.00518     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 1.02        |
# |    value_loss           | 0.206       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1826        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006588951 |
# |    clip_fraction        | 0.066       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.423       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0424     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 1.02        |
# |    value_loss           | 0.116       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1797        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007864615 |
# |    clip_fraction        | 0.0802      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0374     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 1.02        |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1783        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006378142 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0563     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 1.02        |
# |    value_loss           | 0.0702      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1774        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006342929 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0461     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0731      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1768        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004024959 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0656     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00828    |
# |    std                  | 1           |
# |    value_loss           | 0.0674      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1762        |
# |    iterations           | 10          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007092391 |
# |    clip_fraction        | 0.0841      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0557     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.993       |
# |    value_loss           | 0.0532      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1759        |
# |    iterations           | 11          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004895135 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0622     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00951    |
# |    std                  | 0.992       |
# |    value_loss           | 0.0458      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1762       |
# |    iterations           | 12         |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00719543 |
# |    clip_fraction        | 0.0688     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.79       |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0648    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0109    |
# |    std                  | 0.99       |
# |    value_loss           | 0.0371     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1761        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005709942 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0437     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00961    |
# |    std                  | 0.988       |
# |    value_loss           | 0.0357      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1759         |
# |    iterations           | 14           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0062907855 |
# |    clip_fraction        | 0.0612       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.838        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0729      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.981        |
# |    value_loss           | 0.0325       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1757        |
# |    iterations           | 15          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005852302 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0798     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.97        |
# |    value_loss           | 0.0272      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1753         |
# |    iterations           | 16           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0044270344 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.89         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0736      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00935     |
# |    std                  | 0.974        |
# |    value_loss           | 0.0249       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1741         |
# |    iterations           | 17           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0059698597 |
# |    clip_fraction        | 0.046        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0695      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00917     |
# |    std                  | 0.965        |
# |    value_loss           | 0.026        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1737         |
# |    iterations           | 18           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0064391242 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0938      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.012       |
# |    std                  | 0.963        |
# |    value_loss           | 0.0175       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1736        |
# |    iterations           | 19          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005301621 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0713     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00937    |
# |    std                  | 0.97        |
# |    value_loss           | 0.0237      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1734         |
# |    iterations           | 20           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0042726733 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0686      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00835     |
# |    std                  | 0.976        |
# |    value_loss           | 0.0189       |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1729       |
# |    iterations           | 21         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00474088 |
# |    clip_fraction        | 0.0388     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0819    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00932   |
# |    std                  | 0.975      |
# |    value_loss           | 0.0161     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1721         |
# |    iterations           | 22           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0052729533 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0817      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00975     |
# |    std                  | 0.983        |
# |    value_loss           | 0.0149       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1717         |
# |    iterations           | 23           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0052917246 |
# |    clip_fraction        | 0.0606       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0801      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.98         |
# |    value_loss           | 0.0166       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1717        |
# |    iterations           | 24          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004237925 |
# |    clip_fraction        | 0.0392      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0807     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0089     |
# |    std                  | 0.977       |
# |    value_loss           | 0.011       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1715         |
# |    iterations           | 25           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0043314425 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0823      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 0.97         |
# |    value_loss           | 0.0134       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1714        |
# |    iterations           | 26          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.003946339 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0818     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00918    |
# |    std                  | 0.959       |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1710        |
# |    iterations           | 27          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.005645063 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0816     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00998    |
# |    std                  | 0.963       |
# |    value_loss           | 0.00998     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1712         |
# |    iterations           | 28           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0041998103 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0735      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00823     |
# |    std                  | 0.956        |
# |    value_loss           | 0.0101       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1712         |
# |    iterations           | 29           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0039561586 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0662      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00865     |
# |    std                  | 0.96         |
# |    value_loss           | 0.0113       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1712         |
# |    iterations           | 30           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0064603477 |
# |    clip_fraction        | 0.0582       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0951      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0112      |
# |    std                  | 0.959        |
# |    value_loss           | 0.0083       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1711         |
# |    iterations           | 31           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0055514127 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0785      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00819     |
# |    std                  | 0.958        |
# |    value_loss           | 0.00799      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1712         |
# |    iterations           | 32           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0056061274 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0668      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0114      |
# |    std                  | 0.956        |
# |    value_loss           | 0.00888      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1712        |
# |    iterations           | 33          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004165471 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0893     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0087     |
# |    std                  | 0.956       |
# |    value_loss           | 0.00691     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1712         |
# |    iterations           | 34           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0047055394 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0816      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00838     |
# |    std                  | 0.957        |
# |    value_loss           | 0.00618      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1710        |
# |    iterations           | 35          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.003558414 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0879     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00738    |
# |    std                  | 0.951       |
# |    value_loss           | 0.0065      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1711        |
# |    iterations           | 36          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004025612 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0694     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00807    |
# |    std                  | 0.948       |
# |    value_loss           | 0.00657     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1709        |
# |    iterations           | 37          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006549107 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0765     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.942       |
# |    value_loss           | 0.00497     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1708        |
# |    iterations           | 38          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004700846 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0635     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00882    |
# |    std                  | 0.945       |
# |    value_loss           | 0.00437     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1709         |
# |    iterations           | 39           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0039310046 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0834      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00798     |
# |    std                  | 0.944        |
# |    value_loss           | 0.00515      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1708         |
# |    iterations           | 40           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0035981208 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0647      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00914     |
# |    std                  | 0.95         |
# |    value_loss           | 0.00473      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1706         |
# |    iterations           | 41           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0050180624 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0824      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.945        |
# |    value_loss           | 0.00606      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1706        |
# |    iterations           | 42          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007417995 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0818     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.948       |
# |    value_loss           | 0.00617     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1704        |
# |    iterations           | 43          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004247508 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.087      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00965    |
# |    std                  | 0.945       |
# |    value_loss           | 0.00512     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1704         |
# |    iterations           | 44           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0080809295 |
# |    clip_fraction        | 0.0634       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0778      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0118      |
# |    std                  | 0.941        |
# |    value_loss           | 0.00497      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1705         |
# |    iterations           | 45           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0044844663 |
# |    clip_fraction        | 0.0402       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0793      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00855     |
# |    std                  | 0.941        |
# |    value_loss           | 0.00457      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1704         |
# |    iterations           | 46           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0053338828 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0785      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00954     |
# |    std                  | 0.941        |
# |    value_loss           | 0.00371      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1704        |
# |    iterations           | 47          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004274934 |
# |    clip_fraction        | 0.0392      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0979     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.941       |
# |    value_loss           | 0.00377     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1703        |
# |    iterations           | 48          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005291167 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.1        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0095     |
# |    std                  | 0.94        |
# |    value_loss           | 0.00431     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1704        |
# |    iterations           | 49          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004251118 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0906     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0093     |
# |    std                  | 0.949       |
# |    value_loss           | 0.00375     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1704         |
# |    iterations           | 50           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0048605134 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0826      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0111      |
# |    std                  | 0.958        |
# |    value_loss           | 0.00383      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1702         |
# |    iterations           | 51           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0049552387 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.091       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 0.949        |
# |    value_loss           | 0.00401      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1703        |
# |    iterations           | 52          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.004226412 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0809     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00817    |
# |    std                  | 0.948       |
# |    value_loss           | 0.00437     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1703         |
# |    iterations           | 53           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0038925814 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0805      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00915     |
# |    std                  | 0.947        |
# |    value_loss           | 0.00363      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1703        |
# |    iterations           | 54          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.005003824 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0956     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.949       |
# |    value_loss           | 0.00466     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1701       |
# |    iterations           | 55         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.00542718 |
# |    clip_fraction        | 0.0412     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.99       |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0743    |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0089    |
# |    std                  | 0.948      |
# |    value_loss           | 0.00527    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1699        |
# |    iterations           | 56          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.004734154 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0808     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.938       |
# |    value_loss           | 0.00406     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1699         |
# |    iterations           | 57           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0057140784 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0936      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.0124      |
# |    std                  | 0.93         |
# |    value_loss           | 0.00395      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1699        |
# |    iterations           | 58          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.005127074 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.092      |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00933    |
# |    std                  | 0.925       |
# |    value_loss           | 0.00458     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1699         |
# |    iterations           | 59           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0059442464 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0878      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0118      |
# |    std                  | 0.928        |
# |    value_loss           | 0.00561      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1700         |
# |    iterations           | 60           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0049137957 |
# ...
# |    fps                  | 1779       |
# |    iterations           | 7          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00574188 |
# |    clip_fraction        | 0.0491     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.47      |
# |    explained_variance   | 0.502      |
# |    learning_rate        | 0.0002     |
# |    loss                 | -0.0424    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00862   |
# |    std                  | 1.05       |
# |    value_loss           | 0.117      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1777        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008474665 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0488     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 1.06        |
# |    value_loss           | 0.0966      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1769         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0067513273 |
# |    clip_fraction        | 0.0655       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0586      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 1.06         |
# |    value_loss           | 0.0761       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1762         |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0048124306 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0533      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00912     |
# |    std                  | 1.07         |
# |    value_loss           | 0.0633       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1756         |
# |    iterations           | 11           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0037788022 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.745        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0586      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00849     |
# |    std                  | 1.06         |
# |    value_loss           | 0.0714       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1741        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006432805 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0642     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 1.05        |
# |    value_loss           | 0.0583      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1731        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005961498 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0831     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 1.06        |
# |    value_loss           | 0.0362      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1734        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004967925 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0609     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 1.06        |
# |    value_loss           | 0.045       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1732         |
# |    iterations           | 15           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0058055655 |
# |    clip_fraction        | 0.0598       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0725      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0094      |
# |    std                  | 1.05         |
# |    value_loss           | 0.0367       |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       7 print(f"Processing {stock}")
#       8 print(f"{'='*60}")
# ----> 9 portfolio, metrics, actions = run_ppo_trading_pipeline(
#      10     stock_symbol=stock,
#      11     config=config,
#      12     show_plot=True  # Don't show plots in loop
#      13 )
#      14 results[stock] = {'portfolio': portfolio, 'metrics': metrics, 'actions': actions}
#
# Cell In[2], line 54, in run_ppo_trading_pipeline(stock_symbol, config, year, save_path, show_plot)
#      44 env_params = config['reinforcement_learning']['environment']
#      46 env_train = TradingEnvRL(
#      47     train_df,
#      48     initial_balance=env_params.get('initial_balance', 10000),
#    (...)     51     reward_func='profit'
#      52 )
# ---> 54 result = trainer.train_ppo(env_train)
#      55 trainer.save_models(save_path)
#      56 print("Training Complete. Models saved.")
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\src\models\model_trainer_rl_v2_2_buyhold.py:356, in ModelTrainerRL.train_ppo(self, env)
#     341 model = PPO(
#     342     "MlpPolicy",
#     343     vec_env,
#    (...)    351     verbose=1,
#     352 )
#     354 logger.info("Training PPO...")
# --> 356 model.learn(total_timesteps=timesteps)
#     357 logger.info("Training PPO for %d timesteps", timesteps)
#     358 # FIX: Store the environment stats so we can save them later
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\stable_baselines3\ppo\ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)    309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:202, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)  # type: ignore[arg-type]
# --> 202     actions, values, log_probs = self.policy(obs_tensor)
#     203 actions = actions.cpu().numpy()
#     205 # Rescale and perform action
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\stable_baselines3\common\policies.py:647, in ActorCriticPolicy.forward(self, obs, deterministic)
#     645 features = self.extract_features(obs)
#     646 if self.share_features_extractor:
# --> 647     latent_pi, latent_vf = self.mlp_extractor(features)
#     648 else:
#     649     pi_features, vf_features = features
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\stable_baselines3\common\torch_layers.py:257, in MlpExtractor.forward(self, features)
#     252 def forward(self, features: th.Tensor) -> tuple[th.Tensor, th.Tensor]:
#     253     """
#     254     :return: latent_policy, latent_value of the specified network.
#     255         If all layers are shared, then ``latent_policy == latent_value``
#     256     """
# --> 257     return self.forward_actor(features), self.forward_critic(features)
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\stable_baselines3\common\torch_layers.py:260, in MlpExtractor.forward_actor(self, features)
#     259 def forward_actor(self, features: th.Tensor) -> th.Tensor:
# --> 260     return self.policy_net(features)
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\torch\nn\modules\activation.py:430, in Tanh.forward(self, input)
#     426 def forward(self, input: Tensor) -> Tensor:
#     427     """
#     428     Runs the forward pass.
#     429     """
# --> 430     return torch.tanh(input)
#
# KeyboardInterrupt:
