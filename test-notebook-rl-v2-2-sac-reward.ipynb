# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#from src.data.data_collector import DataCollector
from src.models.model_trainer_rl_v2_2 import ModelTrainerRL, TradingEnvRL
from stable_baselines3 import PPO, A2C, DDPG, SAC, TD3
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from src.models.backtester import PortfolioBacktester, PortfolioBacktesterRL
from src.utils.config_loader import load_config


config = load_config("config/config.yaml")
# Out:
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:32: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_format is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_format instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:33: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_width is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_width instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:34: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_height is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_height instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\kaleido\scopes\plotly.py:35: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.default_scale is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.default_scale instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:133: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:141: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.plotlyjs is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.plotlyjs instead.
#
#
# d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\plotly\io\_kaleido.py:147: DeprecationWarning:
#
#
# Use of plotly.io.kaleido.scope.mathjax is deprecated and support will be removed after September 2025.
# Please use plotly.io.defaults.mathjax instead.

# %% [markdown]
# ## V2.2 - SAC

# %% [markdown]
# #### CWCO

# %%
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv('data/processed/CWCO_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training SAC Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_sac(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = SAC.load(os.path.join(save_path, "sac_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, "sac_vecnormalize.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_17340\2324582290.py:6: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
# Data loaded successfully.
# Training SAC Agent...
# Using cpu device
# INFO:src.models.model_trainer_rl_v2_2:Training SAC for 150000 timesteps
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 96       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 2348     |
# | train/             |          |
# |    actor_loss      | -5.2     |
# |    critic_loss     | 0.0139   |
# |    ent_coef        | 0.51     |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2247     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 94       |
# |    time_elapsed    | 49       |
# |    total_timesteps | 4696     |
# | train/             |          |
# |    actor_loss      | -6.51    |
# |    critic_loss     | 0.00761  |
# |    ent_coef        | 0.253    |
# |    ent_coef_loss   | -2.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4595     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 96       |
# |    time_elapsed    | 73       |
# |    total_timesteps | 7044     |
# | train/             |          |
# |    actor_loss      | -6.87    |
# |    critic_loss     | 0.00356  |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -3.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6943     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 100      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 9392     |
# | train/             |          |
# |    actor_loss      | -6.57    |
# |    critic_loss     | 0.00228  |
# |    ent_coef        | 0.0632   |
# |    ent_coef_loss   | -4.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9291     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 102      |
# |    time_elapsed    | 114      |
# |    total_timesteps | 11740    |
# | train/             |          |
# |    actor_loss      | -6.01    |
# |    critic_loss     | 0.00153  |
# |    ent_coef        | 0.0322   |
# |    ent_coef_loss   | -4.73    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11639    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 103      |
# |    time_elapsed    | 136      |
# |    total_timesteps | 14088    |
# | train/             |          |
# |    actor_loss      | -5.55    |
# |    critic_loss     | 0.000937 |
# |    ent_coef        | 0.0167   |
# |    ent_coef_loss   | -4.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13987    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 101      |
# |    time_elapsed    | 162      |
# |    total_timesteps | 16436    |
# | train/             |          |
# |    actor_loss      | -5.16    |
# |    critic_loss     | 0.001    |
# |    ent_coef        | 0.00904  |
# |    ent_coef_loss   | -4       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16335    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 99       |
# |    time_elapsed    | 188      |
# |    total_timesteps | 18784    |
# | train/             |          |
# |    actor_loss      | -4.58    |
# |    critic_loss     | 0.000297 |
# |    ent_coef        | 0.00522  |
# |    ent_coef_loss   | -3.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18683    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 99       |
# |    time_elapsed    | 212      |
# |    total_timesteps | 21132    |
# | train/             |          |
# |    actor_loss      | -4.34    |
# |    critic_loss     | 0.000171 |
# |    ent_coef        | 0.00348  |
# |    ent_coef_loss   | -0.0803  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21031    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 97       |
# |    time_elapsed    | 240      |
# |    total_timesteps | 23480    |
# | train/             |          |
# |    actor_loss      | -3.95    |
# |    critic_loss     | 0.000207 |
# |    ent_coef        | 0.00305  |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23379    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 97       |
# |    time_elapsed    | 265      |
# |    total_timesteps | 25828    |
# | train/             |          |
# |    actor_loss      | -3.67    |
# |    critic_loss     | 0.000163 |
# |    ent_coef        | 0.003    |
# |    ent_coef_loss   | -0.0837  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25727    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 96       |
# |    time_elapsed    | 291      |
# |    total_timesteps | 28176    |
# | train/             |          |
# |    actor_loss      | -3.42    |
# |    critic_loss     | 0.000167 |
# |    ent_coef        | 0.00299  |
# |    ent_coef_loss   | -0.297   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28075    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 97       |
# |    time_elapsed    | 314      |
# |    total_timesteps | 30524    |
# | train/             |          |
# |    actor_loss      | -3.32    |
# |    critic_loss     | 0.000117 |
# |    ent_coef        | 0.00297  |
# |    ent_coef_loss   | -0.0632  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30423    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 97       |
# |    time_elapsed    | 336      |
# |    total_timesteps | 32872    |
# | train/             |          |
# |    actor_loss      | -3.02    |
# |    critic_loss     | 0.000102 |
# |    ent_coef        | 0.00289  |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32771    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 98       |
# |    time_elapsed    | 358      |
# |    total_timesteps | 35220    |
# | train/             |          |
# |    actor_loss      | -2.9     |
# |    critic_loss     | 6.14e-05 |
# |    ent_coef        | 0.00295  |
# |    ent_coef_loss   | -0.452   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35119    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 96       |
# |    time_elapsed    | 387      |
# |    total_timesteps | 37568    |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 8.31e-05 |
# |    ent_coef        | 0.00294  |
# |    ent_coef_loss   | -0.258   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37467    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 96       |
# |    time_elapsed    | 411      |
# |    total_timesteps | 39916    |
# | train/             |          |
# |    actor_loss      | -2.61    |
# |    critic_loss     | 5.64e-05 |
# |    ent_coef        | 0.00296  |
# |    ent_coef_loss   | -0.313   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39815    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 97       |
# |    time_elapsed    | 434      |
# |    total_timesteps | 42264    |
# | train/             |          |
# |    actor_loss      | -2.59    |
# |    critic_loss     | 8.42e-05 |
# |    ent_coef        | 0.00298  |
# |    ent_coef_loss   | 0.0411   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42163    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 97       |
# |    time_elapsed    | 457      |
# |    total_timesteps | 44612    |
# | train/             |          |
# |    actor_loss      | -2.45    |
# |    critic_loss     | 0.000114 |
# |    ent_coef        | 0.00298  |
# |    ent_coef_loss   | -0.344   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44511    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 97       |
# |    time_elapsed    | 482      |
# |    total_timesteps | 46960    |
# | train/             |          |
# |    actor_loss      | -2.37    |
# |    critic_loss     | 0.000125 |
# |    ent_coef        | 0.00299  |
# |    ent_coef_loss   | -0.622   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46859    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 97       |
# |    time_elapsed    | 507      |
# |    total_timesteps | 49308    |
# | train/             |          |
# |    actor_loss      | -2.45    |
# |    critic_loss     | 2.74e-05 |
# |    ent_coef        | 0.00297  |
# |    ent_coef_loss   | 1.17     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49207    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 96       |
# |    time_elapsed    | 534      |
# |    total_timesteps | 51656    |
# | train/             |          |
# |    actor_loss      | -2.28    |
# |    critic_loss     | 4.14e-05 |
# |    ent_coef        | 0.003    |
# |    ent_coef_loss   | -0.187   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51555    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 95       |
# |    time_elapsed    | 565      |
# |    total_timesteps | 54004    |
# | train/             |          |
# |    actor_loss      | -2.31    |
# |    critic_loss     | 3.69e-05 |
# |    ent_coef        | 0.00303  |
# |    ent_coef_loss   | -0.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 53903    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 94       |
# |    time_elapsed    | 597      |
# |    total_timesteps | 56352    |
# | train/             |          |
# |    actor_loss      | -2.29    |
# |    critic_loss     | 3.06e-05 |
# |    ent_coef        | 0.00306  |
# |    ent_coef_loss   | -0.046   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 56251    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 92       |
# |    time_elapsed    | 632      |
# |    total_timesteps | 58700    |
# | train/             |          |
# |    actor_loss      | -2.34    |
# |    critic_loss     | 6.39e-05 |
# |    ent_coef        | 0.00309  |
# |    ent_coef_loss   | 0.113    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58599    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 91       |
# |    time_elapsed    | 663      |
# |    total_timesteps | 61048    |
# | train/             |          |
# |    actor_loss      | -2.33    |
# |    critic_loss     | 5.42e-05 |
# |    ent_coef        | 0.00309  |
# |    ent_coef_loss   | 0.319    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 60947    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 91       |
# |    time_elapsed    | 694      |
# |    total_timesteps | 63396    |
# | train/             |          |
# |    actor_loss      | -2.27    |
# |    critic_loss     | 3.01e-05 |
# |    ent_coef        | 0.00309  |
# |    ent_coef_loss   | 0.484    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63295    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 90       |
# |    time_elapsed    | 723      |
# |    total_timesteps | 65744    |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 0.000116 |
# |    ent_coef        | 0.00314  |
# |    ent_coef_loss   | 0.2      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 65643    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 91       |
# |    time_elapsed    | 744      |
# |    total_timesteps | 68092    |
# | train/             |          |
# |    actor_loss      | -2.25    |
# |    critic_loss     | 2.27e-05 |
# |    ent_coef        | 0.00316  |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 67991    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 91       |
# |    time_elapsed    | 766      |
# |    total_timesteps | 70440    |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 0.00016  |
# |    ent_coef        | 0.00315  |
# |    ent_coef_loss   | 0.166    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70339    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 90       |
# |    time_elapsed    | 800      |
# |    total_timesteps | 72788    |
# | train/             |          |
# |    actor_loss      | -2.18    |
# |    critic_loss     | 2.9e-05  |
# |    ent_coef        | 0.00318  |
# |    ent_coef_loss   | 0.333    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72687    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 89       |
# |    time_elapsed    | 836      |
# |    total_timesteps | 75136    |
# | train/             |          |
# |    actor_loss      | -2.31    |
# |    critic_loss     | 2.33e-05 |
# |    ent_coef        | 0.00321  |
# |    ent_coef_loss   | 1.33     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75035    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 88       |
# |    time_elapsed    | 877      |
# |    total_timesteps | 77484    |
# | train/             |          |
# |    actor_loss      | -2.17    |
# |    critic_loss     | 4.54e-05 |
# |    ent_coef        | 0.00324  |
# |    ent_coef_loss   | -0.00108 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 77383    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 87       |
# |    time_elapsed    | 909      |
# |    total_timesteps | 79832    |
# | train/             |          |
# |    actor_loss      | -2.17    |
# |    critic_loss     | 0.00018  |
# |    ent_coef        | 0.00322  |
# |    ent_coef_loss   | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79731    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 87       |
# |    time_elapsed    | 941      |
# |    total_timesteps | 82180    |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 1.84e-05 |
# |    ent_coef        | 0.00325  |
# |    ent_coef_loss   | 0.597    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 82079    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 86       |
# |    time_elapsed    | 973      |
# |    total_timesteps | 84528    |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 3.14e-05 |
# |    ent_coef        | 0.00325  |
# |    ent_coef_loss   | -0.319   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 84427    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 86       |
# |    time_elapsed    | 1006     |
# |    total_timesteps | 86876    |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 2.9e-05  |
# |    ent_coef        | 0.00326  |
# |    ent_coef_loss   | -0.332   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 86775    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 86       |
# |    time_elapsed    | 1036     |
# |    total_timesteps | 89224    |
# | train/             |          |
# |    actor_loss      | -2.25    |
# |    critic_loss     | 3.43e-05 |
# |    ent_coef        | 0.00331  |
# |    ent_coef_loss   | 0.073    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 89123    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 85       |
# |    time_elapsed    | 1066     |
# |    total_timesteps | 91572    |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 3.81e-05 |
# |    ent_coef        | 0.00333  |
# |    ent_coef_loss   | 0.61     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91471    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 85       |
# |    time_elapsed    | 1095     |
# |    total_timesteps | 93920    |
# | train/             |          |
# |    actor_loss      | -2.24    |
# |    critic_loss     | 1.55e-05 |
# |    ent_coef        | 0.00333  |
# |    ent_coef_loss   | 0.213    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 93819    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 85       |
# |    time_elapsed    | 1127     |
# |    total_timesteps | 96268    |
# | train/             |          |
# |    actor_loss      | -2.3     |
# |    critic_loss     | 1.83e-05 |
# |    ent_coef        | 0.00335  |
# |    ent_coef_loss   | -0.556   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96167    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 85       |
# |    time_elapsed    | 1157     |
# |    total_timesteps | 98616    |
# | train/             |          |
# |    actor_loss      | -2.33    |
# |    critic_loss     | 1.53e-05 |
# |    ent_coef        | 0.00334  |
# |    ent_coef_loss   | 1        |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98515    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 84       |
# |    time_elapsed    | 1190     |
# |    total_timesteps | 100964   |
# | train/             |          |
# |    actor_loss      | -2.27    |
# |    critic_loss     | 2.49e-05 |
# |    ent_coef        | 0.00336  |
# |    ent_coef_loss   | -0.767   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100863   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 84       |
# |    time_elapsed    | 1224     |
# |    total_timesteps | 103312   |
# | train/             |          |
# |    actor_loss      | -2.3     |
# |    critic_loss     | 1.99e-05 |
# |    ent_coef        | 0.00339  |
# |    ent_coef_loss   | 0.407    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 103211   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 84       |
# |    time_elapsed    | 1256     |
# |    total_timesteps | 105660   |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 5.57e-05 |
# |    ent_coef        | 0.00342  |
# |    ent_coef_loss   | 0.312    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 105559   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 83       |
# |    time_elapsed    | 1287     |
# |    total_timesteps | 108008   |
# | train/             |          |
# |    actor_loss      | -2.38    |
# |    critic_loss     | 2.11e-05 |
# |    ent_coef        | 0.00343  |
# |    ent_coef_loss   | 0.408    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 107907   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 83       |
# |    time_elapsed    | 1319     |
# |    total_timesteps | 110356   |
# | train/             |          |
# |    actor_loss      | -2.34    |
# |    critic_loss     | 1.84e-05 |
# |    ent_coef        | 0.00346  |
# |    ent_coef_loss   | 0.00576  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110255   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 83       |
# |    time_elapsed    | 1352     |
# |    total_timesteps | 112704   |
# | train/             |          |
# |    actor_loss      | -2.36    |
# |    critic_loss     | 2.03e-05 |
# |    ent_coef        | 0.00342  |
# |    ent_coef_loss   | -0.265   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 112603   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 83       |
# |    time_elapsed    | 1385     |
# |    total_timesteps | 115052   |
# | train/             |          |
# |    actor_loss      | -2.31    |
# |    critic_loss     | 1.81e-05 |
# |    ent_coef        | 0.0034   |
# |    ent_coef_loss   | 0.112    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 114951   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 82       |
# |    time_elapsed    | 1416     |
# |    total_timesteps | 117400   |
# | train/             |          |
# |    actor_loss      | -2.46    |
# |    critic_loss     | 3.7e-05  |
# |    ent_coef        | 0.00339  |
# |    ent_coef_loss   | 1.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117299   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 82       |
# |    time_elapsed    | 1446     |
# |    total_timesteps | 119748   |
# | train/             |          |
# |    actor_loss      | -2.46    |
# |    critic_loss     | 1.77e-05 |
# |    ent_coef        | 0.00338  |
# |    ent_coef_loss   | -0.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 119647   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 82       |
# |    time_elapsed    | 1476     |
# |    total_timesteps | 122096   |
# | train/             |          |
# |    actor_loss      | -2.51    |
# |    critic_loss     | 6.98e-06 |
# |    ent_coef        | 0.00337  |
# |    ent_coef_loss   | -0.145   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 121995   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 82       |
# |    time_elapsed    | 1505     |
# |    total_timesteps | 124444   |
# | train/             |          |
# |    actor_loss      | -2.31    |
# |    critic_loss     | 1.33e-05 |
# |    ent_coef        | 0.00339  |
# |    ent_coef_loss   | -0.0143  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 124343   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 82       |
# |    time_elapsed    | 1531     |
# |    total_timesteps | 126792   |
# | train/             |          |
# |    actor_loss      | -2.38    |
# |    critic_loss     | 3.45e-05 |
# |    ent_coef        | 0.00337  |
# |    ent_coef_loss   | 0.234    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 126691   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 83       |
# |    time_elapsed    | 1554     |
# |    total_timesteps | 129140   |
# | train/             |          |
# |    actor_loss      | -2.46    |
# |    critic_loss     | 1.16e-05 |
# |    ent_coef        | 0.00339  |
# |    ent_coef_loss   | 0.34     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 129039   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 83       |
# |    time_elapsed    | 1577     |
# |    total_timesteps | 131488   |
# | train/             |          |
# |    actor_loss      | -2.45    |
# |    critic_loss     | 1.98e-05 |
# |    ent_coef        | 0.00338  |
# |    ent_coef_loss   | 0.482    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 131387   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 83       |
# |    time_elapsed    | 1601     |
# |    total_timesteps | 133836   |
# | train/             |          |
# |    actor_loss      | -2.43    |
# |    critic_loss     | 2.86e-05 |
# |    ent_coef        | 0.00342  |
# |    ent_coef_loss   | 0.155    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 133735   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 83       |
# |    time_elapsed    | 1625     |
# |    total_timesteps | 136184   |
# | train/             |          |
# |    actor_loss      | -2.49    |
# |    critic_loss     | 1.31e-05 |
# |    ent_coef        | 0.00341  |
# |    ent_coef_loss   | 0.679    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 136083   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 84       |
# |    time_elapsed    | 1648     |
# |    total_timesteps | 138532   |
# | train/             |          |
# |    actor_loss      | -2.53    |
# |    critic_loss     | 3.73e-05 |
# |    ent_coef        | 0.0034   |
# |    ent_coef_loss   | 0.95     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 138431   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 84       |
# |    time_elapsed    | 1671     |
# |    total_timesteps | 140880   |
# | train/             |          |
# |    actor_loss      | -2.41    |
# |    critic_loss     | 1.88e-05 |
# |    ent_coef        | 0.00345  |
# |    ent_coef_loss   | 0.592    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 140779   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 84       |
# |    time_elapsed    | 1693     |
# |    total_timesteps | 143228   |
# | train/             |          |
# |    actor_loss      | -2.41    |
# |    critic_loss     | 1.01e-05 |
# |    ent_coef        | 0.00342  |
# |    ent_coef_loss   | 1.48     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 143127   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 84       |
# |    time_elapsed    | 1716     |
# |    total_timesteps | 145576   |
# | train/             |          |
# |    actor_loss      | -2.53    |
# |    critic_loss     | 4.01e-05 |
# |    ent_coef        | 0.00345  |
# |    ent_coef_loss   | 0.202    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 145475   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 85       |
# |    time_elapsed    | 1739     |
# |    total_timesteps | 147924   |
# | train/             |          |
# |    actor_loss      | -2.5     |
# |    critic_loss     | 1.1e-05  |
# |    ent_coef        | 0.00349  |
# |    ent_coef_loss   | 0.242    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 147823   |
# ---------------------------------
# Saved model and normalization stats for models/sac_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# Generated 218 actions.
# Running Backtest...
# INFO:BacktesterRL:Backtest successfully completed.
# INFO:BacktesterRL:Strategy Return: 142.57%
# INFO:BacktesterRL:Buy & Hold Return: 32.68%
# INFO:BacktesterRL:Outperformance: 109.89%
# --- Strategy Performance ---
# Total Return (%): 142.5700
# Annual Return (%): 340.9000
# Sharpe Ratio: 5.0000
# Sortino Ratio: 12.8690
# Max Drawdown (%): -7.1700
# Calmar Ratio: 47.5450
# Win Rate (%): 70.5900
# Total Trades: 119.0000
# Final Value ($): 242571.6000

# %% [markdown]
# #### NEE

# %%
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv('data/processed/NEE_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training SAC Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_sac(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = SAC.load(os.path.join(save_path, "sac_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, "sac_vecnormalize.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_12092\2807267510.py:6: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training SAC for 150000 timesteps
# Data loaded successfully.
# Training SAC Agent...
# Using cpu device
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 102      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 2348     |
# | train/             |          |
# |    actor_loss      | -5.1     |
# |    critic_loss     | 0.0198   |
# |    ent_coef        | 0.51     |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2247     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 101      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 4696     |
# | train/             |          |
# |    actor_loss      | -6.6     |
# |    critic_loss     | 0.0084   |
# |    ent_coef        | 0.253    |
# |    ent_coef_loss   | -2.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4595     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 103      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 7044     |
# | train/             |          |
# |    actor_loss      | -6.76    |
# |    critic_loss     | 0.00398  |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -3.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6943     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 105      |
# |    time_elapsed    | 88       |
# |    total_timesteps | 9392     |
# | train/             |          |
# |    actor_loss      | -6.68    |
# |    critic_loss     | 0.00175  |
# |    ent_coef        | 0.0635   |
# |    ent_coef_loss   | -4.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9291     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 107      |
# |    time_elapsed    | 109      |
# |    total_timesteps | 11740    |
# | train/             |          |
# |    actor_loss      | -6.05    |
# |    critic_loss     | 0.000896 |
# |    ent_coef        | 0.0323   |
# |    ent_coef_loss   | -4.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11639    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 108      |
# |    time_elapsed    | 130      |
# |    total_timesteps | 14088    |
# | train/             |          |
# |    actor_loss      | -5.61    |
# |    critic_loss     | 0.000746 |
# |    ent_coef        | 0.0168   |
# |    ent_coef_loss   | -4.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13987    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 108      |
# |    time_elapsed    | 152      |
# |    total_timesteps | 16436    |
# | train/             |          |
# |    actor_loss      | -5.22    |
# |    critic_loss     | 0.00055  |
# |    ent_coef        | 0.00909  |
# |    ent_coef_loss   | -3.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16335    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 105      |
# |    time_elapsed    | 177      |
# |    total_timesteps | 18784    |
# | train/             |          |
# |    actor_loss      | -4.74    |
# |    critic_loss     | 0.000276 |
# |    ent_coef        | 0.00523  |
# |    ent_coef_loss   | -2.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18683    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 104      |
# |    time_elapsed    | 202      |
# |    total_timesteps | 21132    |
# | train/             |          |
# |    actor_loss      | -4.41    |
# |    critic_loss     | 0.000119 |
# |    ent_coef        | 0.00348  |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21031    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 103      |
# |    time_elapsed    | 227      |
# |    total_timesteps | 23480    |
# | train/             |          |
# |    actor_loss      | -4.27    |
# |    critic_loss     | 0.000102 |
# |    ent_coef        | 0.00313  |
# |    ent_coef_loss   | -0.197   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23379    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 100      |
# |    time_elapsed    | 257      |
# |    total_timesteps | 25828    |
# | train/             |          |
# |    actor_loss      | -3.63    |
# |    critic_loss     | 0.000102 |
# |    ent_coef        | 0.00315  |
# |    ent_coef_loss   | -0.124   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25727    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 97       |
# |    time_elapsed    | 289      |
# |    total_timesteps | 28176    |
# | train/             |          |
# |    actor_loss      | -3.57    |
# |    critic_loss     | 0.000153 |
# |    ent_coef        | 0.00312  |
# |    ent_coef_loss   | 0.729    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28075    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 95       |
# |    time_elapsed    | 320      |
# |    total_timesteps | 30524    |
# | train/             |          |
# |    actor_loss      | -3.41    |
# |    critic_loss     | 0.000105 |
# |    ent_coef        | 0.00314  |
# |    ent_coef_loss   | -0.497   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30423    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 95       |
# |    time_elapsed    | 344      |
# |    total_timesteps | 32872    |
# | train/             |          |
# |    actor_loss      | -3.04    |
# |    critic_loss     | 0.000151 |
# |    ent_coef        | 0.00313  |
# |    ent_coef_loss   | -0.827   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32771    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 93       |
# |    time_elapsed    | 375      |
# |    total_timesteps | 35220    |
# | train/             |          |
# |    actor_loss      | -2.99    |
# |    critic_loss     | 9.32e-05 |
# |    ent_coef        | 0.00319  |
# |    ent_coef_loss   | 0.289    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35119    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 92       |
# |    time_elapsed    | 407      |
# |    total_timesteps | 37568    |
# | train/             |          |
# |    actor_loss      | -2.76    |
# |    critic_loss     | 6.61e-05 |
# |    ent_coef        | 0.00316  |
# |    ent_coef_loss   | 0.393    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37467    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 91       |
# |    time_elapsed    | 436      |
# |    total_timesteps | 39916    |
# | train/             |          |
# |    actor_loss      | -2.64    |
# |    critic_loss     | 0.000171 |
# |    ent_coef        | 0.00314  |
# |    ent_coef_loss   | 0.0232   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39815    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 90       |
# |    time_elapsed    | 465      |
# |    total_timesteps | 42264    |
# | train/             |          |
# |    actor_loss      | -2.5     |
# |    critic_loss     | 6.17e-05 |
# |    ent_coef        | 0.00318  |
# |    ent_coef_loss   | 0.355    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42163    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 90       |
# |    time_elapsed    | 494      |
# |    total_timesteps | 44612    |
# | train/             |          |
# |    actor_loss      | -2.49    |
# |    critic_loss     | 3.92e-05 |
# |    ent_coef        | 0.00317  |
# |    ent_coef_loss   | 0.27     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44511    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 90       |
# |    time_elapsed    | 521      |
# |    total_timesteps | 46960    |
# | train/             |          |
# |    actor_loss      | -2.3     |
# |    critic_loss     | 5.28e-05 |
# |    ent_coef        | 0.00321  |
# |    ent_coef_loss   | -0.0854  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46859    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 90       |
# |    time_elapsed    | 542      |
# |    total_timesteps | 49308    |
# | train/             |          |
# |    actor_loss      | -2.35    |
# |    critic_loss     | 3.06e-05 |
# |    ent_coef        | 0.00322  |
# |    ent_coef_loss   | 0.376    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49207    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 91       |
# |    time_elapsed    | 566      |
# |    total_timesteps | 51656    |
# | train/             |          |
# |    actor_loss      | -2.37    |
# |    critic_loss     | 3.08e-05 |
# |    ent_coef        | 0.00324  |
# |    ent_coef_loss   | -0.302   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51555    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 91       |
# |    time_elapsed    | 589      |
# |    total_timesteps | 54004    |
# | train/             |          |
# |    actor_loss      | -2.23    |
# |    critic_loss     | 3.96e-05 |
# |    ent_coef        | 0.00323  |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 53903    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 91       |
# |    time_elapsed    | 612      |
# |    total_timesteps | 56352    |
# | train/             |          |
# |    actor_loss      | -2.23    |
# |    critic_loss     | 4.88e-05 |
# |    ent_coef        | 0.00325  |
# |    ent_coef_loss   | 0.378    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 56251    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 92       |
# |    time_elapsed    | 635      |
# |    total_timesteps | 58700    |
# | train/             |          |
# |    actor_loss      | -2.24    |
# |    critic_loss     | 4.46e-05 |
# |    ent_coef        | 0.00328  |
# |    ent_coef_loss   | 0.525    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58599    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 92       |
# |    time_elapsed    | 658      |
# |    total_timesteps | 61048    |
# | train/             |          |
# |    actor_loss      | -2.19    |
# |    critic_loss     | 2.77e-05 |
# |    ent_coef        | 0.00331  |
# |    ent_coef_loss   | 0.862    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 60947    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 93       |
# |    time_elapsed    | 681      |
# |    total_timesteps | 63396    |
# | train/             |          |
# |    actor_loss      | -2.16    |
# |    critic_loss     | 3.11e-05 |
# |    ent_coef        | 0.00333  |
# |    ent_coef_loss   | -0.167   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63295    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 93       |
# |    time_elapsed    | 703      |
# |    total_timesteps | 65744    |
# | train/             |          |
# |    actor_loss      | -2.09    |
# |    critic_loss     | 2.36e-05 |
# |    ent_coef        | 0.00335  |
# |    ent_coef_loss   | -0.00894 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 65643    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 92       |
# |    time_elapsed    | 733      |
# |    total_timesteps | 68092    |
# | train/             |          |
# |    actor_loss      | -2.18    |
# |    critic_loss     | 2.33e-05 |
# |    ent_coef        | 0.0034   |
# |    ent_coef_loss   | 0.519    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 67991    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 92       |
# |    time_elapsed    | 761      |
# |    total_timesteps | 70440    |
# | train/             |          |
# |    actor_loss      | -2.13    |
# |    critic_loss     | 3.12e-05 |
# |    ent_coef        | 0.00342  |
# |    ent_coef_loss   | -0.436   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70339    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 92       |
# |    time_elapsed    | 790      |
# |    total_timesteps | 72788    |
# | train/             |          |
# |    actor_loss      | -2.17    |
# |    critic_loss     | 2.24e-05 |
# |    ent_coef        | 0.00345  |
# |    ent_coef_loss   | -0.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72687    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 91       |
# |    time_elapsed    | 818      |
# |    total_timesteps | 75136    |
# | train/             |          |
# |    actor_loss      | -2.16    |
# |    critic_loss     | 2.61e-05 |
# |    ent_coef        | 0.00343  |
# |    ent_coef_loss   | -0.0747  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75035    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 91       |
# |    time_elapsed    | 846      |
# |    total_timesteps | 77484    |
# | train/             |          |
# |    actor_loss      | -2.12    |
# |    critic_loss     | 3.2e-05  |
# |    ent_coef        | 0.00348  |
# |    ent_coef_loss   | -0.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 77383    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 91       |
# |    time_elapsed    | 872      |
# |    total_timesteps | 79832    |
# | train/             |          |
# |    actor_loss      | -2.22    |
# |    critic_loss     | 4.27e-05 |
# |    ent_coef        | 0.0035   |
# |    ent_coef_loss   | -0.128   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79731    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 92       |
# |    time_elapsed    | 892      |
# |    total_timesteps | 82180    |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 4.9e-05  |
# |    ent_coef        | 0.00349  |
# |    ent_coef_loss   | 0.625    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 82079    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 92       |
# |    time_elapsed    | 913      |
# |    total_timesteps | 84528    |
# | train/             |          |
# |    actor_loss      | -2.22    |
# |    critic_loss     | 1.6e-05  |
# |    ent_coef        | 0.00354  |
# |    ent_coef_loss   | 0.24     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 84427    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 92       |
# |    time_elapsed    | 938      |
# |    total_timesteps | 86876    |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 1.88e-05 |
# |    ent_coef        | 0.00352  |
# |    ent_coef_loss   | 0.597    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 86775    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 92       |
# |    time_elapsed    | 967      |
# |    total_timesteps | 89224    |
# | train/             |          |
# |    actor_loss      | -2.28    |
# |    critic_loss     | 1.35e-05 |
# |    ent_coef        | 0.00357  |
# |    ent_coef_loss   | -0.00415 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 89123    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 91       |
# |    time_elapsed    | 996      |
# |    total_timesteps | 91572    |
# | train/             |          |
# |    actor_loss      | -2.19    |
# |    critic_loss     | 1.75e-05 |
# |    ent_coef        | 0.00357  |
# |    ent_coef_loss   | 0.364    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91471    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 91       |
# |    time_elapsed    | 1021     |
# |    total_timesteps | 93920    |
# | train/             |          |
# |    actor_loss      | -2.2     |
# |    critic_loss     | 3.73e-05 |
# |    ent_coef        | 0.00357  |
# |    ent_coef_loss   | 0.436    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 93819    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 92       |
# |    time_elapsed    | 1046     |
# |    total_timesteps | 96268    |
# | train/             |          |
# |    actor_loss      | -2.26    |
# |    critic_loss     | 2.81e-05 |
# |    ent_coef        | 0.00359  |
# |    ent_coef_loss   | 1.74     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96167    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 92       |
# |    time_elapsed    | 1070     |
# |    total_timesteps | 98616    |
# | train/             |          |
# |    actor_loss      | -2.36    |
# |    critic_loss     | 3.52e-05 |
# |    ent_coef        | 0.00364  |
# |    ent_coef_loss   | -0.335   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98515    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 91       |
# |    time_elapsed    | 1097     |
# |    total_timesteps | 100964   |
# | train/             |          |
# |    actor_loss      | -2.25    |
# |    critic_loss     | 3.11e-05 |
# |    ent_coef        | 0.00363  |
# |    ent_coef_loss   | 0.589    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100863   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 92       |
# |    time_elapsed    | 1122     |
# |    total_timesteps | 103312   |
# | train/             |          |
# |    actor_loss      | -2.33    |
# |    critic_loss     | 1.45e-05 |
# |    ent_coef        | 0.00369  |
# |    ent_coef_loss   | 0.157    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 103211   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 92       |
# |    time_elapsed    | 1147     |
# |    total_timesteps | 105660   |
# | train/             |          |
# |    actor_loss      | -2.25    |
# |    critic_loss     | 1.4e-05  |
# |    ent_coef        | 0.00371  |
# |    ent_coef_loss   | 0.865    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 105559   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 92       |
# |    time_elapsed    | 1172     |
# |    total_timesteps | 108008   |
# | train/             |          |
# |    actor_loss      | -2.39    |
# |    critic_loss     | 3.13e-05 |
# |    ent_coef        | 0.00371  |
# |    ent_coef_loss   | 0.271    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 107907   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 91       |
# |    time_elapsed    | 1201     |
# |    total_timesteps | 110356   |
# | train/             |          |
# |    actor_loss      | -2.29    |
# |    critic_loss     | 1.88e-05 |
# |    ent_coef        | 0.00374  |
# |    ent_coef_loss   | -0.517   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110255   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 91       |
# |    time_elapsed    | 1230     |
# |    total_timesteps | 112704   |
# | train/             |          |
# |    actor_loss      | -2.38    |
# |    critic_loss     | 2.09e-05 |
# |    ent_coef        | 0.00372  |
# |    ent_coef_loss   | 0.548    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 112603   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 91       |
# |    time_elapsed    | 1253     |
# |    total_timesteps | 115052   |
# | train/             |          |
# |    actor_loss      | -2.27    |
# |    critic_loss     | 2.66e-05 |
# |    ent_coef        | 0.00373  |
# |    ent_coef_loss   | -0.186   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 114951   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 92       |
# |    time_elapsed    | 1273     |
# |    total_timesteps | 117400   |
# | train/             |          |
# |    actor_loss      | -2.31    |
# |    critic_loss     | 3.73e-05 |
# |    ent_coef        | 0.00368  |
# |    ent_coef_loss   | 0.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117299   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 92       |
# |    time_elapsed    | 1296     |
# |    total_timesteps | 119748   |
# | train/             |          |
# |    actor_loss      | -2.37    |
# |    critic_loss     | 2.29e-05 |
# |    ent_coef        | 0.00369  |
# |    ent_coef_loss   | -0.681   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 119647   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 92       |
# |    time_elapsed    | 1323     |
# |    total_timesteps | 122096   |
# | train/             |          |
# |    actor_loss      | -2.35    |
# |    critic_loss     | 1.66e-05 |
# |    ent_coef        | 0.0037   |
# |    ent_coef_loss   | 0.373    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 121995   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 91       |
# |    time_elapsed    | 1354     |
# |    total_timesteps | 124444   |
# | train/             |          |
# |    actor_loss      | -2.39    |
# |    critic_loss     | 9.1e-06  |
# |    ent_coef        | 0.00372  |
# |    ent_coef_loss   | -0.183   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 124343   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 91       |
# |    time_elapsed    | 1383     |
# |    total_timesteps | 126792   |
# | train/             |          |
# |    actor_loss      | -2.39    |
# |    critic_loss     | 7.03e-05 |
# |    ent_coef        | 0.0037   |
# |    ent_coef_loss   | 1.15     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 126691   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 91       |
# |    time_elapsed    | 1412     |
# |    total_timesteps | 129140   |
# | train/             |          |
# |    actor_loss      | -2.31    |
# |    critic_loss     | 6.11e-06 |
# |    ent_coef        | 0.0037   |
# |    ent_coef_loss   | -0.434   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 129039   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 91       |
# |    time_elapsed    | 1440     |
# |    total_timesteps | 131488   |
# | train/             |          |
# |    actor_loss      | -2.37    |
# |    critic_loss     | 1.61e-05 |
# |    ent_coef        | 0.00371  |
# |    ent_coef_loss   | -0.466   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 131387   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 90       |
# |    time_elapsed    | 1470     |
# |    total_timesteps | 133836   |
# | train/             |          |
# |    actor_loss      | -2.41    |
# |    critic_loss     | 7.24e-06 |
# |    ent_coef        | 0.00374  |
# |    ent_coef_loss   | 1.16     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 133735   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 90       |
# |    time_elapsed    | 1498     |
# |    total_timesteps | 136184   |
# | train/             |          |
# |    actor_loss      | -2.32    |
# |    critic_loss     | 3.23e-05 |
# |    ent_coef        | 0.00373  |
# |    ent_coef_loss   | -0.649   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 136083   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 90       |
# |    time_elapsed    | 1528     |
# |    total_timesteps | 138532   |
# | train/             |          |
# |    actor_loss      | -2.4     |
# |    critic_loss     | 1.32e-05 |
# |    ent_coef        | 0.00377  |
# |    ent_coef_loss   | 0.106    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 138431   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 90       |
# |    time_elapsed    | 1558     |
# |    total_timesteps | 140880   |
# | train/             |          |
# |    actor_loss      | -2.45    |
# |    critic_loss     | 5.34e-05 |
# |    ent_coef        | 0.00376  |
# |    ent_coef_loss   | 0.375    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 140779   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 90       |
# |    time_elapsed    | 1586     |
# |    total_timesteps | 143228   |
# | train/             |          |
# |    actor_loss      | -2.44    |
# |    critic_loss     | 1.97e-05 |
# |    ent_coef        | 0.00377  |
# |    ent_coef_loss   | 0.022    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 143127   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 90       |
# |    time_elapsed    | 1612     |
# |    total_timesteps | 145576   |
# | train/             |          |
# |    actor_loss      | -2.53    |
# |    critic_loss     | 8.79e-06 |
# |    ent_coef        | 0.00375  |
# |    ent_coef_loss   | 0.157    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 145475   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 90       |
# |    time_elapsed    | 1638     |
# |    total_timesteps | 147924   |
# | train/             |          |
# |    actor_loss      | -2.47    |
# |    critic_loss     | 2.86e-05 |
# |    ent_coef        | 0.00381  |
# |    ent_coef_loss   | 0.296    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 147823   |
# ---------------------------------
# Saved model and normalization stats for models/sac_vecnormalize.pkl
# Training Complete. Models saved.
# Generating Agent Predictions on Test Data...
# INFO:BacktesterRL:Preparing Backtest. Raw Prices: 279, Predictions: 218
# INFO:BacktesterRL:Running vectorbt simulation...
# INFO:BacktesterRL:Backtest successfully completed.
# Generated 218 actions.
# Running Backtest...
# INFO:BacktesterRL:Strategy Return: 36.57%
# INFO:BacktesterRL:Buy & Hold Return: 28.02%
# INFO:BacktesterRL:Outperformance: 8.55%
# --- Strategy Performance ---
# Total Return (%): 36.5700
# Annual Return (%): 68.5100
# Sharpe Ratio: 2.3579
# Sortino Ratio: 3.7094
# Max Drawdown (%): -12.0000
# Calmar Ratio: 5.7097
# Win Rate (%): 52.9900
# Total Trades: 134.0000
# Final Value ($): 136568.5700

# %% [markdown]
# #### MDU

# %%
stock_symbol = "MDU"
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv(f'data/processed/{stock_symbol}_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training SAC Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_sac(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = SAC.load(os.path.join(save_path, "sac_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, f"sac_vecnormalize_{stock_symbol}.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
# Out:
# C:\Users\BOOKLAPTOP\AppData\Local\Temp\ipykernel_12092\1211995638.py:7: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#
# INFO:src.models.model_trainer_rl_v2_2:Training SAC for 150000 timesteps
# Data loaded successfully.
# Training SAC Agent...
# Using cpu device
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 107      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2348     |
# | train/             |          |
# |    actor_loss      | -5.12    |
# |    critic_loss     | 0.0123   |
# |    ent_coef        | 0.51     |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2247     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 98       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 4696     |
# | train/             |          |
# |    actor_loss      | -6.65    |
# |    critic_loss     | 0.0128   |
# |    ent_coef        | 0.253    |
# |    ent_coef_loss   | -2.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4595     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 92       |
# |    time_elapsed    | 76       |
# |    total_timesteps | 7044     |
# | train/             |          |
# |    actor_loss      | -6.92    |
# |    critic_loss     | 0.00406  |
# |    ent_coef        | 0.127    |
# |    ent_coef_loss   | -3.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6943     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 37
#      27 env_train = TradingEnvRL(
#      28     train_df,
#      29     initial_balance=env_params.get('initial_balance', 10000),
#    (...)     32     reward_func='profit'
#      33 )
#      35 # Train and Save
#      36 # This automatically handles the VecNormalize wrapper creation
# ---> 37 result = trainer.train_sac(env_train)
#      39 # IMPORTANT: Save the model and the normalization stats to disk
#      40 # We will reload them for the test phase to ensure consistency
#      41 save_path = "models/"
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\src\models\model_trainer_rl_v2_2.py:481, in ModelTrainerRL.train_sac(self, env)
#     468 model = SAC(
#     469     "MlpPolicy",
#     470     vec_env,
#    (...)    477     verbose=1,
#     478 )
#     480 logger.info("Training SAC for %d timesteps", timesteps)
# --> 481 model.learn(total_timesteps=timesteps)
#     483 # 3. Store Normalization Stats for Saving
#     484 # We need to save these stats to use the model later!
#     485 self.vec_norm_stats["sac"] = vec_env
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\stable_baselines3\sac\sac.py:313, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     304 def learn(
#     305     self: SelfSAC,
#     306     total_timesteps: int,
#    (...)    311     progress_bar: bool = False,
#     312 ) -> SelfSAC:
# --> 313     return super().learn(
#     314         total_timesteps=total_timesteps,
#     315         callback=callback,
#     316         log_interval=log_interval,
#     317         tb_log_name=tb_log_name,
#     318         reset_num_timesteps=reset_num_timesteps,
#     319         progress_bar=progress_bar,
#     320     )
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:354, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     352         # Special case when the user passes `gradient_steps=0`
#     353         if gradient_steps > 0:
# --> 354             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     356 callback.on_training_end()
#     358 return self
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\stable_baselines3\sac\sac.py:291, in SAC.train(self, gradient_steps, batch_size)
#     289 # Update target networks
#     290 if gradient_step % self.target_update_interval == 0:
# --> 291     polyak_update(self.critic.parameters(), self.critic_target.parameters(), self.tau)
#     292     # Copy running stats, see GH issue #996
#     293     polyak_update(self.batch_norm_stats, self.batch_norm_stats_target, 1.0)
#
# File d:\MSDS\buy-sell-hold-strategy-prediction\venv-3.11\Lib\site-packages\stable_baselines3\common\utils.py:561, in polyak_update(params, target_params, tau)
#     559 for param, target_param in zip_strict(params, target_params):
#     560     target_param.data.mul_(1 - tau)
# --> 561     th.add(target_param.data, param.data, alpha=tau, out=target_param.data)
#
# KeyboardInterrupt:

# %% [markdown]
# #### YORW

# %%
stock_symbol = "YORW"
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv(f'data/processed/{stock_symbol}_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training SAC Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_sac(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = SAC.load(os.path.join(save_path, "sac_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, f"sac_vecnormalize_{stock_symbol}.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()

# %% [markdown]
# #### PCG

# %%
stock_symbol = "PCG"
# 2. Load Data
try:
    # ensuring your path is correct
    data = pd.read_csv(f'data/processed/{stock_symbol}_processed_2022.csv')
    if 'Date' in data.columns:
        data['Date'] = pd.to_datetime(data['Date'])
        data.set_index('Date', inplace=True)
    print("Data loaded successfully.")
except FileNotFoundError:
    print("Error: Data file not found. Check path.")
    sys.exit()

# 3. Split Train/Test
split_idx = int(len(data) * 0.7)
train_df = data.iloc[:split_idx]
test_df = data.iloc[split_idx:]

# --- TRAINING PHASE ---
print("Training SAC Agent...")

# Initialize Trainer (Pass config if needed, or defaults)
trainer = ModelTrainerRL(config['reinforcement_learning'])
env_params = config['reinforcement_learning']['environment']

# Create Training Environment
env_train = TradingEnvRL(
    train_df, 
    initial_balance=env_params.get('initial_balance', 10000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit'
)

# Train and Save
# This automatically handles the VecNormalize wrapper creation
result = trainer.train_sac(env_train) 

# IMPORTANT: Save the model and the normalization stats to disk
# We will reload them for the test phase to ensure consistency
save_path = "models/"
trainer.save_models(save_path)
print("Training Complete. Models saved.")

# --- INFERENCE PHASE (UPDATED) ---
print("Generating Agent Predictions on Test Data...")

# 1. Load the Trained Model
model = SAC.load(os.path.join(save_path, "sac_model"))

# 2. Create the Test Environment
# Must have the same observation space (columns) as training
env_test = TradingEnvRL(
    test_df, 
    initial_balance=env_params.get('initial_balance', 100000),
    commission=env_params.get('commission', 0.001),
    lookback_window=env_params.get('lookback_window', 30),
    reward_func='profit' 
)

# 3. Wrap it in DummyVecEnv (Required for SB3)
vec_env_test = DummyVecEnv([lambda: env_test])

# 4. Load Normalization Statistics
# This applies the Training Mean/Variance to the Test Data (Crucial!)
norm_path = os.path.join(save_path, f"sac_vecnormalize_{stock_symbol}.pkl")
if os.path.exists(norm_path):
    vec_env_test = VecNormalize.load(norm_path, vec_env_test)
    vec_env_test.training = False     # Do not update stats on test data
    vec_env_test.norm_reward = False  # Do not normalize rewards for testing
else:
    print("WARNING: Normalization stats not found. Model predictions may be garbage.")

# 5. Run Inference Loop
obs = vec_env_test.reset()
done = [False]  # VecEnv returns done as a list/array
actions = []

while not done[0]:
    # Predict action (obs is now correctly scaled)
    action, _ = model.predict(obs, deterministic=True)
    actions.append(action[0]) # Extract single action
    
    # Step the environment
    obs, _, done, _ = vec_env_test.step(action)

print(f"Generated {len(actions)} actions.")


# --- BACKTESTING PHASE ---
print("Running Backtest...")

backtester = PortfolioBacktesterRL(env_params) 

# Note: 'actions' corresponds to the period [lookback_window : end]
# Ensure your backtester handles this alignment. 
# Usually, passing the full price_data and the lookback_window allows 
# the backtester to slice the prices correctly to match the actions.
portfolio = backtester.run_backtest(
    price_data=test_df['close'], 
    predicted_weights=np.array(actions).flatten(),
    lookback_window=env_params.get('lookback_window', 30)
)

comparison = backtester.compare_with_buy_and_hold_rl()

# Show Metrics
metrics = backtester.get_performance_metrics()
print("\n--- Strategy Performance ---")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
    
# Plot
portfolio.plot().show()
